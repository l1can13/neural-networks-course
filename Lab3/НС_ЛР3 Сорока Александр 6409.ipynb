# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# 1) Полносвязная нейронная сеть ( Fully-Connected Neural Network)
#
# 2) Нормализация по мини-батчам (Batch normalization)
#
# 3) Dropout
#
# 4) Сверточные нейронные сети (Convolutional Networks)

# %% [markdown]
# Лабораторные работы можно выполнять с использованием сервиса Google Colaboratory (https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) или на локальном компьютере.

# %% [markdown]
# # Полносвязная нейронная сеть

# %% [markdown]
# В данной лабораторной работе необходимо будет реализовать полносвязную нейронную сеть, используя модульный подход. Для каждого  слоя реализации прямого и обратного проходов алгоритма обратного распространения ошибки будут иметь следующий вид:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
#
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```

# %%
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from scripts.classifiers.fc_net import *

from scripts.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from scripts.solver import Solver
from scripts.classifiers.cnn import *
from scripts.layers import *
from scripts.fast_layers import *


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()
# Out:
# =========== You can safely ignore the message below if you are NOT working on ConvolutionalNetworks.ipynb ===========
# 	You will need to compile a Cython extension for a portion of this assignment.
# 	The instructions to do this will be given in a section of the notebook below.
# 	There will be an option for Colab users and another for Jupyter (local) users.

# %% [markdown]
# Загрузите данные из предыдущей лабораторной работы.

# %%
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
import numpy as np

# Загрузка CIFAR-10 датасета
(X, y), (X_test, y_test) = cifar10.load_data()

# Нормализация y
y = y.flatten()
y_test = y_test.flatten()

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=1000/50000, random_state=42)

X_train = X_train.transpose(0, 3, 1, 2)
X_val = X_val.transpose(0, 3, 1, 2)
X_test = X_test.transpose(0, 3, 1, 2)

data = {
    'X_train': X_train,
    'y_train': y_train,
    'X_val': X_val,
    'y_val': y_val,
    'X_test': X_test,
    'y_test': y_test
}

# %% [markdown]
# Для полносвязного слоя реализуйте прямой проход (метод affine_forward в scripts/layers.py). Протестируйте свою реализацию.

# %%
num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])


print('Testing affine_forward function:')
print(f'out: {out}\ncorrect_out: {correct_out}')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# out: [[1.49834967 1.70660132 1.91485297]
#  [3.25553199 3.5141327  3.77273342]]
# correct_out: [[1.49834967 1.70660132 1.91485297]
#  [3.25553199 3.5141327  3.77273342]]
# difference:  9.769849468192957e-10

# %% [markdown]
# Для полносвязного слоя реализуйте обратный проход (метод affine_backward в scripts/layers.py). Протестируйте свою реализацию.

# %%
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# Реализуйте прямой проход для слоя активации ReLU (relu_forward) и протестируйте его.

# %%
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# Реализуйте обратный проход для слоя активации ReLU (relu_backward ) и протестируйте его.

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# В скрипте /layer_utils.py приведены реализации прямого и обратного проходов для часто используемых комбинаций слоев. Например, за полносвязным слоем часто следует слой активации. Ознакомьтесь с функциями affine_relu_forward и affine_relu_backward, запустите код ниже и убедитесь, что ошибка порядка e-10 или ниже.

# %%
from scripts.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# Реализуйте двухслойную полносвязную сеть - класс TwoLayerNet в scripts/classifiers/fc_net.py . Проверьте свою реализацию, запустив код ниже.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.12e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 7.76e-10

# %% [markdown]
# Ознакомьтесь с API для обучения и тестирования моделей в scripts/solver.py . Используйте экземпляр класса Solver для обучения двухслойной полносвязной сети. Необходимо достичь минимум 50% верно классифицированных объектов на валидационном наборе.

# %%
model = TwoLayerNet()
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 5e-4,
                },
                lr_decay=0.95,
                num_epochs=45, batch_size=200,
                print_every=1000)
solver.train()

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 10125) loss: 2.306551
# (Epoch 0 / 45) train acc: 0.119000; val_acc: 0.110000
# (Epoch 1 / 45) train acc: 0.239000; val_acc: 0.245200
# (Epoch 2 / 45) train acc: 0.349000; val_acc: 0.366400
# (Epoch 3 / 45) train acc: 0.428000; val_acc: 0.395600
# (Epoch 4 / 45) train acc: 0.368000; val_acc: 0.389000
# (Iteration 1001 / 10125) loss: 1.693861
# (Epoch 5 / 45) train acc: 0.404000; val_acc: 0.377000
# (Epoch 6 / 45) train acc: 0.402000; val_acc: 0.381600
# (Epoch 7 / 45) train acc: 0.406000; val_acc: 0.399000
# (Epoch 8 / 45) train acc: 0.415000; val_acc: 0.399600
# (Iteration 2001 / 10125) loss: 1.490960
# (Epoch 9 / 45) train acc: 0.440000; val_acc: 0.421000
# (Epoch 10 / 45) train acc: 0.423000; val_acc: 0.409600
# (Epoch 11 / 45) train acc: 0.484000; val_acc: 0.447400
# (Epoch 12 / 45) train acc: 0.472000; val_acc: 0.444400
# (Epoch 13 / 45) train acc: 0.478000; val_acc: 0.436600
# (Iteration 3001 / 10125) loss: 1.339780
# (Epoch 14 / 45) train acc: 0.507000; val_acc: 0.466200
# (Epoch 15 / 45) train acc: 0.510000; val_acc: 0.444800
# (Epoch 16 / 45) train acc: 0.509000; val_acc: 0.465600
# (Epoch 17 / 45) train acc: 0.469000; val_acc: 0.435400
# (Iteration 4001 / 10125) loss: 1.450783
# (Epoch 18 / 45) train acc: 0.493000; val_acc: 0.461200
# (Epoch 19 / 45) train acc: 0.515000; val_acc: 0.469400
# (Epoch 20 / 45) train acc: 0.541000; val_acc: 0.483400
# (Epoch 21 / 45) train acc: 0.513000; val_acc: 0.476200
# (Epoch 22 / 45) train acc: 0.531000; val_acc: 0.479800
# (Iteration 5001 / 10125) loss: 1.304308
# (Epoch 23 / 45) train acc: 0.527000; val_acc: 0.475800
# (Epoch 24 / 45) train acc: 0.482000; val_acc: 0.471800
# (Epoch 25 / 45) train acc: 0.544000; val_acc: 0.475000
# (Epoch 26 / 45) train acc: 0.552000; val_acc: 0.479000
# (Iteration 6001 / 10125) loss: 1.257696
# (Epoch 27 / 45) train acc: 0.553000; val_acc: 0.488400
# (Epoch 28 / 45) train acc: 0.580000; val_acc: 0.487400
# (Epoch 29 / 45) train acc: 0.541000; val_acc: 0.485400
# (Epoch 30 / 45) train acc: 0.527000; val_acc: 0.470000
# (Epoch 31 / 45) train acc: 0.540000; val_acc: 0.497600
# (Iteration 7001 / 10125) loss: 1.322393
# (Epoch 32 / 45) train acc: 0.535000; val_acc: 0.483000
# (Epoch 33 / 45) train acc: 0.549000; val_acc: 0.496800
# (Epoch 34 / 45) train acc: 0.561000; val_acc: 0.495400
# (Epoch 35 / 45) train acc: 0.564000; val_acc: 0.502600
# (Iteration 8001 / 10125) loss: 1.260217
# (Epoch 36 / 45) train acc: 0.587000; val_acc: 0.498200
# (Epoch 37 / 45) train acc: 0.559000; val_acc: 0.503000
# (Epoch 38 / 45) train acc: 0.545000; val_acc: 0.498800
# (Epoch 39 / 45) train acc: 0.582000; val_acc: 0.497200
# (Epoch 40 / 45) train acc: 0.581000; val_acc: 0.501400
# (Iteration 9001 / 10125) loss: 1.229375
# (Epoch 41 / 45) train acc: 0.585000; val_acc: 0.499200
# (Epoch 42 / 45) train acc: 0.574000; val_acc: 0.504400
# (Epoch 43 / 45) train acc: 0.566000; val_acc: 0.507000
# (Epoch 44 / 45) train acc: 0.580000; val_acc: 0.500000
# (Iteration 10001 / 10125) loss: 1.154898
# (Epoch 45 / 45) train acc: 0.594000; val_acc: 0.503600

# %%
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# Теперь реализуйте полносвязную сеть с произвольным числом скрытых слоев. Ознакомьтесь с классом FullyConnectedNet в scripts/classifiers/fc_net.py . Реализуйте инициализацию, прямой и обратный проходы.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # NOTE: It is fine however to see an error for W2 on the order of e-5
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 7.36e-09
# W2 relative error: 6.87e-08
# W3 relative error: 3.48e-08
# b1 relative error: 1.48e-08
# b2 relative error: 1.72e-09
# b3 relative error: 1.80e-10

# %% [markdown]
# Попробуйте добиться эффекта переобучения на небольшом наборе изображений (например, 50). Используйте трехслойную сеть со 100 нейронами на каждом скрытом слое. Попробуйте переобучить сеть, достигнув 100 % accuracy за 20 эпох. Для этого поэкспериментируйте с параметрами weight_scale и learning_rate.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

weight_scale = 5e-2   # Заданный масштаб веса
learning_rate = 5e-4  # Заданная скорость обучения

train_acc = 0
iteration = 0

while train_acc < 1.0:
    print(f"\nИтерация: {iteration + 1}")
    model = FullyConnectedNet([100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver = Solver(model, small_data,
                    print_every=400, num_epochs=20, batch_size=25,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    verbose=True)
    solver.train()

    # Получение и вывод последней точности на обучающем наборе
    train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
    print(f'Final train accuracy after iteration {iteration + 1}: {train_acc}')

    if train_acc < 1.0:
        print("Train accuracy is less than 100%, trying again...")
        iteration += 1
    else:
        print("Reached 100% train accuracy!")
        
    # Визуализация истории потерь после достижения 100% точности
    if train_acc == 1.0:
        plt.plot(solver.loss_history, 'o')
        plt.title('Training loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Training loss')
        plt.show()
        break
# Out:
# Итерация: 1
# (Iteration 1 / 40) loss: 99.107410
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.097200
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.112600
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.104800
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.133400
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.106800
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.126000
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.142400
# (Epoch 7 / 20) train acc: 0.320000; val_acc: 0.120000
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.125000
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.146800
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.142200
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.140600
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.154600
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.136600
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.140800
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.129200
# (Epoch 16 / 20) train acc: 0.800000; val_acc: 0.132200
# (Epoch 17 / 20) train acc: 0.640000; val_acc: 0.134000
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.139000
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.139400
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.145200
# Final train accuracy after iteration 1: 0.68
# Train accuracy is less than 100%, trying again...
#
# Итерация: 2
# (Iteration 1 / 40) loss: 82.940377
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.100000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.099400
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.105800
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.095400
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.114800
# (Epoch 5 / 20) train acc: 0.280000; val_acc: 0.112400
# (Epoch 6 / 20) train acc: 0.460000; val_acc: 0.117800
# (Epoch 7 / 20) train acc: 0.500000; val_acc: 0.131200
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.135400
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.112200
# (Epoch 10 / 20) train acc: 0.500000; val_acc: 0.119800
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.135000
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.135600
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.127400
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.131200
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.131800
# (Epoch 16 / 20) train acc: 0.680000; val_acc: 0.131400
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.133200
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.137600
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.136800
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.137400
# Final train accuracy after iteration 2: 0.86
# Train accuracy is less than 100%, trying again...
#
# Итерация: 3
# (Iteration 1 / 40) loss: 67.223110
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.106600
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.085400
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.096800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.114400
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.120200
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.116000
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.116400
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.127800
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.131800
# (Epoch 10 / 20) train acc: 0.340000; val_acc: 0.127600
# (Epoch 11 / 20) train acc: 0.520000; val_acc: 0.124600
# (Epoch 12 / 20) train acc: 0.580000; val_acc: 0.132600
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.127000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.141000
# (Epoch 15 / 20) train acc: 0.660000; val_acc: 0.132600
# (Epoch 16 / 20) train acc: 0.720000; val_acc: 0.129600
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.130400
# (Epoch 18 / 20) train acc: 0.740000; val_acc: 0.135000
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.132800
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.126600
# Final train accuracy after iteration 3: 0.72
# Train accuracy is less than 100%, trying again...
#
# Итерация: 4
# (Iteration 1 / 40) loss: 87.177153
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.106400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.099400
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.092200
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.092400
# (Epoch 4 / 20) train acc: 0.200000; val_acc: 0.093400
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.101600
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.107200
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.110400
# (Epoch 8 / 20) train acc: 0.420000; val_acc: 0.102800
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.108800
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.112600
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.113400
# (Epoch 12 / 20) train acc: 0.600000; val_acc: 0.108400
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.119400
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.112200
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.113000
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.116000
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.114800
# (Epoch 18 / 20) train acc: 0.760000; val_acc: 0.119200
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.116000
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.120200
# Final train accuracy after iteration 4: 0.82
# Train accuracy is less than 100%, trying again...
#
# Итерация: 5
# (Iteration 1 / 40) loss: 88.045787
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.099000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.116800
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.118200
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.117200
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.126200
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.124000
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.130800
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.121800
# (Epoch 8 / 20) train acc: 0.420000; val_acc: 0.135800
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.140800
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.129000
# (Epoch 11 / 20) train acc: 0.560000; val_acc: 0.144400
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.141000
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.139600
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.134400
# (Epoch 15 / 20) train acc: 0.660000; val_acc: 0.137800
# (Epoch 16 / 20) train acc: 0.760000; val_acc: 0.143200
# (Epoch 17 / 20) train acc: 0.760000; val_acc: 0.138400
# (Epoch 18 / 20) train acc: 0.760000; val_acc: 0.134000
# (Epoch 19 / 20) train acc: 0.780000; val_acc: 0.142600
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.136800
# Final train accuracy after iteration 5: 0.56
# Train accuracy is less than 100%, trying again...
#
# Итерация: 6
# (Iteration 1 / 40) loss: 49.295598
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.101400
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.097800
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.099400
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.420000; val_acc: 0.108200
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.097800
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.099200
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.114600
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.109200
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.109800
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.103600
# (Epoch 12 / 20) train acc: 0.580000; val_acc: 0.102400
# (Epoch 13 / 20) train acc: 0.600000; val_acc: 0.103600
# (Epoch 14 / 20) train acc: 0.600000; val_acc: 0.103000
# (Epoch 15 / 20) train acc: 0.620000; val_acc: 0.099200
# (Epoch 16 / 20) train acc: 0.640000; val_acc: 0.104400
# (Epoch 17 / 20) train acc: 0.640000; val_acc: 0.116800
# (Epoch 18 / 20) train acc: 0.680000; val_acc: 0.109800
# (Epoch 19 / 20) train acc: 0.660000; val_acc: 0.116400
# (Epoch 20 / 20) train acc: 0.640000; val_acc: 0.109800
# Final train accuracy after iteration 6: 0.64
# Train accuracy is less than 100%, trying again...
#
# Итерация: 7
# (Iteration 1 / 40) loss: 160.800416
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.096600
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.093400
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.109800
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.130400
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.120400
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.129600
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.119000
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.122000
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.126200
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.133400
# (Epoch 10 / 20) train acc: 0.680000; val_acc: 0.132200
# (Epoch 11 / 20) train acc: 0.700000; val_acc: 0.130200
# (Epoch 12 / 20) train acc: 0.480000; val_acc: 0.130000
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.126800
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.136800
# (Epoch 15 / 20) train acc: 0.820000; val_acc: 0.138000
# (Epoch 16 / 20) train acc: 0.760000; val_acc: 0.139000
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.145400
# (Epoch 18 / 20) train acc: 0.840000; val_acc: 0.137200
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.141800
# (Epoch 20 / 20) train acc: 0.780000; val_acc: 0.149200
# Final train accuracy after iteration 7: 0.78
# Train accuracy is less than 100%, trying again...
#
# Итерация: 8
# (Iteration 1 / 40) loss: 136.571672
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.096400
# (Epoch 1 / 20) train acc: 0.040000; val_acc: 0.086800
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.136800
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.117400
# (Epoch 4 / 20) train acc: 0.360000; val_acc: 0.107600
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.122800
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.129200
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.126400
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.111000
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.123400
# (Epoch 10 / 20) train acc: 0.500000; val_acc: 0.122600
# (Epoch 11 / 20) train acc: 0.620000; val_acc: 0.113600
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.126600
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.129200
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.132600
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.122000
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.127000
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.125000
# (Epoch 18 / 20) train acc: 0.820000; val_acc: 0.127000
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.134800
# (Epoch 20 / 20) train acc: 0.780000; val_acc: 0.133800
# Final train accuracy after iteration 8: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 9
# (Iteration 1 / 40) loss: 64.214578
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.103400
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.091800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.104200
# (Epoch 4 / 20) train acc: 0.200000; val_acc: 0.110800
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.107400
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.113000
# (Epoch 7 / 20) train acc: 0.280000; val_acc: 0.111400
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.106800
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.120200
# (Epoch 10 / 20) train acc: 0.440000; val_acc: 0.107600
# (Epoch 11 / 20) train acc: 0.620000; val_acc: 0.125600
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.125000
# (Epoch 13 / 20) train acc: 0.820000; val_acc: 0.127400
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.130600
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.116400
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.125000
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.125200
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.131800
# (Epoch 19 / 20) train acc: 0.900000; val_acc: 0.133600
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.128400
# Final train accuracy after iteration 9: 0.9
# Train accuracy is less than 100%, trying again...
#
# Итерация: 10
# (Iteration 1 / 40) loss: 59.135944
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.101400
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.098800
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.102400
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.094200
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.103200
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.103400
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.112400
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.116800
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.106400
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.111000
# (Epoch 10 / 20) train acc: 0.580000; val_acc: 0.119800
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.118600
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.116000
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.119000
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.114400
# (Epoch 15 / 20) train acc: 0.800000; val_acc: 0.115400
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.133600
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.127600
# (Epoch 18 / 20) train acc: 0.720000; val_acc: 0.120400
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.124600
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.133000
# Final train accuracy after iteration 10: 0.78
# Train accuracy is less than 100%, trying again...
#
# Итерация: 11
# (Iteration 1 / 40) loss: 49.153090
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.103400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.116600
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.122400
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.125600
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.116000
# (Epoch 5 / 20) train acc: 0.360000; val_acc: 0.124000
# (Epoch 6 / 20) train acc: 0.460000; val_acc: 0.122200
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.125000
# (Epoch 8 / 20) train acc: 0.560000; val_acc: 0.119800
# (Epoch 9 / 20) train acc: 0.620000; val_acc: 0.125400
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.124400
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.128600
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.124600
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.120000
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.114400
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.118000
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.123600
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.130200
# (Epoch 18 / 20) train acc: 0.740000; val_acc: 0.123800
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.127000
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.126800
# Final train accuracy after iteration 11: 0.78
# Train accuracy is less than 100%, trying again...
#
# Итерация: 12
# (Iteration 1 / 40) loss: 81.158406
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102400
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.100800
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.113200
# (Epoch 3 / 20) train acc: 0.040000; val_acc: 0.094000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.116200
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.127600
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.138200
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.141800
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.149200
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.137800
# (Epoch 10 / 20) train acc: 0.660000; val_acc: 0.151600
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.145200
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.158600
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.153600
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.156000
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.156800
# (Epoch 16 / 20) train acc: 0.680000; val_acc: 0.156200
# (Epoch 17 / 20) train acc: 0.720000; val_acc: 0.153800
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.156600
# (Epoch 19 / 20) train acc: 0.740000; val_acc: 0.166200
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.154800
# Final train accuracy after iteration 12: 0.74
# Train accuracy is less than 100%, trying again...
#
# Итерация: 13
# (Iteration 1 / 40) loss: 98.601564
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.102800
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.100400
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.100200
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.127800
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.138600
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.136400
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.115400
# (Epoch 7 / 20) train acc: 0.480000; val_acc: 0.150400
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.152800
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.138000
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.147400
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.140600
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.138200
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.145200
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.139600
# (Epoch 15 / 20) train acc: 0.800000; val_acc: 0.138200
# (Epoch 16 / 20) train acc: 0.800000; val_acc: 0.138800
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.140200
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.140000
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.142000
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.142200
# Final train accuracy after iteration 13: 0.54
# Train accuracy is less than 100%, trying again...
#
# Итерация: 14
# (Iteration 1 / 40) loss: 65.725412
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.080000; val_acc: 0.103600
# (Epoch 2 / 20) train acc: 0.240000; val_acc: 0.127800
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.093400
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.134400
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.130400
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.120400
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.129200
# (Epoch 9 / 20) train acc: 0.480000; val_acc: 0.130200
# (Epoch 10 / 20) train acc: 0.560000; val_acc: 0.130800
# (Epoch 11 / 20) train acc: 0.620000; val_acc: 0.133000
# (Epoch 12 / 20) train acc: 0.580000; val_acc: 0.129000
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.133200
# (Epoch 14 / 20) train acc: 0.600000; val_acc: 0.133600
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.134600
# (Epoch 16 / 20) train acc: 0.720000; val_acc: 0.133200
# (Epoch 17 / 20) train acc: 0.680000; val_acc: 0.133200
# (Epoch 18 / 20) train acc: 0.700000; val_acc: 0.136800
# (Epoch 19 / 20) train acc: 0.740000; val_acc: 0.135600
# (Epoch 20 / 20) train acc: 0.700000; val_acc: 0.135200
# Final train accuracy after iteration 14: 0.7
# Train accuracy is less than 100%, trying again...
#
# Итерация: 15
# (Iteration 1 / 40) loss: 49.363618
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.101800
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.094800
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.102800
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.115400
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.112600
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.117000
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.125000
# (Epoch 9 / 20) train acc: 0.480000; val_acc: 0.123200
# (Epoch 10 / 20) train acc: 0.500000; val_acc: 0.119200
# (Epoch 11 / 20) train acc: 0.500000; val_acc: 0.125600
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.125800
# (Epoch 13 / 20) train acc: 0.620000; val_acc: 0.127400
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.126000
# (Epoch 15 / 20) train acc: 0.680000; val_acc: 0.125800
# (Epoch 16 / 20) train acc: 0.660000; val_acc: 0.126400
# (Epoch 17 / 20) train acc: 0.660000; val_acc: 0.129200
# (Epoch 18 / 20) train acc: 0.640000; val_acc: 0.126600
# (Epoch 19 / 20) train acc: 0.700000; val_acc: 0.130800
# (Epoch 20 / 20) train acc: 0.640000; val_acc: 0.129200
# Final train accuracy after iteration 15: 0.7
# Train accuracy is less than 100%, trying again...
#
# Итерация: 16
# (Iteration 1 / 40) loss: 103.770876
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.102400
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.101000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.080400
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.113600
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.103800
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.111400
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.120200
# (Epoch 7 / 20) train acc: 0.360000; val_acc: 0.140400
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.124200
# (Epoch 9 / 20) train acc: 0.460000; val_acc: 0.132200
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.154400
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.141000
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.139400
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.147000
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.141200
# (Epoch 15 / 20) train acc: 0.740000; val_acc: 0.140400
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.143400
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.141400
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.145200
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.138200
# (Epoch 20 / 20) train acc: 0.780000; val_acc: 0.136200
# Final train accuracy after iteration 16: 0.54
# Train accuracy is less than 100%, trying again...
#
# Итерация: 17
# (Iteration 1 / 40) loss: 54.506100
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.102600
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.106000
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.116800
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.116200
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.118400
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.129400
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.123600
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.124600
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.133800
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.133000
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.130000
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.136200
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.132400
# (Epoch 14 / 20) train acc: 0.660000; val_acc: 0.127200
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.134200
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.136200
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.135000
# (Epoch 18 / 20) train acc: 0.820000; val_acc: 0.137600
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.140400
# (Epoch 20 / 20) train acc: 0.800000; val_acc: 0.144800
# Final train accuracy after iteration 17: 0.8
# Train accuracy is less than 100%, trying again...
#
# Итерация: 18
# (Iteration 1 / 40) loss: 97.038957
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.095400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.100800
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.101200
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.104600
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.116800
# (Epoch 6 / 20) train acc: 0.420000; val_acc: 0.121600
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.117400
# (Epoch 8 / 20) train acc: 0.560000; val_acc: 0.127400
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.124200
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.126000
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.122400
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.127600
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.121600
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.131400
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.125600
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.124600
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.136800
# (Epoch 18 / 20) train acc: 0.820000; val_acc: 0.130000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.131400
# (Epoch 20 / 20) train acc: 0.760000; val_acc: 0.123400
# Final train accuracy after iteration 18: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 19
# (Iteration 1 / 40) loss: 47.852652
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.096800
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.076800
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.102200
# (Epoch 4 / 20) train acc: 0.360000; val_acc: 0.111800
# (Epoch 5 / 20) train acc: 0.280000; val_acc: 0.111400
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.360000; val_acc: 0.120200
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.143000
# (Epoch 9 / 20) train acc: 0.460000; val_acc: 0.140400
# (Epoch 10 / 20) train acc: 0.600000; val_acc: 0.128400
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.139400
# (Epoch 12 / 20) train acc: 0.740000; val_acc: 0.133600
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.141200
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.137000
# (Epoch 15 / 20) train acc: 0.780000; val_acc: 0.135800
# (Epoch 16 / 20) train acc: 0.840000; val_acc: 0.134600
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.139000
# (Epoch 18 / 20) train acc: 0.900000; val_acc: 0.135400
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.138800
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.136000
# Final train accuracy after iteration 19: 0.46
# Train accuracy is less than 100%, trying again...
#
# Итерация: 20
# (Iteration 1 / 40) loss: 65.924835
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.093800
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.098400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.119000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.116600
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.134600
# (Epoch 5 / 20) train acc: 0.280000; val_acc: 0.125800
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.128000
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.109200
# (Epoch 8 / 20) train acc: 0.600000; val_acc: 0.117000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.126400
# (Epoch 10 / 20) train acc: 0.740000; val_acc: 0.116800
# (Epoch 11 / 20) train acc: 0.780000; val_acc: 0.116400
# (Epoch 12 / 20) train acc: 0.820000; val_acc: 0.116200
# (Epoch 13 / 20) train acc: 0.860000; val_acc: 0.122200
# (Epoch 14 / 20) train acc: 0.900000; val_acc: 0.127000
# (Epoch 15 / 20) train acc: 0.920000; val_acc: 0.117800
# (Epoch 16 / 20) train acc: 0.920000; val_acc: 0.116600
# (Epoch 17 / 20) train acc: 0.940000; val_acc: 0.125400
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.117600
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.123800
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.122400
# Final train accuracy after iteration 20: 0.26
# Train accuracy is less than 100%, trying again...
#
# Итерация: 21
# (Iteration 1 / 40) loss: 92.565138
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.098400
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.096800
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.096600
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.127200
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.123200
# (Epoch 5 / 20) train acc: 0.360000; val_acc: 0.115000
# (Epoch 6 / 20) train acc: 0.420000; val_acc: 0.117000
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.117400
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.125800
# (Epoch 9 / 20) train acc: 0.340000; val_acc: 0.140000
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.121800
# (Epoch 11 / 20) train acc: 0.620000; val_acc: 0.127400
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.132600
# (Epoch 13 / 20) train acc: 0.600000; val_acc: 0.127600
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.141200
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.141400
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.138000
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.143800
# (Epoch 18 / 20) train acc: 0.820000; val_acc: 0.139800
# (Epoch 19 / 20) train acc: 0.800000; val_acc: 0.133400
# (Epoch 20 / 20) train acc: 0.840000; val_acc: 0.136400
# Final train accuracy after iteration 21: 0.78
# Train accuracy is less than 100%, trying again...
#
# Итерация: 22
# (Iteration 1 / 40) loss: 88.272184
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.100400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.101000
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.117200
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.126000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.116200
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.113000
# (Epoch 7 / 20) train acc: 0.280000; val_acc: 0.117600
# (Epoch 8 / 20) train acc: 0.280000; val_acc: 0.107000
# (Epoch 9 / 20) train acc: 0.260000; val_acc: 0.108600
# (Epoch 10 / 20) train acc: 0.340000; val_acc: 0.117200
# (Epoch 11 / 20) train acc: 0.420000; val_acc: 0.120600
# (Epoch 12 / 20) train acc: 0.440000; val_acc: 0.119200
# (Epoch 13 / 20) train acc: 0.440000; val_acc: 0.119400
# (Epoch 14 / 20) train acc: 0.460000; val_acc: 0.119200
# (Epoch 15 / 20) train acc: 0.460000; val_acc: 0.118600
# (Epoch 16 / 20) train acc: 0.440000; val_acc: 0.117800
# (Epoch 17 / 20) train acc: 0.460000; val_acc: 0.120200
# (Epoch 18 / 20) train acc: 0.480000; val_acc: 0.123000
# (Epoch 19 / 20) train acc: 0.500000; val_acc: 0.121200
# (Epoch 20 / 20) train acc: 0.500000; val_acc: 0.121200
# Final train accuracy after iteration 22: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 23
# (Iteration 1 / 40) loss: 114.919294
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.101800
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.101400
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.102600
# (Epoch 3 / 20) train acc: 0.300000; val_acc: 0.111800
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.118000
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.124000
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.128000
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.139000
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.140000
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.127600
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.140800
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.135000
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.134000
# (Epoch 13 / 20) train acc: 0.780000; val_acc: 0.135800
# (Epoch 14 / 20) train acc: 0.680000; val_acc: 0.140400
# (Epoch 15 / 20) train acc: 0.460000; val_acc: 0.121800
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.139200
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.130600
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.128600
# (Epoch 19 / 20) train acc: 0.840000; val_acc: 0.141600
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.136800
# Final train accuracy after iteration 23: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 24
# (Iteration 1 / 40) loss: 40.168580
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.105400
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.133200
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.133200
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.099800
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.106200
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.104400
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.125800
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.121800
# (Epoch 8 / 20) train acc: 0.400000; val_acc: 0.131800
# (Epoch 9 / 20) train acc: 0.480000; val_acc: 0.125800
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.128800
# (Epoch 11 / 20) train acc: 0.560000; val_acc: 0.130400
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.127400
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.129400
# (Epoch 14 / 20) train acc: 0.640000; val_acc: 0.129800
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.128000
# (Epoch 16 / 20) train acc: 0.700000; val_acc: 0.129200
# (Epoch 17 / 20) train acc: 0.740000; val_acc: 0.131800
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.136400
# (Epoch 19 / 20) train acc: 0.740000; val_acc: 0.139200
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.135200
# Final train accuracy after iteration 24: 0.74
# Train accuracy is less than 100%, trying again...
#
# Итерация: 25
# (Iteration 1 / 40) loss: 122.707776
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.116000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.100600
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.101600
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.098000
# (Epoch 4 / 20) train acc: 0.340000; val_acc: 0.103600
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.127600
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.123200
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.117600
# (Epoch 8 / 20) train acc: 0.560000; val_acc: 0.131800
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.125600
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.139000
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.126000
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.133800
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.129800
# (Epoch 14 / 20) train acc: 0.680000; val_acc: 0.138600
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.139600
# (Epoch 16 / 20) train acc: 0.840000; val_acc: 0.135600
# (Epoch 17 / 20) train acc: 0.860000; val_acc: 0.129800
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.133400
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.131000
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.133200
# Final train accuracy after iteration 25: 0.72
# Train accuracy is less than 100%, trying again...
#
# Итерация: 26
# (Iteration 1 / 40) loss: 49.717931
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.107800
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.106600
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.112600
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.129400
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.118600
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.116800
# (Epoch 8 / 20) train acc: 0.380000; val_acc: 0.126200
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.133400
# (Epoch 10 / 20) train acc: 0.500000; val_acc: 0.131200
# (Epoch 11 / 20) train acc: 0.560000; val_acc: 0.124400
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.120400
# (Epoch 13 / 20) train acc: 0.760000; val_acc: 0.121200
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.123000
# (Epoch 15 / 20) train acc: 0.820000; val_acc: 0.127400
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.120400
# (Epoch 17 / 20) train acc: 0.700000; val_acc: 0.117000
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.129200
# (Epoch 19 / 20) train acc: 0.760000; val_acc: 0.123600
# (Epoch 20 / 20) train acc: 0.740000; val_acc: 0.129600
# Final train accuracy after iteration 26: 0.52
# Train accuracy is less than 100%, trying again...
#
# Итерация: 27
# (Iteration 1 / 40) loss: 81.306577
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.101400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.107600
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.103800
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.132400
# (Epoch 5 / 20) train acc: 0.360000; val_acc: 0.113000
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.115200
# (Epoch 7 / 20) train acc: 0.320000; val_acc: 0.111000
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.111200
# (Epoch 9 / 20) train acc: 0.420000; val_acc: 0.113400
# (Epoch 10 / 20) train acc: 0.420000; val_acc: 0.110400
# (Epoch 11 / 20) train acc: 0.500000; val_acc: 0.113000
# (Epoch 12 / 20) train acc: 0.480000; val_acc: 0.115600
# (Epoch 13 / 20) train acc: 0.480000; val_acc: 0.114400
# (Epoch 14 / 20) train acc: 0.520000; val_acc: 0.114000
# (Epoch 15 / 20) train acc: 0.560000; val_acc: 0.118000
# (Epoch 16 / 20) train acc: 0.580000; val_acc: 0.118600
# (Epoch 17 / 20) train acc: 0.600000; val_acc: 0.122600
# (Epoch 18 / 20) train acc: 0.640000; val_acc: 0.118200
# (Epoch 19 / 20) train acc: 0.640000; val_acc: 0.121200
# (Epoch 20 / 20) train acc: 0.640000; val_acc: 0.118200
# Final train accuracy after iteration 27: 0.26
# Train accuracy is less than 100%, trying again...
#
# Итерация: 28
# (Iteration 1 / 40) loss: 57.401286
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.097800
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.096400
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.093800
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.106000
# (Epoch 4 / 20) train acc: 0.200000; val_acc: 0.106000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.109200
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.118600
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.123400
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.137200
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.131000
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.141000
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.118800
# (Epoch 12 / 20) train acc: 0.600000; val_acc: 0.116200
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.143600
# (Epoch 14 / 20) train acc: 0.660000; val_acc: 0.144600
# (Epoch 15 / 20) train acc: 0.740000; val_acc: 0.127000
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.123400
# (Epoch 17 / 20) train acc: 0.660000; val_acc: 0.148600
# (Epoch 18 / 20) train acc: 0.700000; val_acc: 0.143200
# (Epoch 19 / 20) train acc: 0.720000; val_acc: 0.129000
# (Epoch 20 / 20) train acc: 0.740000; val_acc: 0.130600
# Final train accuracy after iteration 28: 0.66
# Train accuracy is less than 100%, trying again...
#
# Итерация: 29
# (Iteration 1 / 40) loss: 65.453746
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.118400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.111800
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.108800
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.130200
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.109200
# (Epoch 6 / 20) train acc: 0.420000; val_acc: 0.092600
# (Epoch 7 / 20) train acc: 0.480000; val_acc: 0.123600
# (Epoch 8 / 20) train acc: 0.560000; val_acc: 0.116000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.124400
# (Epoch 10 / 20) train acc: 0.420000; val_acc: 0.119000
# (Epoch 11 / 20) train acc: 0.500000; val_acc: 0.115400
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.124200
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.115800
# (Epoch 14 / 20) train acc: 0.820000; val_acc: 0.117000
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.119600
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.119200
# (Epoch 17 / 20) train acc: 0.860000; val_acc: 0.117200
# (Epoch 18 / 20) train acc: 0.900000; val_acc: 0.124000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.115400
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.123200
# Final train accuracy after iteration 29: 0.24
# Train accuracy is less than 100%, trying again...
#
# Итерация: 30
# (Iteration 1 / 40) loss: 50.966080
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.101000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.105800
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.105200
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.115400
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.105800
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.101600
# (Epoch 7 / 20) train acc: 0.260000; val_acc: 0.102000
# (Epoch 8 / 20) train acc: 0.340000; val_acc: 0.100200
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.103800
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.109200
# (Epoch 11 / 20) train acc: 0.440000; val_acc: 0.106000
# (Epoch 12 / 20) train acc: 0.520000; val_acc: 0.115000
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.112600
# (Epoch 14 / 20) train acc: 0.540000; val_acc: 0.116200
# (Epoch 15 / 20) train acc: 0.660000; val_acc: 0.123400
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.114200
# (Epoch 17 / 20) train acc: 0.780000; val_acc: 0.118200
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.114200
# (Epoch 19 / 20) train acc: 0.740000; val_acc: 0.111800
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.107600
# Final train accuracy after iteration 30: 0.66
# Train accuracy is less than 100%, trying again...
#
# Итерация: 31
# (Iteration 1 / 40) loss: 31.634363
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.093400
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.097200
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.099200
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.095000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.121800
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.119400
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.112800
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.113600
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.111600
# (Epoch 9 / 20) train acc: 0.560000; val_acc: 0.124800
# (Epoch 10 / 20) train acc: 0.560000; val_acc: 0.120000
# (Epoch 11 / 20) train acc: 0.580000; val_acc: 0.132800
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.128200
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.138400
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.127800
# (Epoch 15 / 20) train acc: 0.580000; val_acc: 0.120800
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.131000
# (Epoch 17 / 20) train acc: 0.740000; val_acc: 0.126200
# (Epoch 18 / 20) train acc: 0.740000; val_acc: 0.131400
# (Epoch 19 / 20) train acc: 0.780000; val_acc: 0.128800
# (Epoch 20 / 20) train acc: 0.760000; val_acc: 0.129200
# Final train accuracy after iteration 31: 0.66
# Train accuracy is less than 100%, trying again...
#
# Итерация: 32
# (Iteration 1 / 40) loss: 71.128487
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.104000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.125600
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.080400
# (Epoch 3 / 20) train acc: 0.040000; val_acc: 0.089600
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.116200
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.109400
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.132800
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.133600
# (Epoch 8 / 20) train acc: 0.400000; val_acc: 0.129200
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.141000
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.139400
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.138000
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.136800
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.138400
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.134200
# (Epoch 15 / 20) train acc: 0.860000; val_acc: 0.134600
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.133000
# (Epoch 17 / 20) train acc: 0.940000; val_acc: 0.138000
# (Epoch 18 / 20) train acc: 0.900000; val_acc: 0.141000
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.141000
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.137600
# Final train accuracy after iteration 32: 0.52
# Train accuracy is less than 100%, trying again...
#
# Итерация: 33
# (Iteration 1 / 40) loss: 106.514796
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.097200
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.105600
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.099800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.110400
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.092600
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.104800
# (Epoch 7 / 20) train acc: 0.300000; val_acc: 0.120000
# (Epoch 8 / 20) train acc: 0.340000; val_acc: 0.110800
# (Epoch 9 / 20) train acc: 0.320000; val_acc: 0.102000
# (Epoch 10 / 20) train acc: 0.400000; val_acc: 0.114200
# (Epoch 11 / 20) train acc: 0.460000; val_acc: 0.119400
# (Epoch 12 / 20) train acc: 0.440000; val_acc: 0.118800
# (Epoch 13 / 20) train acc: 0.500000; val_acc: 0.123400
# (Epoch 14 / 20) train acc: 0.520000; val_acc: 0.128400
# (Epoch 15 / 20) train acc: 0.560000; val_acc: 0.122400
# (Epoch 16 / 20) train acc: 0.600000; val_acc: 0.124800
# (Epoch 17 / 20) train acc: 0.580000; val_acc: 0.126000
# (Epoch 18 / 20) train acc: 0.640000; val_acc: 0.130200
# (Epoch 19 / 20) train acc: 0.660000; val_acc: 0.127800
# (Epoch 20 / 20) train acc: 0.640000; val_acc: 0.124600
# Final train accuracy after iteration 33: 0.64
# Train accuracy is less than 100%, trying again...
#
# Итерация: 34
# (Iteration 1 / 40) loss: 72.147875
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.119400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.131000
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.129800
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.133800
# (Epoch 7 / 20) train acc: 0.360000; val_acc: 0.142400
# (Epoch 8 / 20) train acc: 0.320000; val_acc: 0.144600
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.148400
# (Epoch 10 / 20) train acc: 0.440000; val_acc: 0.147000
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.148600
# (Epoch 12 / 20) train acc: 0.520000; val_acc: 0.148400
# (Epoch 13 / 20) train acc: 0.480000; val_acc: 0.148000
# (Epoch 14 / 20) train acc: 0.480000; val_acc: 0.150800
# (Epoch 15 / 20) train acc: 0.560000; val_acc: 0.149600
# (Epoch 16 / 20) train acc: 0.560000; val_acc: 0.151800
# (Epoch 17 / 20) train acc: 0.580000; val_acc: 0.149200
# (Epoch 18 / 20) train acc: 0.620000; val_acc: 0.146600
# (Epoch 19 / 20) train acc: 0.620000; val_acc: 0.144200
# (Epoch 20 / 20) train acc: 0.620000; val_acc: 0.144800
# Final train accuracy after iteration 34: 0.56
# Train accuracy is less than 100%, trying again...
#
# Итерация: 35
# (Iteration 1 / 40) loss: 103.013140
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.095800
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.108000
# (Epoch 2 / 20) train acc: 0.220000; val_acc: 0.118400
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.121000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.108200
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.113200
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.135200
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.116000
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.113800
# (Epoch 9 / 20) train acc: 0.480000; val_acc: 0.109800
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.112000
# (Epoch 11 / 20) train acc: 0.580000; val_acc: 0.120400
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.129400
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.111400
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.118400
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.116600
# (Epoch 17 / 20) train acc: 0.660000; val_acc: 0.126400
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.134000
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.780000; val_acc: 0.119600
# Final train accuracy after iteration 35: 0.4
# Train accuracy is less than 100%, trying again...
#
# Итерация: 36
# (Iteration 1 / 40) loss: 119.476367
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.106800
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.106200
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.119000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.104600
# (Epoch 6 / 20) train acc: 0.240000; val_acc: 0.112600
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.114400
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.121400
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.125000
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.114800
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.114800
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.128200
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.125000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.121800
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.128400
# (Epoch 16 / 20) train acc: 0.720000; val_acc: 0.123200
# (Epoch 17 / 20) train acc: 0.720000; val_acc: 0.130800
# (Epoch 18 / 20) train acc: 0.740000; val_acc: 0.128400
# (Epoch 19 / 20) train acc: 0.740000; val_acc: 0.134000
# (Epoch 20 / 20) train acc: 0.760000; val_acc: 0.128400
# Final train accuracy after iteration 36: 0.74
# Train accuracy is less than 100%, trying again...
#
# Итерация: 37
# (Iteration 1 / 40) loss: 55.788810
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.102600
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.086400
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.111000
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.120600
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.137000
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.125400
# (Epoch 7 / 20) train acc: 0.260000; val_acc: 0.117000
# (Epoch 8 / 20) train acc: 0.240000; val_acc: 0.120800
# (Epoch 9 / 20) train acc: 0.340000; val_acc: 0.115800
# (Epoch 10 / 20) train acc: 0.300000; val_acc: 0.119800
# (Epoch 11 / 20) train acc: 0.420000; val_acc: 0.123200
# (Epoch 12 / 20) train acc: 0.480000; val_acc: 0.125600
# (Epoch 13 / 20) train acc: 0.500000; val_acc: 0.129200
# (Epoch 14 / 20) train acc: 0.500000; val_acc: 0.133000
# (Epoch 15 / 20) train acc: 0.600000; val_acc: 0.135000
# (Epoch 16 / 20) train acc: 0.540000; val_acc: 0.146600
# (Epoch 17 / 20) train acc: 0.560000; val_acc: 0.138200
# (Epoch 18 / 20) train acc: 0.600000; val_acc: 0.143600
# (Epoch 19 / 20) train acc: 0.620000; val_acc: 0.142800
# (Epoch 20 / 20) train acc: 0.680000; val_acc: 0.141200
# Final train accuracy after iteration 37: 0.54
# Train accuracy is less than 100%, trying again...
#
# Итерация: 38
# (Iteration 1 / 40) loss: 62.581378
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.111200
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.100000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.101800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.099000
# ...
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.127400
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.138600
# (Epoch 16 / 20) train acc: 0.800000; val_acc: 0.122600
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.131800
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.136800
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.129400
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.125400
# Final train accuracy after iteration 202: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 203
# (Iteration 1 / 40) loss: 64.666091
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.097800
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.103800
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.103800
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.125400
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.141000
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.118000
# (Epoch 6 / 20) train acc: 0.240000; val_acc: 0.126800
# (Epoch 7 / 20) train acc: 0.480000; val_acc: 0.127600
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.142400
# (Epoch 9 / 20) train acc: 0.680000; val_acc: 0.140200
# (Epoch 10 / 20) train acc: 0.560000; val_acc: 0.133800
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.134200
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.139800
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.139000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.136000
# (Epoch 15 / 20) train acc: 0.640000; val_acc: 0.129400
# (Epoch 16 / 20) train acc: 0.720000; val_acc: 0.143600
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.152600
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.137000
# (Epoch 19 / 20) train acc: 0.800000; val_acc: 0.141200
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.141200
# Final train accuracy after iteration 203: 0.82
# Train accuracy is less than 100%, trying again...
#
# Итерация: 204
# (Iteration 1 / 40) loss: 60.414835
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.093600
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.122400
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.125600
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.135200
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.128600
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.128000
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.131000
# (Epoch 10 / 20) train acc: 0.580000; val_acc: 0.132000
# (Epoch 11 / 20) train acc: 0.700000; val_acc: 0.129200
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.138000
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.144000
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.143200
# (Epoch 15 / 20) train acc: 0.620000; val_acc: 0.120400
# (Epoch 16 / 20) train acc: 0.700000; val_acc: 0.132600
# (Epoch 17 / 20) train acc: 0.920000; val_acc: 0.142000
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.141000
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.139400
# (Epoch 20 / 20) train acc: 0.960000; val_acc: 0.142000
# Final train accuracy after iteration 204: 0.8
# Train accuracy is less than 100%, trying again...
#
# Итерация: 205
# (Iteration 1 / 40) loss: 66.018787
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.101800
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.109600
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.114000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.110800
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.107400
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.099800
# (Epoch 7 / 20) train acc: 0.480000; val_acc: 0.101600
# (Epoch 8 / 20) train acc: 0.560000; val_acc: 0.109600
# (Epoch 9 / 20) train acc: 0.660000; val_acc: 0.103800
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.106200
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.110200
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.117800
# (Epoch 13 / 20) train acc: 0.560000; val_acc: 0.111000
# (Epoch 14 / 20) train acc: 0.660000; val_acc: 0.112200
# (Epoch 15 / 20) train acc: 0.740000; val_acc: 0.117800
# (Epoch 16 / 20) train acc: 0.680000; val_acc: 0.114200
# (Epoch 17 / 20) train acc: 0.760000; val_acc: 0.112800
# (Epoch 18 / 20) train acc: 0.760000; val_acc: 0.114000
# (Epoch 19 / 20) train acc: 0.760000; val_acc: 0.124800
# (Epoch 20 / 20) train acc: 0.780000; val_acc: 0.119600
# Final train accuracy after iteration 205: 0.76
# Train accuracy is less than 100%, trying again...
#
# Итерация: 206
# (Iteration 1 / 40) loss: 46.598063
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.113400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.142600
# (Epoch 2 / 20) train acc: 0.080000; val_acc: 0.102400
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.116000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.110200
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.141400
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.100800
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.132600
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.132400
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.132800
# (Epoch 10 / 20) train acc: 0.560000; val_acc: 0.133400
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.139400
# (Epoch 12 / 20) train acc: 0.560000; val_acc: 0.140600
# (Epoch 13 / 20) train acc: 0.620000; val_acc: 0.132800
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.137000
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.129800
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.141600
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.133400
# (Epoch 18 / 20) train acc: 0.840000; val_acc: 0.140400
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.137400
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.139000
# Final train accuracy after iteration 206: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 207
# (Iteration 1 / 40) loss: 92.203286
# (Epoch 0 / 20) train acc: 0.080000; val_acc: 0.094400
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.095200
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.091400
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.117200
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.107200
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.108400
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.127200
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.118800
# (Epoch 8 / 20) train acc: 0.380000; val_acc: 0.117200
# (Epoch 9 / 20) train acc: 0.400000; val_acc: 0.116000
# (Epoch 10 / 20) train acc: 0.300000; val_acc: 0.127000
# (Epoch 11 / 20) train acc: 0.420000; val_acc: 0.133600
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.135800
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.128200
# (Epoch 14 / 20) train acc: 0.500000; val_acc: 0.137200
# (Epoch 15 / 20) train acc: 0.620000; val_acc: 0.127000
# (Epoch 16 / 20) train acc: 0.440000; val_acc: 0.123400
# (Epoch 17 / 20) train acc: 0.680000; val_acc: 0.141600
# (Epoch 18 / 20) train acc: 0.760000; val_acc: 0.145800
# (Epoch 19 / 20) train acc: 0.580000; val_acc: 0.136200
# (Epoch 20 / 20) train acc: 0.800000; val_acc: 0.145600
# Final train accuracy after iteration 207: 0.76
# Train accuracy is less than 100%, trying again...
#
# Итерация: 208
# (Iteration 1 / 40) loss: 70.859333
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.117800
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.080000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.094400
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.120600
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.123200
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.122400
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.120400
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.134800
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.142200
# (Epoch 10 / 20) train acc: 0.660000; val_acc: 0.141400
# (Epoch 11 / 20) train acc: 0.700000; val_acc: 0.143600
# (Epoch 12 / 20) train acc: 0.740000; val_acc: 0.131200
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.137000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.136800
# (Epoch 15 / 20) train acc: 0.780000; val_acc: 0.139200
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.137800
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.138800
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.139000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.139200
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.136800
# Final train accuracy after iteration 208: 0.7
# Train accuracy is less than 100%, trying again...
#
# Итерация: 209
# (Iteration 1 / 40) loss: 37.913539
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.099600
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.122400
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.103400
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.100200
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.112000
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.141200
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.127600
# (Epoch 8 / 20) train acc: 0.420000; val_acc: 0.125800
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.121800
# (Epoch 10 / 20) train acc: 0.580000; val_acc: 0.124000
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.126200
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.126200
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.123800
# (Epoch 14 / 20) train acc: 0.680000; val_acc: 0.130600
# (Epoch 15 / 20) train acc: 0.600000; val_acc: 0.126000
# (Epoch 16 / 20) train acc: 0.720000; val_acc: 0.130000
# (Epoch 17 / 20) train acc: 0.740000; val_acc: 0.129000
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.134400
# (Epoch 19 / 20) train acc: 0.820000; val_acc: 0.132600
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.127400
# Final train accuracy after iteration 209: 0.38
# Train accuracy is less than 100%, trying again...
#
# Итерация: 210
# (Iteration 1 / 40) loss: 48.631146
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.125200
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.095000
# (Epoch 2 / 20) train acc: 0.280000; val_acc: 0.115600
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.138400
# (Epoch 4 / 20) train acc: 0.500000; val_acc: 0.140600
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.142600
# (Epoch 6 / 20) train acc: 0.540000; val_acc: 0.149400
# (Epoch 7 / 20) train acc: 0.580000; val_acc: 0.148600
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.132800
# (Epoch 9 / 20) train acc: 0.760000; val_acc: 0.136200
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.143600
# (Epoch 11 / 20) train acc: 0.800000; val_acc: 0.138800
# (Epoch 12 / 20) train acc: 0.820000; val_acc: 0.139600
# (Epoch 13 / 20) train acc: 0.820000; val_acc: 0.143800
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.132400
# (Epoch 15 / 20) train acc: 0.640000; val_acc: 0.138600
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.140800
# (Epoch 17 / 20) train acc: 0.920000; val_acc: 0.139400
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.142400
# (Epoch 19 / 20) train acc: 0.960000; val_acc: 0.147800
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.145800
# Final train accuracy after iteration 210: 0.54
# Train accuracy is less than 100%, trying again...
#
# Итерация: 211
# (Iteration 1 / 40) loss: 58.051772
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.113400
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.101600
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.116800
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.088600
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.122600
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.113400
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.106800
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.105000
# (Epoch 9 / 20) train acc: 0.440000; val_acc: 0.109000
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.112000
# (Epoch 11 / 20) train acc: 0.500000; val_acc: 0.112600
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.111600
# (Epoch 13 / 20) train acc: 0.500000; val_acc: 0.110600
# (Epoch 14 / 20) train acc: 0.520000; val_acc: 0.103000
# (Epoch 15 / 20) train acc: 0.520000; val_acc: 0.111400
# (Epoch 16 / 20) train acc: 0.520000; val_acc: 0.109000
# (Epoch 17 / 20) train acc: 0.520000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.500000; val_acc: 0.109000
# (Epoch 19 / 20) train acc: 0.540000; val_acc: 0.108600
# (Epoch 20 / 20) train acc: 0.540000; val_acc: 0.108400
# Final train accuracy after iteration 211: 0.22
# Train accuracy is less than 100%, trying again...
#
# Итерация: 212
# (Iteration 1 / 40) loss: 71.779414
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102800
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.104200
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.098800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.102800
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.092000
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.106000
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.097800
# (Epoch 7 / 20) train acc: 0.300000; val_acc: 0.100800
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.109400
# (Epoch 9 / 20) train acc: 0.540000; val_acc: 0.110400
# (Epoch 10 / 20) train acc: 0.440000; val_acc: 0.122600
# (Epoch 11 / 20) train acc: 0.540000; val_acc: 0.126000
# (Epoch 12 / 20) train acc: 0.760000; val_acc: 0.113000
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.117800
# (Epoch 14 / 20) train acc: 0.780000; val_acc: 0.119400
# (Epoch 15 / 20) train acc: 0.820000; val_acc: 0.117400
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.111400
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.118800
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.110800
# (Epoch 19 / 20) train acc: 0.900000; val_acc: 0.115400
# (Epoch 20 / 20) train acc: 0.680000; val_acc: 0.106000
# Final train accuracy after iteration 212: 0.54
# Train accuracy is less than 100%, trying again...
#
# Итерация: 213
# (Iteration 1 / 40) loss: 44.165510
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.120800
# (Epoch 1 / 20) train acc: 0.220000; val_acc: 0.130600
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.116400
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.097600
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.121200
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.108800
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.113800
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.117400
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.119200
# (Epoch 9 / 20) train acc: 0.600000; val_acc: 0.117200
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.129600
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.134800
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.125800
# (Epoch 13 / 20) train acc: 0.760000; val_acc: 0.134000
# (Epoch 14 / 20) train acc: 0.760000; val_acc: 0.128400
# (Epoch 15 / 20) train acc: 0.780000; val_acc: 0.136000
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.128000
# (Epoch 17 / 20) train acc: 0.760000; val_acc: 0.132200
# (Epoch 18 / 20) train acc: 0.780000; val_acc: 0.132200
# (Epoch 19 / 20) train acc: 0.780000; val_acc: 0.126200
# (Epoch 20 / 20) train acc: 0.820000; val_acc: 0.138000
# Final train accuracy after iteration 213: 0.82
# Train accuracy is less than 100%, trying again...
#
# Итерация: 214
# (Iteration 1 / 40) loss: 91.738169
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.096200
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.109600
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.131000
# (Epoch 3 / 20) train acc: 0.220000; val_acc: 0.128000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.104600
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.130200
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.131000
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.121200
# (Epoch 8 / 20) train acc: 0.420000; val_acc: 0.136200
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.134000
# (Epoch 10 / 20) train acc: 0.700000; val_acc: 0.127400
# (Epoch 11 / 20) train acc: 0.780000; val_acc: 0.127800
# (Epoch 12 / 20) train acc: 0.560000; val_acc: 0.126800
# (Epoch 13 / 20) train acc: 0.600000; val_acc: 0.135400
# (Epoch 14 / 20) train acc: 0.820000; val_acc: 0.131600
# (Epoch 15 / 20) train acc: 0.920000; val_acc: 0.139400
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.137600
# (Epoch 17 / 20) train acc: 0.940000; val_acc: 0.140200
# (Epoch 18 / 20) train acc: 0.960000; val_acc: 0.139400
# (Epoch 19 / 20) train acc: 0.980000; val_acc: 0.139200
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.142000
# Final train accuracy after iteration 214: 1.0
# Reached 100% train accuracy!

# %% [markdown]
# Повторите эксперимент, описанный выше, для пятислойной сети.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

# Предполагается, что данные CIFAR-10 уже загружены в переменную data
num_train = 50
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

weight_scale = 6e-2   # Обновленный масштаб веса
learning_rate = 6e-4    # Обновленная скорость обучения

train_acc = 0
iteration = 0

while train_acc < 1.0:
    print(f"\nИтерация: {iteration + 1}")
    model = FullyConnectedNet([100, 100, 100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver = Solver(model, small_data,
                    print_every=10, num_epochs=20, batch_size=25,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    verbose=True)
    solver.train()

    # Получение и вывод последней точности на обучающем наборе
    train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
    print(f'Final train accuracy after iteration {iteration + 1}: {train_acc}')

    if train_acc < 1.0:
        print("Train accuracy is less than 100%, trying again...")
        iteration += 1
    else:
        print("Reached 100% train accuracy!")

    # Визуализация истории потерь после достижения 100% точности
    if train_acc == 1.0:
        plt.plot(solver.loss_history, 'o')
        plt.title('Training loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Training loss')
        plt.show()
        break
# Out:
# Итерация: 1
# (Iteration 1 / 40) loss: 12.969311
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.103600
# (Epoch 1 / 20) train acc: 0.220000; val_acc: 0.125400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.105200
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.119000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.111600
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.121800
# (Iteration 11 / 40) loss: 2.754527
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.125400
# (Epoch 7 / 20) train acc: 0.480000; val_acc: 0.143400
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.144000
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.153600
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.144600
# (Iteration 21 / 40) loss: 0.944982
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.140400
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.146400
# (Epoch 13 / 20) train acc: 0.440000; val_acc: 0.142400
# (Epoch 14 / 20) train acc: 0.700000; val_acc: 0.157600
# (Epoch 15 / 20) train acc: 0.880000; val_acc: 0.160800
# (Iteration 31 / 40) loss: 0.540472
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.156600
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.154600
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.158200
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.158400
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.163000
# Final train accuracy after iteration 1: 0.92
# Train accuracy is less than 100%, trying again...
#
# Итерация: 2
# (Iteration 1 / 40) loss: 31.190443
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.108800
# (Epoch 1 / 20) train acc: 0.040000; val_acc: 0.093800
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.097800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.102600
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.125000
# (Iteration 11 / 40) loss: 3.175318
# (Epoch 6 / 20) train acc: 0.340000; val_acc: 0.100400
# (Epoch 7 / 20) train acc: 0.540000; val_acc: 0.118000
# (Epoch 8 / 20) train acc: 0.620000; val_acc: 0.114600
# (Epoch 9 / 20) train acc: 0.600000; val_acc: 0.108400
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.116200
# (Iteration 21 / 40) loss: 0.812117
# (Epoch 11 / 20) train acc: 0.720000; val_acc: 0.117200
# (Epoch 12 / 20) train acc: 0.760000; val_acc: 0.127600
# (Epoch 13 / 20) train acc: 0.780000; val_acc: 0.128200
# (Epoch 14 / 20) train acc: 0.840000; val_acc: 0.127400
# (Epoch 15 / 20) train acc: 0.880000; val_acc: 0.126000
# (Iteration 31 / 40) loss: 0.601047
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.133600
# (Epoch 17 / 20) train acc: 0.860000; val_acc: 0.122800
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.134600
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.135400
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.129800
# Final train accuracy after iteration 2: 0.94
# Train accuracy is less than 100%, trying again...
#
# Итерация: 3
# (Iteration 1 / 40) loss: 10.595566
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.105800
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.119200
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.107800
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.124400
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.125400
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.137800
# (Iteration 11 / 40) loss: 1.821005
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.116000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.134600
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.137000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.134400
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.143000
# (Iteration 21 / 40) loss: 1.627344
# (Epoch 11 / 20) train acc: 0.540000; val_acc: 0.149800
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.140400
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.153400
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.146600
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.146800
# (Iteration 31 / 40) loss: 0.939369
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.156800
# (Epoch 17 / 20) train acc: 0.860000; val_acc: 0.157400
# (Epoch 18 / 20) train acc: 0.660000; val_acc: 0.135800
# (Epoch 19 / 20) train acc: 0.780000; val_acc: 0.149200
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.149600
# Final train accuracy after iteration 3: 0.86
# Train accuracy is less than 100%, trying again...
#
# Итерация: 4
# (Iteration 1 / 40) loss: 16.523020
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.092400
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.115800
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.116200
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.096400
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.115800
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.122400
# (Iteration 11 / 40) loss: 3.261183
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.121600
# (Epoch 7 / 20) train acc: 0.520000; val_acc: 0.123800
# (Epoch 8 / 20) train acc: 0.600000; val_acc: 0.142600
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.141600
# (Epoch 10 / 20) train acc: 0.600000; val_acc: 0.146800
# (Iteration 21 / 40) loss: 0.873268
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.149200
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.158400
# (Epoch 13 / 20) train acc: 0.620000; val_acc: 0.162800
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.139400
# (Epoch 15 / 20) train acc: 0.800000; val_acc: 0.143800
# (Iteration 31 / 40) loss: 0.706489
# (Epoch 16 / 20) train acc: 0.860000; val_acc: 0.148800
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.145200
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.149200
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.155200
# (Epoch 20 / 20) train acc: 0.700000; val_acc: 0.139000
# Final train accuracy after iteration 4: 0.62
# Train accuracy is less than 100%, trying again...
#
# Итерация: 5
# (Iteration 1 / 40) loss: 24.887832
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.101400
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.105600
# (Epoch 2 / 20) train acc: 0.240000; val_acc: 0.111200
# (Epoch 3 / 20) train acc: 0.320000; val_acc: 0.116800
# (Epoch 4 / 20) train acc: 0.500000; val_acc: 0.118600
# (Epoch 5 / 20) train acc: 0.460000; val_acc: 0.120800
# (Iteration 11 / 40) loss: 1.042305
# (Epoch 6 / 20) train acc: 0.600000; val_acc: 0.129600
# (Epoch 7 / 20) train acc: 0.540000; val_acc: 0.123800
# (Epoch 8 / 20) train acc: 0.680000; val_acc: 0.121200
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.114200
# (Epoch 10 / 20) train acc: 0.740000; val_acc: 0.123200
# (Iteration 21 / 40) loss: 0.886435
# (Epoch 11 / 20) train acc: 0.760000; val_acc: 0.126200
# (Epoch 12 / 20) train acc: 0.760000; val_acc: 0.127000
# (Epoch 13 / 20) train acc: 0.780000; val_acc: 0.124200
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.121600
# (Epoch 15 / 20) train acc: 0.860000; val_acc: 0.128400
# (Iteration 31 / 40) loss: 0.467093
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.133000
# (Epoch 17 / 20) train acc: 0.700000; val_acc: 0.122200
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.125000
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.130800
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.132200
# Final train accuracy after iteration 5: 0.9
# Train accuracy is less than 100%, trying again...
#
# Итерация: 6
# (Iteration 1 / 40) loss: 16.429504
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.088200
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.095800
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.110400
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.117200
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.118600
# (Iteration 11 / 40) loss: 1.769101
# (Epoch 6 / 20) train acc: 0.520000; val_acc: 0.115600
# (Epoch 7 / 20) train acc: 0.560000; val_acc: 0.111000
# (Epoch 8 / 20) train acc: 0.640000; val_acc: 0.121600
# (Epoch 9 / 20) train acc: 0.720000; val_acc: 0.121400
# (Epoch 10 / 20) train acc: 0.740000; val_acc: 0.126200
# (Iteration 21 / 40) loss: 1.240093
# (Epoch 11 / 20) train acc: 0.700000; val_acc: 0.116800
# (Epoch 12 / 20) train acc: 0.800000; val_acc: 0.129800
# (Epoch 13 / 20) train acc: 0.820000; val_acc: 0.134200
# (Epoch 14 / 20) train acc: 0.880000; val_acc: 0.131200
# (Epoch 15 / 20) train acc: 0.880000; val_acc: 0.120800
# (Iteration 31 / 40) loss: 0.504345
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.119000
# (Epoch 17 / 20) train acc: 0.920000; val_acc: 0.124000
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.127800
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.132800
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.125600
# Final train accuracy after iteration 6: 0.82
# Train accuracy is less than 100%, trying again...
#
# Итерация: 7
# (Iteration 1 / 40) loss: 17.320171
# (Epoch 0 / 20) train acc: 0.220000; val_acc: 0.104600
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.104200
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.117800
# (Epoch 3 / 20) train acc: 0.280000; val_acc: 0.111800
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.111400
# (Epoch 5 / 20) train acc: 0.420000; val_acc: 0.131400
# (Iteration 11 / 40) loss: 2.103421
# (Epoch 6 / 20) train acc: 0.640000; val_acc: 0.124000
# (Epoch 7 / 20) train acc: 0.720000; val_acc: 0.132200
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.114400
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.132600
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.128800
# (Iteration 21 / 40) loss: 1.321795
# (Epoch 11 / 20) train acc: 0.580000; val_acc: 0.121400
# (Epoch 12 / 20) train acc: 0.800000; val_acc: 0.132000
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.127600
# (Epoch 14 / 20) train acc: 0.860000; val_acc: 0.139800
# (Epoch 15 / 20) train acc: 0.900000; val_acc: 0.142000
# (Iteration 31 / 40) loss: 0.185462
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.134000
# (Epoch 17 / 20) train acc: 0.940000; val_acc: 0.144000
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.140600
# (Epoch 19 / 20) train acc: 0.960000; val_acc: 0.141800
# (Epoch 20 / 20) train acc: 0.960000; val_acc: 0.142200
# Final train accuracy after iteration 7: 0.94
# Train accuracy is less than 100%, trying again...
#
# Итерация: 8
# (Iteration 1 / 40) loss: 41.699842
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.086000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.103600
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.113400
# (Epoch 3 / 20) train acc: 0.360000; val_acc: 0.130200
# (Epoch 4 / 20) train acc: 0.440000; val_acc: 0.126600
# (Epoch 5 / 20) train acc: 0.460000; val_acc: 0.127400
# (Iteration 11 / 40) loss: 1.760105
# (Epoch 6 / 20) train acc: 0.480000; val_acc: 0.115000
# (Epoch 7 / 20) train acc: 0.660000; val_acc: 0.132000
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.126400
# (Epoch 9 / 20) train acc: 0.820000; val_acc: 0.134200
# (Epoch 10 / 20) train acc: 0.700000; val_acc: 0.125000
# (Iteration 21 / 40) loss: 0.920273
# (Epoch 11 / 20) train acc: 0.800000; val_acc: 0.134800
# (Epoch 12 / 20) train acc: 0.860000; val_acc: 0.140800
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.137000
# (Epoch 14 / 20) train acc: 0.880000; val_acc: 0.144400
# (Epoch 15 / 20) train acc: 0.920000; val_acc: 0.131400
# (Iteration 31 / 40) loss: 0.490961
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.131000
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.123200
# (Epoch 18 / 20) train acc: 0.960000; val_acc: 0.143000
# (Epoch 19 / 20) train acc: 0.960000; val_acc: 0.136000
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.142200
# Final train accuracy after iteration 8: 0.88
# Train accuracy is less than 100%, trying again...
#
# Итерация: 9
# (Iteration 1 / 40) loss: 14.313169
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.101600
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.122000
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.109800
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.103600
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.094000
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.122800
# (Iteration 11 / 40) loss: 1.785721
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.114800
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.131200
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.126600
# (Epoch 9 / 20) train acc: 0.620000; val_acc: 0.124400
# (Epoch 10 / 20) train acc: 0.600000; val_acc: 0.135600
# (Iteration 21 / 40) loss: 0.939654
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.118600
# (Epoch 12 / 20) train acc: 0.760000; val_acc: 0.132000
# (Epoch 13 / 20) train acc: 0.660000; val_acc: 0.128600
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.128600
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.137000
# (Iteration 31 / 40) loss: 0.767266
# (Epoch 16 / 20) train acc: 0.840000; val_acc: 0.131800
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.140800
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.132600
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.138400
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.140600
# Final train accuracy after iteration 9: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 10
# (Iteration 1 / 40) loss: 35.865704
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.128400
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.114400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.097600
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.082200
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.103000
# (Epoch 5 / 20) train acc: 0.280000; val_acc: 0.098000
# (Iteration 11 / 40) loss: 3.565101
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.107600
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.108400
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.121200
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.125600
# (Epoch 10 / 20) train acc: 0.660000; val_acc: 0.109200
# (Iteration 21 / 40) loss: 0.892229
# (Epoch 11 / 20) train acc: 0.780000; val_acc: 0.122800
# (Epoch 12 / 20) train acc: 0.740000; val_acc: 0.127400
# (Epoch 13 / 20) train acc: 0.720000; val_acc: 0.110800
# (Epoch 14 / 20) train acc: 0.840000; val_acc: 0.122000
# (Epoch 15 / 20) train acc: 0.900000; val_acc: 0.119000
# (Iteration 31 / 40) loss: 0.605528
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.124200
# (Epoch 17 / 20) train acc: 0.920000; val_acc: 0.123400
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.131200
# (Epoch 19 / 20) train acc: 0.960000; val_acc: 0.123200
# (Epoch 20 / 20) train acc: 0.960000; val_acc: 0.122000
# Final train accuracy after iteration 10: 0.92
# Train accuracy is less than 100%, trying again...
#
# Итерация: 11
# (Iteration 1 / 40) loss: 24.307867
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.108400
# (Epoch 1 / 20) train acc: 0.240000; val_acc: 0.123000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.103200
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.115800
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.103800
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.107600
# (Iteration 11 / 40) loss: 2.682841
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.099000
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.133400
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.127400
# (Epoch 9 / 20) train acc: 0.460000; val_acc: 0.128200
# (Epoch 10 / 20) train acc: 0.440000; val_acc: 0.122400
# (Iteration 21 / 40) loss: 2.324449
# (Epoch 11 / 20) train acc: 0.640000; val_acc: 0.122200
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.127000
# (Epoch 13 / 20) train acc: 0.780000; val_acc: 0.125200
# (Epoch 14 / 20) train acc: 0.800000; val_acc: 0.124000
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.132600
# (Iteration 31 / 40) loss: 0.552946
# (Epoch 16 / 20) train acc: 0.860000; val_acc: 0.137200
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.138800
# (Epoch 18 / 20) train acc: 0.900000; val_acc: 0.127000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.132200
# (Epoch 20 / 20) train acc: 0.880000; val_acc: 0.135800
# Final train accuracy after iteration 11: 0.88
# Train accuracy is less than 100%, trying again...
#
# Итерация: 12
# (Iteration 1 / 40) loss: 21.837010
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.083200
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.101200
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.100600
# (Epoch 3 / 20) train acc: 0.280000; val_acc: 0.112600
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.097600
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.111000
# (Iteration 11 / 40) loss: 2.442979
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.119400
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.121200
# (Epoch 8 / 20) train acc: 0.640000; val_acc: 0.122800
# (Epoch 9 / 20) train acc: 0.660000; val_acc: 0.120800
# (Epoch 10 / 20) train acc: 0.760000; val_acc: 0.129000
# (Iteration 21 / 40) loss: 0.365481
# (Epoch 11 / 20) train acc: 0.720000; val_acc: 0.123800
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.130400
# (Epoch 13 / 20) train acc: 0.900000; val_acc: 0.129400
# (Epoch 14 / 20) train acc: 0.940000; val_acc: 0.123200
# (Epoch 15 / 20) train acc: 0.940000; val_acc: 0.131200
# (Iteration 31 / 40) loss: 0.485643
# (Epoch 16 / 20) train acc: 0.960000; val_acc: 0.129200
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.125600
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.129200
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.130800
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.124200
# Final train accuracy after iteration 12: 0.94
# Train accuracy is less than 100%, trying again...
#
# Итерация: 13
# (Iteration 1 / 40) loss: 29.487869
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.100800
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.100000
# (Epoch 2 / 20) train acc: 0.020000; val_acc: 0.095400
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.094600
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.100400
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.100000
# (Iteration 11 / 40) loss: 3.577567
# (Epoch 6 / 20) train acc: 0.320000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.115400
# (Epoch 8 / 20) train acc: 0.380000; val_acc: 0.105200
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.112800
# (Epoch 10 / 20) train acc: 0.420000; val_acc: 0.124600
# (Iteration 21 / 40) loss: 1.413923
# (Epoch 11 / 20) train acc: 0.460000; val_acc: 0.132200
# (Epoch 12 / 20) train acc: 0.500000; val_acc: 0.133400
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.121000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.117600
# (Epoch 15 / 20) train acc: 0.740000; val_acc: 0.126800
# (Iteration 31 / 40) loss: 1.025257
# (Epoch 16 / 20) train acc: 0.760000; val_acc: 0.125000
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.126600
# (Epoch 18 / 20) train acc: 0.800000; val_acc: 0.134400
# (Epoch 19 / 20) train acc: 0.780000; val_acc: 0.118800
# (Epoch 20 / 20) train acc: 0.760000; val_acc: 0.113800
# Final train accuracy after iteration 13: 0.8
# Train accuracy is less than 100%, trying again...
#
# Итерация: 14
# (Iteration 1 / 40) loss: 12.334115
# (Epoch 0 / 20) train acc: 0.040000; val_acc: 0.099000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.101600
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.097800
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.099000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.117000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.127200
# (Iteration 11 / 40) loss: 2.269274
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.122600
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.127400
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.129800
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.131200
# (Epoch 10 / 20) train acc: 0.660000; val_acc: 0.137000
# (Iteration 21 / 40) loss: 1.083762
# (Epoch 11 / 20) train acc: 0.680000; val_acc: 0.132200
# (Epoch 12 / 20) train acc: 0.720000; val_acc: 0.131200
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.126800
# (Epoch 14 / 20) train acc: 0.820000; val_acc: 0.136800
# (Epoch 15 / 20) train acc: 0.820000; val_acc: 0.139800
# (Iteration 31 / 40) loss: 0.999862
# (Epoch 16 / 20) train acc: 0.860000; val_acc: 0.131000
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.128600
# (Epoch 18 / 20) train acc: 0.660000; val_acc: 0.118600
# (Epoch 19 / 20) train acc: 0.720000; val_acc: 0.136600
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.146200
# Final train accuracy after iteration 14: 0.9
# Train accuracy is less than 100%, trying again...
#
# Итерация: 15
# (Iteration 1 / 40) loss: 13.903711
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.086200
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.101800
# (Epoch 2 / 20) train acc: 0.240000; val_acc: 0.119200
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.107800
# (Epoch 4 / 20) train acc: 0.340000; val_acc: 0.118800
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.100400
# (Iteration 11 / 40) loss: 3.966843
# (Epoch 6 / 20) train acc: 0.440000; val_acc: 0.128800
# (Epoch 7 / 20) train acc: 0.540000; val_acc: 0.131800
# (Epoch 8 / 20) train acc: 0.580000; val_acc: 0.127200
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.129000
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.135800
# (Iteration 21 / 40) loss: 1.143634
# (Epoch 11 / 20) train acc: 0.800000; val_acc: 0.131800
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.133200
# (Epoch 13 / 20) train acc: 0.840000; val_acc: 0.141200
# (Epoch 14 / 20) train acc: 0.860000; val_acc: 0.143800
# (Epoch 15 / 20) train acc: 0.800000; val_acc: 0.147600
# (Iteration 31 / 40) loss: 0.522539
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.149600
# (Epoch 17 / 20) train acc: 0.920000; val_acc: 0.149800
# (Epoch 18 / 20) train acc: 0.940000; val_acc: 0.151000
# (Epoch 19 / 20) train acc: 0.900000; val_acc: 0.150600
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.154400
# Final train accuracy after iteration 15: 0.9
# Train accuracy is less than 100%, trying again...
#
# Итерация: 16
# (Iteration 1 / 40) loss: 14.523879
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.093400
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.096400
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.110800
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.114800
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.130800
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.137800
# (Iteration 11 / 40) loss: 1.634105
# (Epoch 6 / 20) train acc: 0.560000; val_acc: 0.137600
# (Epoch 7 / 20) train acc: 0.420000; val_acc: 0.114200
# (Epoch 8 / 20) train acc: 0.640000; val_acc: 0.133800
# (Epoch 9 / 20) train acc: 0.640000; val_acc: 0.123800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 29
#      21 model = FullyConnectedNet([100, 100, 100, 100], weight_scale=weight_scale, dtype=np.float64)
#      22 solver = Solver(model, small_data,
#      23                 print_every=10, num_epochs=20, batch_size=25,
#      24                 update_rule='sgd',
#    (...)
#      27                 },
#      28                 verbose=True)
# ---> 29 solver.train()
#      31 # Получение и вывод последней точности на обучающем наборе
#      32 train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\solver.py:288, in Solver.train(self)
#     284 if first_it or last_it or epoch_end:
#     285     train_acc = self.check_accuracy(
#     286         self.X_train, self.y_train, num_samples=self.num_train_samples
#     287     )
# --> 288     val_acc = self.check_accuracy(
#     289         self.X_val, self.y_val, num_samples=self.num_val_samples
#     290     )
#     291     self.train_acc_history.append(train_acc)
#     292     self.val_acc_history.append(val_acc)
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\solver.py:248, in Solver.check_accuracy(self, X, y, num_samples, batch_size)
#     246     end = (i + 1) * batch_size
#     247     scores = self.model.loss(X[start:end])
# --> 248     y_pred.append(np.argmax(scores, axis=1))
#     249 y_pred = np.hstack(y_pred)
#     250 acc = np.mean(y_pred == y)
#
# File ~\PycharmProjects\neural-networks-course\venv\lib\site-packages\numpy\core\fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\PycharmProjects\neural-networks-course\venv\lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# На 12 итерации получилась точность 1.0

# %% [markdown]
# Ранее обновление весов проходило по правилу SGD. Теперь попробуйте реализовать стохастический градиентный спуск с импульсом (SGD+momentum). http://cs231n.github.io/neural-networks-3/#sgd Реализуйте sgd_momentum в scripts/optim.py  и запустите проверку.

# %%
from scripts.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Сравните результаты обучения шестислойной сети, обученной классическим градиентным спуском и адаптивным алгоритмом с импульсом. Какой алгоритм сходится быстрее.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# running with  sgd
# (Iteration 1 / 200) loss: 3.674155
# (Epoch 0 / 5) train acc: 0.104000; val_acc: 0.100600
# (Iteration 11 / 200) loss: 2.356815
# (Iteration 21 / 200) loss: 2.262905
# (Iteration 31 / 200) loss: 2.212363
# (Epoch 1 / 5) train acc: 0.180000; val_acc: 0.162200
# (Iteration 41 / 200) loss: 2.187778
# (Iteration 51 / 200) loss: 2.035599
# (Iteration 61 / 200) loss: 2.024224
# (Iteration 71 / 200) loss: 2.142700
# (Epoch 2 / 5) train acc: 0.275000; val_acc: 0.233600
# (Iteration 81 / 200) loss: 1.964057
# (Iteration 91 / 200) loss: 2.024058
# (Iteration 101 / 200) loss: 1.991974
# (Iteration 111 / 200) loss: 1.853724
# (Epoch 3 / 5) train acc: 0.292000; val_acc: 0.239200
# (Iteration 121 / 200) loss: 2.071760
# (Iteration 131 / 200) loss: 1.924913
# (Iteration 141 / 200) loss: 1.944522
# (Iteration 151 / 200) loss: 2.122069
# (Epoch 4 / 5) train acc: 0.277000; val_acc: 0.238600
# (Iteration 161 / 200) loss: 2.052304
# (Iteration 171 / 200) loss: 1.918291
# (Iteration 181 / 200) loss: 1.908327
# (Iteration 191 / 200) loss: 1.858690
# (Epoch 5 / 5) train acc: 0.343000; val_acc: 0.285600
#
# running with  sgd_momentum
# (Iteration 1 / 200) loss: 3.737451
# (Epoch 0 / 5) train acc: 0.113000; val_acc: 0.102200
# (Iteration 11 / 200) loss: 2.247122
# (Iteration 21 / 200) loss: 2.340910
# (Iteration 31 / 200) loss: 2.178701
# (Epoch 1 / 5) train acc: 0.144000; val_acc: 0.160400
# (Iteration 41 / 200) loss: 2.314759
# (Iteration 51 / 200) loss: 2.109288
# (Iteration 61 / 200) loss: 2.084545
# (Iteration 71 / 200) loss: 1.997492
# (Epoch 2 / 5) train acc: 0.249000; val_acc: 0.223800
# (Iteration 81 / 200) loss: 2.018925
# (Iteration 91 / 200) loss: 2.013668
# (Iteration 101 / 200) loss: 1.945084
# (Iteration 111 / 200) loss: 2.086969
# (Epoch 3 / 5) train acc: 0.262000; val_acc: 0.254400
# (Iteration 121 / 200) loss: 1.922131
# (Iteration 131 / 200) loss: 1.837066
# (Iteration 141 / 200) loss: 1.868399
# (Iteration 151 / 200) loss: 1.920873
# (Epoch 4 / 5) train acc: 0.283000; val_acc: 0.270600
# (Iteration 161 / 200) loss: 1.777726
# (Iteration 171 / 200) loss: 1.980194
# (Iteration 181 / 200) loss: 2.000390
# (Iteration 191 / 200) loss: 1.836309
# (Epoch 5 / 5) train acc: 0.245000; val_acc: 0.247200

# %% [markdown]
# Реализуйте алгоритмы RMSProp [1] and Adam [2] с коррекцией смещения  - методы rmsprop и adam .
#
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from scripts.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from scripts.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Обучите пару глубоких сетей с испольованием RMSProp и Adam алгоритмов обновления весов и сравните результаты обучения.

# %% [markdown]
# Получите лучшую полносвязную сеть для классификации вашего набора данных. На наборе CIFAR-10 необходимо получить accuracy не ниже 50 % на валидационном наборе.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Инициализационные параметры
weight_scale = 1e-3
learning_rate = 1e-3
update_rules = ['rmsprop', 'adam']
best_val_acc = 0.0  # Сохраняем наилучшую точность на валидационном наборе
best_model = None

for update_rule in update_rules:
    print("\nОбучение с использованием", update_rule.upper())

    model = FullyConnectedNet([500, 250, 250], weight_scale=weight_scale, dtype=np.float32, seed=42)

    solver = Solver(model, data,
                    print_every=500,
                    num_epochs=30,
                    batch_size=250,
                    update_rule=update_rule,
                    optim_config={
                        'learning_rate': learning_rate,
                    },
                    lr_decay=0.9)

    solver.train()

    print("Точность валидации:", solver.best_val_acc)

    # Проверка и сохранение лучшей модели
    if solver.best_val_acc > best_val_acc:
        best_val_acc = solver.best_val_acc
        best_model = model

print("\nЛучшая точность валидации:", best_val_acc)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# Обучение с использованием RMSPROP
# (Iteration 1 / 5880) loss: 2.302585
# (Epoch 0 / 30) train acc: 0.096000; val_acc: 0.096000
# (Epoch 1 / 30) train acc: 0.137000; val_acc: 0.127000
# (Epoch 2 / 30) train acc: 0.203000; val_acc: 0.192000
# (Iteration 501 / 5880) loss: 2.050922
# (Epoch 3 / 30) train acc: 0.205000; val_acc: 0.195000
# (Epoch 4 / 30) train acc: 0.262000; val_acc: 0.290000
# (Epoch 5 / 30) train acc: 0.351000; val_acc: 0.327000
# (Iteration 1001 / 5880) loss: 1.863992
# (Epoch 6 / 30) train acc: 0.367000; val_acc: 0.353000
# (Epoch 7 / 30) train acc: 0.379000; val_acc: 0.384000
# (Iteration 1501 / 5880) loss: 1.762391
# (Epoch 8 / 30) train acc: 0.396000; val_acc: 0.416000
# (Epoch 9 / 30) train acc: 0.429000; val_acc: 0.434000
# (Epoch 10 / 30) train acc: 0.410000; val_acc: 0.416000
# (Iteration 2001 / 5880) loss: 1.600920
# (Epoch 11 / 30) train acc: 0.483000; val_acc: 0.451000
# (Epoch 12 / 30) train acc: 0.455000; val_acc: 0.444000
# (Iteration 2501 / 5880) loss: 1.537968
# (Epoch 13 / 30) train acc: 0.453000; val_acc: 0.425000
# (Epoch 14 / 30) train acc: 0.516000; val_acc: 0.459000
# (Epoch 15 / 30) train acc: 0.465000; val_acc: 0.462000
# (Iteration 3001 / 5880) loss: 1.423760
# (Epoch 16 / 30) train acc: 0.510000; val_acc: 0.468000
# (Epoch 17 / 30) train acc: 0.519000; val_acc: 0.470000
# (Iteration 3501 / 5880) loss: 1.397461
# (Epoch 18 / 30) train acc: 0.518000; val_acc: 0.478000
# (Epoch 19 / 30) train acc: 0.509000; val_acc: 0.474000
# (Epoch 20 / 30) train acc: 0.537000; val_acc: 0.481000
# (Iteration 4001 / 5880) loss: 1.424403
# (Epoch 21 / 30) train acc: 0.549000; val_acc: 0.467000
# (Epoch 22 / 30) train acc: 0.519000; val_acc: 0.485000
# (Iteration 4501 / 5880) loss: 1.224757
# (Epoch 23 / 30) train acc: 0.530000; val_acc: 0.483000
# (Epoch 24 / 30) train acc: 0.546000; val_acc: 0.485000
# (Epoch 25 / 30) train acc: 0.569000; val_acc: 0.477000
# (Iteration 5001 / 5880) loss: 1.362811
# (Epoch 26 / 30) train acc: 0.549000; val_acc: 0.488000
# (Epoch 27 / 30) train acc: 0.554000; val_acc: 0.497000
# (Epoch 28 / 30) train acc: 0.536000; val_acc: 0.494000
# (Iteration 5501 / 5880) loss: 1.318237
# (Epoch 29 / 30) train acc: 0.545000; val_acc: 0.487000
# (Epoch 30 / 30) train acc: 0.551000; val_acc: 0.487000
# Точность валидации: 0.497
#
# Обучение с использованием ADAM
# (Iteration 1 / 5880) loss: 2.302584
# (Epoch 0 / 30) train acc: 0.094000; val_acc: 0.110000
# (Epoch 1 / 30) train acc: 0.279000; val_acc: 0.302000
# (Epoch 2 / 30) train acc: 0.353000; val_acc: 0.366000
# (Iteration 501 / 5880) loss: 1.701075
# (Epoch 3 / 30) train acc: 0.399000; val_acc: 0.386000
# (Epoch 4 / 30) train acc: 0.425000; val_acc: 0.407000
# (Epoch 5 / 30) train acc: 0.414000; val_acc: 0.420000
# (Iteration 1001 / 5880) loss: 1.516625
# (Epoch 6 / 30) train acc: 0.442000; val_acc: 0.450000
# (Epoch 7 / 30) train acc: 0.453000; val_acc: 0.469000
# (Iteration 1501 / 5880) loss: 1.537974
# (Epoch 8 / 30) train acc: 0.486000; val_acc: 0.446000
# (Epoch 9 / 30) train acc: 0.465000; val_acc: 0.471000
# (Epoch 10 / 30) train acc: 0.500000; val_acc: 0.470000
# (Iteration 2001 / 5880) loss: 1.277742
# (Epoch 11 / 30) train acc: 0.500000; val_acc: 0.468000
# (Epoch 12 / 30) train acc: 0.468000; val_acc: 0.470000
# (Iteration 2501 / 5880) loss: 1.354119
# (Epoch 13 / 30) train acc: 0.540000; val_acc: 0.472000
# (Epoch 14 / 30) train acc: 0.522000; val_acc: 0.476000
# (Epoch 15 / 30) train acc: 0.503000; val_acc: 0.480000
# (Iteration 3001 / 5880) loss: 1.345815
# (Epoch 16 / 30) train acc: 0.498000; val_acc: 0.480000
# (Epoch 17 / 30) train acc: 0.516000; val_acc: 0.483000
# (Iteration 3501 / 5880) loss: 1.368789
# (Epoch 18 / 30) train acc: 0.514000; val_acc: 0.493000
# (Epoch 19 / 30) train acc: 0.540000; val_acc: 0.484000
# (Epoch 20 / 30) train acc: 0.544000; val_acc: 0.484000
# (Iteration 4001 / 5880) loss: 1.280578
# (Epoch 21 / 30) train acc: 0.513000; val_acc: 0.495000
# (Epoch 22 / 30) train acc: 0.523000; val_acc: 0.488000
# (Iteration 4501 / 5880) loss: 1.253119
# (Epoch 23 / 30) train acc: 0.549000; val_acc: 0.482000
# (Epoch 24 / 30) train acc: 0.563000; val_acc: 0.486000
# (Epoch 25 / 30) train acc: 0.572000; val_acc: 0.491000
# (Iteration 5001 / 5880) loss: 1.299398
# (Epoch 26 / 30) train acc: 0.556000; val_acc: 0.503000
# (Epoch 27 / 30) train acc: 0.545000; val_acc: 0.500000
# (Epoch 28 / 30) train acc: 0.528000; val_acc: 0.495000
# (Iteration 5501 / 5880) loss: 1.213963
# (Epoch 29 / 30) train acc: 0.541000; val_acc: 0.504000
# (Epoch 30 / 30) train acc: 0.525000; val_acc: 0.492000
# Точность валидации: 0.504
#
# Лучшая точность валидации: 0.504

# %% [markdown]
# Получите оценку accuracy для валидационной и тестовой выборок.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.504
# Test set accuracy:  0.4909

# %% [markdown]
# # Нормализация по мини-батчам
#
# Идея нормализации по мини-батчам предложена в работе [1]
#
# [1] Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift", ICML 2015.

# %% [markdown]
# Реализуйте прямой проход для слоя батч-нормализации - функция batchnorm_forward в scripts/layers.py . Проверьте свою реализацию, запустив следующий код:

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after batch normalization   

# Simulate the forward pass for a two-layer network
np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before batch normalization:')
print_mean_std(a,axis=0)

gamma = np.ones((D3,))
beta = np.zeros((D3,))
# Means should be close to zero and stds close to one
print('After batch normalization (gamma=1, beta=0)')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)

gamma = np.asarray([1.0, 2.0, 3.0])
beta = np.asarray([11.0, 12.0, 13.0])
# Now means should be close to beta and stds close to gamma
print('After batch normalization (gamma=', gamma, ', beta=', beta, ')')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)
# Out:
# Before batch normalization:
#   means:  [ -2.3814598  -13.18038246   1.91780462]
#   stds:   [27.18502186 34.21455511 37.68611762]
#
# After batch normalization (gamma=1, beta=0)
#   means:  [7.32747196e-17 1.22124533e-17 5.41233725e-18]
#   stds:   [0.99999999 1.         1.        ]
#
# After batch normalization (gamma= [1. 2. 3.] , beta= [11. 12. 13.] )
#   means:  [11. 12. 13.]
#   stds:   [0.99999999 1.99999999 2.99999999]

# %%
# Check the test-time forward pass by running the training-time
# forward pass many times to warm up the running averages, and then
# checking the means and variances of activations after a test-time
# forward pass.

np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)

bn_param = {'mode': 'train'}
gamma = np.ones(D3)
beta = np.zeros(D3)

for t in range(50):
  X = np.random.randn(N, D1)
  a = np.maximum(0, X.dot(W1)).dot(W2)
  batchnorm_forward(a, gamma, beta, bn_param)

bn_param['mode'] = 'test'
X = np.random.randn(N, D1)
a = np.maximum(0, X.dot(W1)).dot(W2)
a_norm, _ = batchnorm_forward(a, gamma, beta, bn_param)

# Means should be close to zero and stds close to one, but will be
# noisier than training-time forward passes.
print('After batch normalization (test-time):')
print_mean_std(a_norm,axis=0)
# Out:
# After batch normalization (test-time):
#   means:  [-0.03927354 -0.04349152 -0.10452688]
#   stds:   [1.01531428 1.01238373 0.97819988]

# %% [markdown]
# Реализуйте обратный проход в функции batchnorm_backward.

# %%
# Gradient check batchnorm backward pass
np.random.seed(231)
N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}
fx = lambda x: batchnorm_forward(x, gamma, beta, bn_param)[0]
fg = lambda a: batchnorm_forward(x, a, beta, bn_param)[0]
fb = lambda b: batchnorm_forward(x, gamma, b, bn_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma.copy(), dout)
db_num = eval_numerical_gradient_array(fb, beta.copy(), dout)

_, cache = batchnorm_forward(x, gamma, beta, bn_param)
dx, dgamma, dbeta = batchnorm_backward(dout, cache)
#You should expect to see relative errors between 1e-13 and 1e-8
print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))
# Out:
# dx error:  1.7029261167605239e-09
# dgamma error:  7.420414216247087e-13
# dbeta error:  2.8795057655839487e-12

# %% [markdown]
# Измените реализацию класса FullyConnectedNet, добавив батч-нормализацию.
# Если флаг normalization == "batchnorm", то вам необходимо вставить слой батч-нормализации перед каждым слоем активации ReLU, кроме выхода сети.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

# You should expect losses between 1e-4~1e-10 for W, 
# losses between 1e-08~1e-10 for b,
# and losses between 1e-08~1e-09 for beta and gammas.
for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64,
                            normalization='batchnorm')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  if reg == 0: print()
# Out:
# Running check with reg =  0
# Initial loss:  2.2611955101340957
# W1 relative error: 1.10e-04
# W2 relative error: 2.85e-06
# W3 relative error: 4.05e-10
# b1 relative error: 4.44e-08
# b2 relative error: 2.22e-08
# b3 relative error: 1.01e-10
# beta1 relative error: 7.33e-09
# beta2 relative error: 1.89e-09
# gamma1 relative error: 6.96e-09
# gamma2 relative error: 1.96e-09
#
# Running check with reg =  3.14
# Initial loss:  6.996533220108303
# W1 relative error: 1.98e-06
# W2 relative error: 2.28e-06
# W3 relative error: 1.11e-08
# b1 relative error: 5.55e-09
# b2 relative error: 2.22e-08
# b3 relative error: 2.10e-10
# beta1 relative error: 6.65e-09
# beta2 relative error: 4.23e-09
# gamma1 relative error: 6.27e-09
# gamma2 relative error: 5.28e-09

# %% [markdown]
# Обучите 6-ти слойную сеть на наборе из 1000 изображений с батч-нормализацией и без нее

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 2e-2
bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization='batchnorm')
model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)

print('Solver with batch norm:')
bn_solver = Solver(bn_model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True,print_every=20)
bn_solver.train()

print('\nSolver without batch norm:')
solver = Solver(model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()
# Out:
# Solver with batch norm:
# (Iteration 1 / 200) loss: 2.292243
# (Epoch 0 / 10) train acc: 0.120000; val_acc: 0.099200
# (Epoch 1 / 10) train acc: 0.226000; val_acc: 0.192200
# (Iteration 21 / 200) loss: 1.969448
# (Epoch 2 / 10) train acc: 0.300000; val_acc: 0.233000
# (Iteration 41 / 200) loss: 1.790542
# (Epoch 3 / 10) train acc: 0.403000; val_acc: 0.264600
# (Iteration 61 / 200) loss: 1.562697
# (Epoch 4 / 10) train acc: 0.357000; val_acc: 0.233400
# (Iteration 81 / 200) loss: 1.457809
# (Epoch 5 / 10) train acc: 0.371000; val_acc: 0.227200
# (Iteration 101 / 200) loss: 1.476270
# (Epoch 6 / 10) train acc: 0.474000; val_acc: 0.275600
# (Iteration 121 / 200) loss: 1.345639
# (Epoch 7 / 10) train acc: 0.599000; val_acc: 0.303400
# (Iteration 141 / 200) loss: 0.892504
# (Epoch 8 / 10) train acc: 0.536000; val_acc: 0.271200
# (Iteration 161 / 200) loss: 0.926193
# (Epoch 9 / 10) train acc: 0.488000; val_acc: 0.263000
# (Iteration 181 / 200) loss: 0.730682
# (Epoch 10 / 10) train acc: 0.650000; val_acc: 0.276400
#
# Solver without batch norm:
# (Iteration 1 / 200) loss: 2.305179
# (Epoch 0 / 10) train acc: 0.108000; val_acc: 0.100600
# (Epoch 1 / 10) train acc: 0.130000; val_acc: 0.106800
# (Iteration 21 / 200) loss: 2.242805
# (Epoch 2 / 10) train acc: 0.170000; val_acc: 0.152800
# (Iteration 41 / 200) loss: 2.194127
# (Epoch 3 / 10) train acc: 0.194000; val_acc: 0.157800
# (Iteration 61 / 200) loss: 2.071387
# (Epoch 4 / 10) train acc: 0.191000; val_acc: 0.174200
# (Iteration 81 / 200) loss: 1.965151
# (Epoch 5 / 10) train acc: 0.229000; val_acc: 0.185800
# (Iteration 101 / 200) loss: 2.029896
# (Epoch 6 / 10) train acc: 0.233000; val_acc: 0.183400
# (Iteration 121 / 200) loss: 2.038638
# (Epoch 7 / 10) train acc: 0.241000; val_acc: 0.195800
# (Iteration 141 / 200) loss: 2.065465
# (Epoch 8 / 10) train acc: 0.245000; val_acc: 0.205200
# (Iteration 161 / 200) loss: 1.785807
# (Epoch 9 / 10) train acc: 0.223000; val_acc: 0.197000
# (Iteration 181 / 200) loss: 1.903525
# (Epoch 10 / 10) train acc: 0.243000; val_acc: 0.206600

# %% [markdown]
# Визуализируйте процесс обучения для двух сетей. Увеличилась ли скорость сходимости в случае с батч-нормализацией? Сделайте выводы.

# %% [markdown]
# ## Выводы
#
# Графики демонстрируют, что сеть, интегрированная с техникой пакетной нормализации, продемонстрировала лучшие результаты по сравнению с сетью без этой технологии. Конкретно, она показала более низкие уровни потерь при обучении, что указывает на более эффективное и стабильное уменьшение ошибок в процессе обучения. Точность обучения у этой сети увеличивается более резко и достигает высших значений быстрее, чем у стандартной сети. Это же преимущество наблюдается и в производительности на валидационной выборке: сеть с пакетной нормализацией выявляет себя более эффективной. Следовательно, включение пакетной нормализации в архитектуру нейронной сети способствует ускорению её обучения, достигая при этом лучших показателей точности и снижения ошибок как на этапе обучения, так и при валидации.

# %%
def plot_training_history(title, label, baseline, bn_solvers, plot_fn, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    bn_plots = [plot_fn(bn_solver) for bn_solver in bn_solvers]
    bl_plot = plot_fn(baseline)
    num_bn = len(bn_plots)
    for i in range(num_bn):
        label='with_norm'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
    label='baseline'
    if labels is not None:
        label += str(labels[0])
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', solver, [bn_solver], \
                      lambda x: x.loss_history, bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.train_acc_history, bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.val_acc_history, bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# Обучите 6-тислойную сеть с батч-нормализацией и без нее, используя разные размеры батча. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента.

# %% [markdown]
# # Выводы
#
# Нейронные сети, включающие в себя механизм пакетной нормализации, демонстрируют превосходство в точности как на этапе обучения, так и при проверке по сравнению с сетями, где данный метод не применяется. При этом, с ростом объема данных в пакете, эффективность сетей, использующих пакетную нормализацию, увеличивается, подчеркивая высокую работоспособность этого подхода при обработке больших партий данных. В отличие от них, сеть без механизма пакетной нормализации показывает менее удовлетворительные результаты обучения, что выражается в более низкой и менее ровной траектории увеличения точности. В итоге, применение пакетной нормализации способствует более гладкому и последовательному улучшению показателей сети со временем.

# %%
def run_batchsize_experiments(normalization_mode):
    np.random.seed(231)
    # Try training a very deep net with batchnorm
    hidden_dims = [100, 100, 100, 100, 100]
    num_train = 1000
    small_data = {
      'X_train': data['X_train'][:num_train],
      'y_train': data['y_train'][:num_train],
      'X_val': data['X_val'],
      'y_val': data['y_val'],
    }
    n_epochs=10
    weight_scale = 2e-2
    batch_sizes = [5,10,50]
    lr = 10**(-3.5)
    solver_bsize = batch_sizes[0]

    print('No normalization: batch size = ',solver_bsize)
    model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)
    solver = Solver(model, small_data,
                    num_epochs=n_epochs, batch_size=solver_bsize,
                    update_rule='adam',
                    optim_config={
                      'learning_rate': lr,
                    },
                    verbose=False)
    solver.train()
    
    bn_solvers = []
    for i in range(len(batch_sizes)):
        b_size=batch_sizes[i]
        print('Normalization: batch size = ',b_size)
        bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=normalization_mode)
        bn_solver = Solver(bn_model, small_data,
                        num_epochs=n_epochs, batch_size=b_size,
                        update_rule='adam',
                        optim_config={
                          'learning_rate': lr,
                        },
                        verbose=False)
        bn_solver.train()
        bn_solvers.append(bn_solver)
        
    return bn_solvers, solver, batch_sizes

batch_sizes = [5,10,50]
bn_solvers_bsize, solver_bsize, batch_sizes = run_batchsize_experiments('batchnorm')
# Out:
# No normalization: batch size =  5
# Normalization: batch size =  5
# Normalization: batch size =  10
# Normalization: batch size =  50

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.train_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.val_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# # Dropout

# %% [markdown]
# Реализуйте прямой проход для dropout-слоя в scripts/layers.py
#
# http://cs231n.github.io/neural-networks-2/#reg

# %%
np.random.seed(231)
x = np.random.randn(500, 500) + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
  out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean())
  print('Mean of train-time output: ', out.mean())
  print('Mean of test-time output: ', out_test.mean())
  print('Fraction of train-time output set to zero: ', (out == 0).mean())
  print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
  print()
# Out:
# Running tests with p =  0.25
# Mean of input:  10.000207878477502
# Mean of train-time output:  10.014059116977283
# Mean of test-time output:  10.000207878477502
# Fraction of train-time output set to zero:  0.749784
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.4
# Mean of input:  10.000207878477502
# Mean of train-time output:  9.977917658761159
# Mean of test-time output:  10.000207878477502
# Fraction of train-time output set to zero:  0.600796
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.7
# Mean of input:  10.000207878477502
# Mean of train-time output:  9.987811912159426
# Mean of test-time output:  10.000207878477502
# Fraction of train-time output set to zero:  0.30074
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# Реализуйте обратный проход для dropout-слоя

# %%
np.random.seed(231)
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  5.44560814873387e-11

# %% [markdown]
# Добавьте в реализацию класса FullyConnectedNet поддержку dropout. Если параметр dropout != 1, то добавьте в модель dropout-слой после каждого слоя активации. Проверьте свою реализацию

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [1, 0.75, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Relative errors should be around e-6 or less; Note that it's fine
  # if for dropout=1 you have W2 error be on the order of e-5.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  print()
# Out:
# Running check with dropout =  1
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
#
# Running check with dropout =  0.75
# Initial loss:  2.302371489704412
# W1 relative error: 1.90e-07
# W2 relative error: 4.76e-06
# W3 relative error: 2.60e-08
# b1 relative error: 4.73e-09
# b2 relative error: 1.82e-09
# b3 relative error: 1.70e-10
#
# Running check with dropout =  0.5
# Initial loss:  2.3042759220785896
# W1 relative error: 3.11e-07
# W2 relative error: 1.84e-08
# W3 relative error: 5.35e-08
# b1 relative error: 5.37e-09
# b2 relative error: 2.99e-09
# b3 relative error: 1.13e-10

# %% [markdown]
# Обучите две двухслойные сети с dropout-слоем (вероятность отсева 0,25) и без на наборе из 500 изображений. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента

# %% [markdown]
# # Выводы
#
# Из представленных графиков следует, что нейронная сеть, обученная без использования dropout, показывает лучшие результаты по сравнению с сетью, в которой применяется dropout с определенным коэффициентом. Сеть без механизма dropout отмечает устойчивый прирост точности на этапах обучения и валидации, достигая к концу процесса обучения заметно высших показателей эффективности. С другой стороны, сеть с включенным dropout показывает значительно меньший прирост точности как на обучающем, так и на валидационном наборах данных, что может свидетельствовать о ее недостаточной обученности.

# %%
# Train two identical nets, one with dropout and one without
np.random.seed(231)
num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [1, 0.25]
for dropout in dropout_choices:
  model = FullyConnectedNet([500], dropout=dropout)
  print(dropout)

  solver = Solver(model, small_data,
                  num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=100)
  solver.train()
  solvers[dropout] = solver
  print()
# Out:
# 1
# (Iteration 1 / 125) loss: 22.871692
# (Epoch 0 / 25) train acc: 0.134000; val_acc: 0.100000
# (Epoch 1 / 25) train acc: 0.080000; val_acc: 0.104800
# (Epoch 2 / 25) train acc: 0.104000; val_acc: 0.094600
# (Epoch 3 / 25) train acc: 0.172000; val_acc: 0.145600
# (Epoch 4 / 25) train acc: 0.172000; val_acc: 0.131400
# (Epoch 5 / 25) train acc: 0.132000; val_acc: 0.118400
# (Epoch 6 / 25) train acc: 0.226000; val_acc: 0.159600
# (Epoch 7 / 25) train acc: 0.164000; val_acc: 0.125000
# (Epoch 8 / 25) train acc: 0.130000; val_acc: 0.130400
# (Epoch 9 / 25) train acc: 0.172000; val_acc: 0.140800
# (Epoch 10 / 25) train acc: 0.170000; val_acc: 0.140000
# (Epoch 11 / 25) train acc: 0.176000; val_acc: 0.146400
# (Epoch 12 / 25) train acc: 0.210000; val_acc: 0.147000
# (Epoch 13 / 25) train acc: 0.230000; val_acc: 0.153800
# (Epoch 14 / 25) train acc: 0.254000; val_acc: 0.156000
# (Epoch 15 / 25) train acc: 0.262000; val_acc: 0.170000
# (Epoch 16 / 25) train acc: 0.258000; val_acc: 0.173200
# (Epoch 17 / 25) train acc: 0.264000; val_acc: 0.175000
# (Epoch 18 / 25) train acc: 0.268000; val_acc: 0.177200
# (Epoch 19 / 25) train acc: 0.298000; val_acc: 0.187200
# (Epoch 20 / 25) train acc: 0.284000; val_acc: 0.173600
# (Iteration 101 / 125) loss: 1.885645
# (Epoch 21 / 25) train acc: 0.284000; val_acc: 0.183800
# (Epoch 22 / 25) train acc: 0.312000; val_acc: 0.191800
# (Epoch 23 / 25) train acc: 0.310000; val_acc: 0.177600
# (Epoch 24 / 25) train acc: 0.308000; val_acc: 0.189400
# (Epoch 25 / 25) train acc: 0.304000; val_acc: 0.184000
#
# 0.25
# (Iteration 1 / 125) loss: 31.300647
# (Epoch 0 / 25) train acc: 0.100000; val_acc: 0.097200
# (Epoch 1 / 25) train acc: 0.108000; val_acc: 0.112000
# (Epoch 2 / 25) train acc: 0.232000; val_acc: 0.172200
# (Epoch 3 / 25) train acc: 0.142000; val_acc: 0.104800
# (Epoch 4 / 25) train acc: 0.098000; val_acc: 0.074200
# (Epoch 5 / 25) train acc: 0.138000; val_acc: 0.103800
# (Epoch 6 / 25) train acc: 0.132000; val_acc: 0.100000
# (Epoch 7 / 25) train acc: 0.130000; val_acc: 0.099200
# (Epoch 8 / 25) train acc: 0.126000; val_acc: 0.099000
# (Epoch 9 / 25) train acc: 0.126000; val_acc: 0.100200
# (Epoch 10 / 25) train acc: 0.140000; val_acc: 0.102000
# (Epoch 11 / 25) train acc: 0.142000; val_acc: 0.100600
# (Epoch 12 / 25) train acc: 0.140000; val_acc: 0.100800
# (Epoch 13 / 25) train acc: 0.144000; val_acc: 0.100000
# (Epoch 14 / 25) train acc: 0.144000; val_acc: 0.100200
# (Epoch 15 / 25) train acc: 0.144000; val_acc: 0.099800
# (Epoch 16 / 25) train acc: 0.144000; val_acc: 0.100200
# (Epoch 17 / 25) train acc: 0.144000; val_acc: 0.100200
# (Epoch 18 / 25) train acc: 0.144000; val_acc: 0.100400
# (Epoch 19 / 25) train acc: 0.144000; val_acc: 0.099600
# (Epoch 20 / 25) train acc: 0.144000; val_acc: 0.100400
# (Iteration 101 / 125) loss: 2.293558
# (Epoch 21 / 25) train acc: 0.146000; val_acc: 0.100000
# (Epoch 22 / 25) train acc: 0.144000; val_acc: 0.101000
# (Epoch 23 / 25) train acc: 0.146000; val_acc: 0.101000
# (Epoch 24 / 25) train acc: 0.150000; val_acc: 0.102200
# (Epoch 25 / 25) train acc: 0.148000; val_acc: 0.100000

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
  solver = solvers[dropout]
  train_accs.append(solver.train_acc_history[-1])
  val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].train_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].val_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Сверточные нейронные сети (CNN)

# %% [markdown]
# Реализуйте прямой проход для сверточного слоя - функция conv_forward_naive в scripts/layers.py юПроверьте свою реализацию, запустив код ниже

# %%
x_shape = (2, 3, 4, 4)
w_shape = (3, 3, 4, 4)
x = np.linspace(-0.1, 0.5, num=np.prod(x_shape)).reshape(x_shape)
w = np.linspace(-0.2, 0.3, num=np.prod(w_shape)).reshape(w_shape)
b = np.linspace(-0.1, 0.2, num=3)

conv_param = {'stride': 2, 'pad': 1}
out, _ = conv_forward_naive(x, w, b, conv_param)
correct_out = np.array([[[[-0.08759809, -0.10987781],
                           [-0.18387192, -0.2109216 ]],
                          [[ 0.21027089,  0.21661097],
                           [ 0.22847626,  0.23004637]],
                          [[ 0.50813986,  0.54309974],
                           [ 0.64082444,  0.67101435]]],
                         [[[-0.98053589, -1.03143541],
                           [-1.19128892, -1.24695841]],
                          [[ 0.69108355,  0.66880383],
                           [ 0.59480972,  0.56776003]],
                          [[ 2.36270298,  2.36904306],
                           [ 2.38090835,  2.38247847]]]])

# Compare your output to ours; difference should be around e-8
print('Testing conv_forward_naive')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing conv_forward_naive
# difference:  2.2121476417505994e-08

# %% [markdown]
# Реализуйте обратный проход - функция conv_backward_naive в scripts/layers.py

# %%
np.random.seed(231)
x = np.random.randn(4, 3, 5, 5)
w = np.random.randn(2, 3, 3, 3)
b = np.random.randn(2,)
dout = np.random.randn(4, 2, 5, 5)
conv_param = {'stride': 1, 'pad': 1}

dx_num = eval_numerical_gradient_array(lambda x: conv_forward_naive(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_forward_naive(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_forward_naive(x, w, b, conv_param)[0], b, dout)

out, cache = conv_forward_naive(x, w, b, conv_param)
dx, dw, db = conv_backward_naive(dout, cache)

# Your errors should be around e-8 or less.
print('Testing conv_backward_naive function')
print('dx error: ', rel_error(dx, dx_num))
print('dw error: ', rel_error(dw, dw_num))
print('db error: ', rel_error(db, db_num))
# Out:
# Testing conv_backward_naive function
# dx error:  1.159803161159293e-08
# dw error:  2.2471264748452487e-10
# db error:  3.37264006649648e-11

# %% [markdown]
# Реализуйте прямой проход для max-pooling слоя -функция  max_pool_forward_naive в scripts/layers.py

# %%
x_shape = (2, 3, 4, 4)
x = np.linspace(-0.3, 0.4, num=np.prod(x_shape)).reshape(x_shape)
pool_param = {'pool_width': 2, 'pool_height': 2, 'stride': 2}

out, _ = max_pool_forward_naive(x, pool_param)

correct_out = np.array([[[[-0.26315789, -0.24842105],
                          [-0.20421053, -0.18947368]],
                         [[-0.14526316, -0.13052632],
                          [-0.08631579, -0.07157895]],
                         [[-0.02736842, -0.01263158],
                          [ 0.03157895,  0.04631579]]],
                        [[[ 0.09052632,  0.10526316],
                          [ 0.14947368,  0.16421053]],
                         [[ 0.20842105,  0.22315789],
                          [ 0.26736842,  0.28210526]],
                         [[ 0.32631579,  0.34105263],
                          [ 0.38526316,  0.4       ]]]])

# Compare your output with ours. Difference should be on the order of e-8.
print('Testing max_pool_forward_naive function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing max_pool_forward_naive function:
# difference:  4.1666665157267834e-08

# %% [markdown]
# Реализуйте обратный проход для max-pooling слоя в max_pool_backward_naive .

# %%
np.random.seed(231)
x = np.random.randn(3, 2, 8, 8)
dout = np.random.randn(3, 2, 4, 4)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

dx_num = eval_numerical_gradient_array(lambda x: max_pool_forward_naive(x, pool_param)[0], x, dout)

out, cache = max_pool_forward_naive(x, pool_param)
dx = max_pool_backward_naive(dout, cache)

# Your error should be on the order of e-12
print('Testing max_pool_backward_naive function:')
print('dx error: ', rel_error(dx, dx_num))
# Out:
# Testing max_pool_backward_naive function:
# dx error:  3.27562514223145e-12

# %% [markdown]
# В скрипте scripts/fast_layers.py представлены быстрые реализации слоев свертки и пуллинга, написанных с использованием  Cython.
#
# Для компиляции выполните следующую команду в директории scripts
#
# ```bash
# python setup.py build_ext --inplace
# ```

# %% [markdown]
# Сравните ваши реализации слоев свертки и пуллинга с быстрыми реализациями.

# %%
# Rel errors should be around e-9 or less
from scripts.fast_layers import conv_forward_fast, conv_backward_fast
from time import time
np.random.seed(231)
x = np.random.randn(100, 3, 31, 31)
w = np.random.randn(25, 3, 3, 3)
b = np.random.randn(25,)
dout = np.random.randn(100, 25, 16, 16)
conv_param = {'stride': 2, 'pad': 1}

t0 = time()
out_naive, cache_naive = conv_forward_naive(x, w, b, conv_param)
t1 = time()
out_fast, cache_fast = conv_forward_fast(x, w, b, conv_param)
t2 = time()

print('Testing conv_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
print('Speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('Difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive, dw_naive, db_naive = conv_backward_naive(dout, cache_naive)
t1 = time()
dx_fast, dw_fast, db_fast = conv_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting conv_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
print('Speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('dx difference: ', rel_error(dx_naive, dx_fast))
print('dw difference: ', rel_error(dw_naive, dw_fast))
print('db difference: ', rel_error(db_naive, db_fast))
# Out:
# Testing conv_forward_fast:
# Naive: 1.942103s
# Fast: 0.005487s
# Speedup: 353.963847x
# Difference:  4.926407851494105e-11
#
# Testing conv_backward_fast:
# Naive: 2.994731s
# Fast: 0.005000s
# Speedup: 598.932434x
# dx difference:  1.949764775345631e-11
# dw difference:  4.957046344783224e-13
# db difference:  3.481354613192702e-14

# %%
# Relative errors should be close to 0.0
from scripts.fast_layers import max_pool_forward_fast, max_pool_backward_fast
np.random.seed(231)
x = np.random.randn(100, 3, 32, 32)
dout = np.random.randn(100, 3, 16, 16)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

t0 = time()
out_naive, cache_naive = max_pool_forward_naive(x, pool_param)
t1 = time()
out_fast, cache_fast = max_pool_forward_fast(x, pool_param)
t2 = time()

print('Testing pool_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive = max_pool_backward_naive(dout, cache_naive)
t1 = time()
dx_fast = max_pool_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting pool_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('dx difference: ', rel_error(dx_naive, dx_fast))
# Out:
# Testing pool_forward_fast:
# Naive: 0.159104s
# fast: 0.002556s
# speedup: 62.239414x
# difference:  0.0
#
# Testing pool_backward_fast:
# Naive: 0.470184s
# fast: 0.006936s
# speedup: 67.792815x
# dx difference:  0.0

# %% [markdown]
# В layer_utils.py вы можете найти  часто используемые комбинации слоев, используемых в сверточных сетях. Ознакомьтесь с ними и запустите код ниже для проверки их работы

# %%
from scripts.layer_utils import conv_relu_pool_forward, conv_relu_pool_backward
np.random.seed(231)
x = np.random.randn(2, 3, 16, 16)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

out, cache = conv_relu_pool_forward(x, w, b, conv_param, pool_param)
dx, dw, db = conv_relu_pool_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu_pool')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing conv_relu_pool
# dx error:  9.591132621921372e-09
# dw error:  5.802401370096438e-09
# db error:  1.0146343411762047e-09

# %%
from scripts.layer_utils import conv_relu_forward, conv_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 8, 8)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}

out, cache = conv_relu_forward(x, w, b, conv_param)
dx, dw, db = conv_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_forward(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_forward(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_forward(x, w, b, conv_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing conv_relu:
# dx error:  1.5218619980349303e-09
# dw error:  2.702022646099404e-10
# db error:  1.451272393591721e-10

# %% [markdown]
# Напишите реализацию класса ThreeLayerConvNet в scripts/classifiers/cnn.py . Вы можете использовать готовые реализации слоев и их комбинаций.

# %% [markdown]
# Проверьте вашу реализацию. Ожидается, что значение функции потерь softmax будет порядка `log(C)` для `C` классов для случая без регуляризации. В случае регуляризации значение функции потерь должно немного возрасти.

# %%
model = ThreeLayerConvNet()

N = 50
X = np.random.randn(N, 3, 32, 32)
y = np.random.randint(10, size=N)

loss, grads = model.loss(X, y)
print('Initial loss (no regularization): ', loss)

model.reg = 0.5
loss, grads = model.loss(X, y)
print('Initial loss (with regularization): ', loss)
# Out:
# Initial loss (no regularization):  2.302586071243987
# Initial loss (with regularization):  2.508255638232932

# %% [markdown]
# Проверьте реализацию обратного прохода

# %%
num_inputs = 2
input_dim = (3, 16, 16)
reg = 0.0
num_classes = 10
np.random.seed(231)
X = np.random.randn(num_inputs, *input_dim)
y = np.random.randint(num_classes, size=num_inputs)

model = ThreeLayerConvNet(num_filters=3, filter_size=3,
                          input_dim=input_dim, hidden_dim=7,
                          dtype=np.float64)
loss, grads = model.loss(X, y)
# Errors should be small, but correct implementations may have
# relative errors up to the order of e-2
for param_name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 1.380104e-04
# W2 max relative error: 1.822723e-02
# W3 max relative error: 3.064049e-04
# b1 max relative error: 3.477652e-05
# b2 max relative error: 2.516375e-03
# b3 max relative error: 7.945660e-10

# %% [markdown]
# Попробуйте добиться эффекта переобучения. Обучите модель на небольшом наборе данных.Сравните значения accuracy на обучающих данных и на валидационных. Визуализируйте графики обучения

# %%
np.random.seed(231)

num_train = 100
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

model = ThreeLayerConvNet(weight_scale=1e-2)

solver = Solver(model, small_data,
                num_epochs=30, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=1)
solver.train()
# Out:
# (Iteration 1 / 60) loss: 2.497258
# (Epoch 0 / 30) train acc: 0.100000; val_acc: 0.094000
# (Iteration 2 / 60) loss: 4.896987
# (Epoch 1 / 30) train acc: 0.140000; val_acc: 0.085000
# (Iteration 3 / 60) loss: 2.928631
# (Iteration 4 / 60) loss: 2.380989
# (Epoch 2 / 30) train acc: 0.090000; val_acc: 0.106000
# (Iteration 5 / 60) loss: 2.268877
# (Iteration 6 / 60) loss: 2.295504
# (Epoch 3 / 30) train acc: 0.230000; val_acc: 0.094000
# (Iteration 7 / 60) loss: 2.279244
# (Iteration 8 / 60) loss: 2.312382
# (Epoch 4 / 30) train acc: 0.240000; val_acc: 0.113000
# (Iteration 9 / 60) loss: 2.266993
# (Iteration 10 / 60) loss: 2.252097
# (Epoch 5 / 30) train acc: 0.370000; val_acc: 0.114000
# (Iteration 11 / 60) loss: 2.230121
# (Iteration 12 / 60) loss: 2.237582
# (Epoch 6 / 30) train acc: 0.240000; val_acc: 0.132000
# (Iteration 13 / 60) loss: 2.237010
# (Iteration 14 / 60) loss: 2.059196
# (Epoch 7 / 30) train acc: 0.490000; val_acc: 0.151000
# (Iteration 15 / 60) loss: 2.079127
# (Iteration 16 / 60) loss: 2.045732
# (Epoch 8 / 30) train acc: 0.260000; val_acc: 0.110000
# (Iteration 17 / 60) loss: 2.013468
# (Iteration 18 / 60) loss: 1.996848
# (Epoch 9 / 30) train acc: 0.590000; val_acc: 0.152000
# (Iteration 19 / 60) loss: 1.828294
# (Iteration 20 / 60) loss: 1.867094
# (Epoch 10 / 30) train acc: 0.640000; val_acc: 0.162000
# (Iteration 21 / 60) loss: 1.510767
# (Iteration 22 / 60) loss: 1.217806
# (Epoch 11 / 30) train acc: 0.490000; val_acc: 0.142000
# (Iteration 23 / 60) loss: 1.225989
# (Iteration 24 / 60) loss: 1.324907
# (Epoch 12 / 30) train acc: 0.570000; val_acc: 0.173000
# (Iteration 25 / 60) loss: 1.352729
# (Iteration 26 / 60) loss: 1.083249
# (Epoch 13 / 30) train acc: 0.720000; val_acc: 0.190000
# (Iteration 27 / 60) loss: 1.034824
# (Iteration 28 / 60) loss: 1.095869
# (Epoch 14 / 30) train acc: 0.830000; val_acc: 0.185000
# (Iteration 29 / 60) loss: 0.797988
# (Iteration 30 / 60) loss: 0.839295
# (Epoch 15 / 30) train acc: 0.850000; val_acc: 0.203000
# (Iteration 31 / 60) loss: 0.669815
# (Iteration 32 / 60) loss: 0.791398
# (Epoch 16 / 30) train acc: 0.870000; val_acc: 0.195000
# (Iteration 33 / 60) loss: 0.603607
# (Iteration 34 / 60) loss: 0.590800
# (Epoch 17 / 30) train acc: 0.830000; val_acc: 0.184000
# (Iteration 35 / 60) loss: 0.551332
# (Iteration 36 / 60) loss: 0.408104
# (Epoch 18 / 30) train acc: 0.890000; val_acc: 0.185000
# (Iteration 37 / 60) loss: 0.413171
# (Iteration 38 / 60) loss: 0.491568
# (Epoch 19 / 30) train acc: 0.900000; val_acc: 0.172000
# (Iteration 39 / 60) loss: 0.361985
# (Iteration 40 / 60) loss: 0.222675
# (Epoch 20 / 30) train acc: 0.940000; val_acc: 0.201000
# (Iteration 41 / 60) loss: 0.263916
# (Iteration 42 / 60) loss: 0.083359
# (Epoch 21 / 30) train acc: 0.920000; val_acc: 0.207000
# (Iteration 43 / 60) loss: 0.158568
# (Iteration 44 / 60) loss: 0.152928
# (Epoch 22 / 30) train acc: 0.960000; val_acc: 0.215000
# (Iteration 45 / 60) loss: 0.070885
# (Iteration 46 / 60) loss: 0.154067
# (Epoch 23 / 30) train acc: 0.990000; val_acc: 0.219000
# (Iteration 47 / 60) loss: 0.038505
# (Iteration 48 / 60) loss: 0.114879
# (Epoch 24 / 30) train acc: 0.990000; val_acc: 0.219000
# (Iteration 49 / 60) loss: 0.047004
# (Iteration 50 / 60) loss: 0.061275
# (Epoch 25 / 30) train acc: 1.000000; val_acc: 0.207000
# (Iteration 51 / 60) loss: 0.077392
# (Iteration 52 / 60) loss: 0.079282
# (Epoch 26 / 30) train acc: 0.990000; val_acc: 0.192000
# (Iteration 53 / 60) loss: 0.048489
# (Iteration 54 / 60) loss: 0.038668
# (Epoch 27 / 30) train acc: 1.000000; val_acc: 0.203000
# (Iteration 55 / 60) loss: 0.031143
# (Iteration 56 / 60) loss: 0.040044
# (Epoch 28 / 30) train acc: 0.990000; val_acc: 0.217000
# (Iteration 57 / 60) loss: 0.012991
# (Iteration 58 / 60) loss: 0.019647
# (Epoch 29 / 30) train acc: 1.000000; val_acc: 0.217000
# (Iteration 59 / 60) loss: 0.009951
# (Iteration 60 / 60) loss: 0.029344
# (Epoch 30 / 30) train acc: 1.000000; val_acc: 0.229000

# %%
# Print final training accuracy
print(
    "Small data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)
# Out:
# Small data training accuracy: 1.0

# %%
# Print final validation accuracy
print(
    "Small data validation accuracy:",
    solver.check_accuracy(small_data['X_val'], small_data['y_val'])
)
# Out:
# Small data validation accuracy: 0.229

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# Обучите сеть на полном наборе данных. Выведите accuracy на обучающей и валидационной выборках

# %%
model = ThreeLayerConvNet(weight_scale=0.001, hidden_dim=500, reg=0.001)

solver = Solver(model, data,
                num_epochs=1, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()
# Out:
# (Iteration 1 / 980) loss: 2.304594
# (Epoch 0 / 1) train acc: 0.095000; val_acc: 0.094000
# (Iteration 21 / 980) loss: 2.321204
# (Iteration 41 / 980) loss: 2.314598
# (Iteration 61 / 980) loss: 2.258189
# (Iteration 81 / 980) loss: 2.249962
# (Iteration 101 / 980) loss: 2.226018
# (Iteration 121 / 980) loss: 2.247858
# (Iteration 141 / 980) loss: 2.162471
# (Iteration 161 / 980) loss: 1.945202
# (Iteration 181 / 980) loss: 1.891377
# (Iteration 201 / 980) loss: 1.955837
# (Iteration 221 / 980) loss: 2.109055
# (Iteration 241 / 980) loss: 1.960261
# (Iteration 261 / 980) loss: 1.709180
# (Iteration 281 / 980) loss: 1.933283
# (Iteration 301 / 980) loss: 1.753624
# (Iteration 321 / 980) loss: 1.808990
# (Iteration 341 / 980) loss: 2.117996
# (Iteration 361 / 980) loss: 1.840804
# (Iteration 381 / 980) loss: 1.774547
# (Iteration 401 / 980) loss: 2.032634
# (Iteration 421 / 980) loss: 1.943798
# (Iteration 441 / 980) loss: 1.897597
# (Iteration 461 / 980) loss: 1.761784
# (Iteration 481 / 980) loss: 1.725905
# (Iteration 501 / 980) loss: 1.689433
# (Iteration 521 / 980) loss: 1.741730
# (Iteration 541 / 980) loss: 1.957039
# (Iteration 561 / 980) loss: 1.790617
# (Iteration 581 / 980) loss: 1.629242
# (Iteration 601 / 980) loss: 1.785187
# (Iteration 621 / 980) loss: 1.701421
# (Iteration 641 / 980) loss: 1.845366
# (Iteration 661 / 980) loss: 1.884435
# (Iteration 681 / 980) loss: 1.674860
# (Iteration 701 / 980) loss: 1.713178
# (Iteration 721 / 980) loss: 1.765916
# (Iteration 741 / 980) loss: 1.632049
# (Iteration 761 / 980) loss: 1.721373
# (Iteration 781 / 980) loss: 1.779825
# (Iteration 801 / 980) loss: 1.873528
# (Iteration 821 / 980) loss: 1.934025
# (Iteration 841 / 980) loss: 1.411440
# (Iteration 861 / 980) loss: 1.557531
# (Iteration 881 / 980) loss: 1.934384
# (Iteration 901 / 980) loss: 1.760732
# (Iteration 921 / 980) loss: 1.801632
# (Iteration 941 / 980) loss: 2.126993
# (Iteration 961 / 980) loss: 1.600684
# (Epoch 1 / 1) train acc: 0.401000; val_acc: 0.393000

# %%
# Print final training accuracy
print(
    "Full data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)
# Out:
# Full data training accuracy: 0.4

# %%
# Print final validation accuracy
print(
    "Full data validation accuracy:",
    solver.check_accuracy(data['X_val'], data['y_val'])
)
# Out:
# Full data validation accuracy: 0.393

# %% [markdown]
# Визуализируйте фильтры на первом слое обученной сети

# %%
from scripts.vis_utils import visualize_grid

grid = visualize_grid(model.params['W1'].transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(5, 5)
plt.show()
