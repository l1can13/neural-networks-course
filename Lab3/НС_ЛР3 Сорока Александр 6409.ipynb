# %% [markdown]
# # Лабораторная работа 3

# %% [markdown]
# 1) Полносвязная нейронная сеть ( Fully-Connected Neural Network)
#
# 2) Нормализация по мини-батчам (Batch normalization)
#
# 3) Dropout
#
# 4) Сверточные нейронные сети (Convolutional Networks)

# %% [markdown]
# Лабораторные работы можно выполнять с использованием сервиса Google Colaboratory (https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) или на локальном компьютере.

# %% [markdown]
# # Полносвязная нейронная сеть

# %% [markdown]
# В данной лабораторной работе необходимо будет реализовать полносвязную нейронную сеть, используя модульный подход. Для каждого  слоя реализации прямого и обратного проходов алгоритма обратного распространения ошибки будут иметь следующий вид:
#
# ```python
# def layer_forward(x, w):
#   """ Receive inputs x and weights w """
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   out = # the output
#
#   cache = (x, w, z, out) # Values we need to compute gradients
#
#   return out, cache
# ```
#
#
#
# ```python
# def layer_backward(dout, cache):
#   """
#   Receive dout (derivative of loss with respect to outputs) and cache,
#   and compute derivative with respect to inputs.
#   """
#   # Unpack cache values
#   x, w, z, out = cache
#
#   # Use values in cache to compute derivatives
#   dx = # Derivative of loss with respect to x
#   dw = # Derivative of loss with respect to w
#
#   return dx, dw
# ```

# %%
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from scripts.classifiers.fc_net import *

from scripts.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from scripts.solver import Solver
from scripts.classifiers.cnn import *
from scripts.layers import *
from scripts.fast_layers import *


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
def print_mean_std(x,axis=0):
    print('  means: ', x.mean(axis=axis))
    print('  stds:  ', x.std(axis=axis))
    print()

# %% [markdown]
# Загрузите данные из предыдущей лабораторной работы.

# %%
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
import numpy as np

# Загрузка CIFAR-10 датасета
(X, y), (X_test, y_test) = cifar10.load_data()

# Нормализация y
y = y.flatten()
y_test = y_test.flatten()

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=1000/50000, random_state=42)

X_train = X_train.transpose(0, 3, 1, 2)
X_val = X_val.transpose(0, 3, 1, 2)
X_test = X_test.transpose(0, 3, 1, 2)

data = {
    'X_train': X_train,
    'y_train': y_train,
    'X_val': X_val,
    'y_val': y_val,
    'X_test': X_test,
    'y_test': y_test
}

# %% [markdown]
# Для полносвязного слоя реализуйте прямой проход (метод affine_forward в scripts/layers.py). Протестируйте свою реализацию.

# %%
num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])


print('Testing affine_forward function:')
print(f'out: {out}\ncorrect_out: {correct_out}')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# out: [[1.49834967 1.70660132 1.91485297]
#  [3.25553199 3.5141327  3.77273342]]
# correct_out: [[1.49834967 1.70660132 1.91485297]
#  [3.25553199 3.5141327  3.77273342]]
# difference:  9.769849468192957e-10

# %% [markdown]
# Для полносвязного слоя реализуйте обратный проход (метод affine_backward в scripts/layers.py). Протестируйте свою реализацию.

# %%
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# Реализуйте прямой проход для слоя активации ReLU (relu_forward) и протестируйте его.

# %%
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# Реализуйте обратный проход для слоя активации ReLU (relu_backward ) и протестируйте его.

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# В скрипте /layer_utils.py приведены реализации прямого и обратного проходов для часто используемых комбинаций слоев. Например, за полносвязным слоем часто следует слой активации. Ознакомьтесь с функциями affine_relu_forward и affine_relu_backward, запустите код ниже и убедитесь, что ошибка порядка e-10 или ниже.

# %%
from scripts.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# Реализуйте двухслойную полносвязную сеть - класс TwoLayerNet в scripts/classifiers/fc_net.py . Проверьте свою реализацию, запустив код ниже.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.12e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 7.76e-10

# %% [markdown]
# Ознакомьтесь с API для обучения и тестирования моделей в scripts/solver.py . Используйте экземпляр класса Solver для обучения двухслойной полносвязной сети. Необходимо достичь минимум 50% верно классифицированных объектов на валидационном наборе.

# %%
model = TwoLayerNet()
solver = None

##############################################################################
# TODO: Use a Solver instance to train a TwoLayerNet that achieves at least  #
# 50% accuracy on the validation set.                                        #
##############################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

solver = Solver(model, data,
                update_rule='sgd',
                optim_config={
                  'learning_rate': 5e-4,
                },
                lr_decay=0.95,
                num_epochs=45, batch_size=200,
                print_every=1000)
solver.train()

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
##############################################################################
#                             END OF YOUR CODE                               #
##############################################################################
# Out:
# (Iteration 1 / 11025) loss: 2.311206
# (Epoch 0 / 45) train acc: 0.099000; val_acc: 0.100000
# (Epoch 1 / 45) train acc: 0.301000; val_acc: 0.279000
# (Epoch 2 / 45) train acc: 0.342000; val_acc: 0.362000
# (Epoch 3 / 45) train acc: 0.370000; val_acc: 0.369000
# (Epoch 4 / 45) train acc: 0.361000; val_acc: 0.370000
# (Iteration 1001 / 11025) loss: 1.656008
# (Epoch 5 / 45) train acc: 0.411000; val_acc: 0.416000
# (Epoch 6 / 45) train acc: 0.445000; val_acc: 0.439000
# (Epoch 7 / 45) train acc: 0.394000; val_acc: 0.407000
# (Epoch 8 / 45) train acc: 0.443000; val_acc: 0.436000
# (Iteration 2001 / 11025) loss: 1.504815
# (Epoch 9 / 45) train acc: 0.452000; val_acc: 0.446000
# (Epoch 10 / 45) train acc: 0.480000; val_acc: 0.445000
# (Epoch 11 / 45) train acc: 0.481000; val_acc: 0.466000
# (Epoch 12 / 45) train acc: 0.479000; val_acc: 0.474000
# (Iteration 3001 / 11025) loss: 1.475936
# (Epoch 13 / 45) train acc: 0.507000; val_acc: 0.472000
# (Epoch 14 / 45) train acc: 0.511000; val_acc: 0.472000
# (Epoch 15 / 45) train acc: 0.495000; val_acc: 0.471000
# (Epoch 16 / 45) train acc: 0.496000; val_acc: 0.469000
# (Iteration 4001 / 11025) loss: 1.390319
# (Epoch 17 / 45) train acc: 0.479000; val_acc: 0.463000
# (Epoch 18 / 45) train acc: 0.512000; val_acc: 0.469000
# (Epoch 19 / 45) train acc: 0.515000; val_acc: 0.473000
# (Epoch 20 / 45) train acc: 0.508000; val_acc: 0.484000
# (Iteration 5001 / 11025) loss: 1.405817
# (Epoch 21 / 45) train acc: 0.524000; val_acc: 0.478000
# (Epoch 22 / 45) train acc: 0.523000; val_acc: 0.469000
# (Epoch 23 / 45) train acc: 0.559000; val_acc: 0.485000
# (Epoch 24 / 45) train acc: 0.521000; val_acc: 0.485000
# (Iteration 6001 / 11025) loss: 1.261933
# (Epoch 25 / 45) train acc: 0.505000; val_acc: 0.506000
# (Epoch 26 / 45) train acc: 0.548000; val_acc: 0.489000
# (Epoch 27 / 45) train acc: 0.520000; val_acc: 0.491000
# (Epoch 28 / 45) train acc: 0.549000; val_acc: 0.495000
# (Iteration 7001 / 11025) loss: 1.315843
# (Epoch 29 / 45) train acc: 0.541000; val_acc: 0.505000
# (Epoch 30 / 45) train acc: 0.560000; val_acc: 0.497000
# (Epoch 31 / 45) train acc: 0.575000; val_acc: 0.509000
# (Epoch 32 / 45) train acc: 0.559000; val_acc: 0.503000
# (Iteration 8001 / 11025) loss: 1.235902
# (Epoch 33 / 45) train acc: 0.566000; val_acc: 0.501000
# (Epoch 34 / 45) train acc: 0.543000; val_acc: 0.497000
# (Epoch 35 / 45) train acc: 0.572000; val_acc: 0.499000
# (Epoch 36 / 45) train acc: 0.574000; val_acc: 0.495000
# (Iteration 9001 / 11025) loss: 1.093455
# (Epoch 37 / 45) train acc: 0.576000; val_acc: 0.515000
# (Epoch 38 / 45) train acc: 0.546000; val_acc: 0.512000
# (Epoch 39 / 45) train acc: 0.565000; val_acc: 0.501000
# (Epoch 40 / 45) train acc: 0.557000; val_acc: 0.504000
# (Iteration 10001 / 11025) loss: 1.379593
# (Epoch 41 / 45) train acc: 0.576000; val_acc: 0.510000
# (Epoch 42 / 45) train acc: 0.572000; val_acc: 0.514000
# (Epoch 43 / 45) train acc: 0.591000; val_acc: 0.506000
# (Epoch 44 / 45) train acc: 0.578000; val_acc: 0.503000
# (Iteration 11001 / 11025) loss: 1.203027
# (Epoch 45 / 45) train acc: 0.581000; val_acc: 0.514000

# %%
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %% [markdown]
# Теперь реализуйте полносвязную сеть с произвольным числом скрытых слоев. Ознакомьтесь с классом FullyConnectedNet в scripts/classifiers/fc_net.py . Реализуйте инициализацию, прямой и обратный проходы.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Most of the errors should be on the order of e-7 or smaller.   
  # NOTE: It is fine however to see an error for W2 on the order of e-5
  # for the check when reg = 0.0
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Running check with reg =  0
# Initial loss:  2.3004790897684924
# W1 relative error: 1.48e-07
# W2 relative error: 2.21e-05
# W3 relative error: 3.53e-07
# b1 relative error: 5.38e-09
# b2 relative error: 2.09e-09
# b3 relative error: 5.80e-11
# Running check with reg =  3.14
# Initial loss:  7.052114776533016
# W1 relative error: 7.36e-09
# W2 relative error: 6.87e-08
# W3 relative error: 3.48e-08
# b1 relative error: 1.48e-08
# b2 relative error: 1.72e-09
# b3 relative error: 1.80e-10

# %% [markdown]
# Попробуйте добиться эффекта переобучения на небольшом наборе изображений (например, 50). Используйте трехслойную сеть со 100 нейронами на каждом скрытом слое. Попробуйте переобучить сеть, достигнув 100 % accuracy за 20 эпох. Для этого поэкспериментируйте с параметрами weight_scale и learning_rate.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

weight_scale = 5e-2   # Заданный масштаб веса
learning_rate = 5e-4  # Заданная скорость обучения

train_acc = 0
iteration = 0

while train_acc < 1.0:
    print(f"\nИтерация: {iteration + 1}")
    model = FullyConnectedNet([100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver = Solver(model, small_data,
                    print_every=400, num_epochs=20, batch_size=25,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    verbose=True)
    solver.train()

    # Получение и вывод последней точности на обучающем наборе
    train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
    print(f'Final train accuracy after iteration {iteration + 1}: {train_acc}')

    if train_acc < 1.0:
        print("Train accuracy is less than 100%, trying again...")
        iteration += 1
    else:
        print("Reached 100% train accuracy!")
        
    # Визуализация истории потерь после достижения 100% точности
    if train_acc == 1.0:
        plt.plot(solver.loss_history, 'o')
        plt.title('Training loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Training loss')
        plt.show()
        break
# Out:
# Итерация: 1
# (Iteration 1 / 40) loss: 4.391118
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.097000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.111000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.082000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.092000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.107000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.103000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.102000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.116000
# (Epoch 13 / 20) train acc: 0.200000; val_acc: 0.115000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.110000
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 18 / 20) train acc: 0.200000; val_acc: 0.108000
# (Epoch 19 / 20) train acc: 0.180000; val_acc: 0.108000
# (Epoch 20 / 20) train acc: 0.200000; val_acc: 0.111000
# Final train accuracy after iteration 1: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 2
# (Iteration 1 / 40) loss: 6.015027
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.090000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.109000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.141000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.117000
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.133000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.110000
# (Epoch 8 / 20) train acc: 0.180000; val_acc: 0.124000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 10 / 20) train acc: 0.180000; val_acc: 0.109000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 12 / 20) train acc: 0.100000; val_acc: 0.101000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.105000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.105000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.105000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.107000
# (Epoch 19 / 20) train acc: 0.120000; val_acc: 0.107000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.117000
# Final train accuracy after iteration 2: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 3
# (Iteration 1 / 40) loss: 3.906726
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.130000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.107000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.124000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.116000
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.098000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.092000
# (Epoch 8 / 20) train acc: 0.220000; val_acc: 0.091000
# (Epoch 9 / 20) train acc: 0.100000; val_acc: 0.092000
# (Epoch 10 / 20) train acc: 0.180000; val_acc: 0.084000
# (Epoch 11 / 20) train acc: 0.200000; val_acc: 0.098000
# (Epoch 12 / 20) train acc: 0.180000; val_acc: 0.098000
# (Epoch 13 / 20) train acc: 0.220000; val_acc: 0.107000
# (Epoch 14 / 20) train acc: 0.220000; val_acc: 0.100000
# (Epoch 15 / 20) train acc: 0.180000; val_acc: 0.107000
# (Epoch 16 / 20) train acc: 0.180000; val_acc: 0.098000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.095000
# (Epoch 18 / 20) train acc: 0.180000; val_acc: 0.101000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.096000
# (Epoch 20 / 20) train acc: 0.220000; val_acc: 0.105000
# Final train accuracy after iteration 3: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 4
# (Iteration 1 / 40) loss: 6.980039
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.100000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.087000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 8 / 20) train acc: 0.200000; val_acc: 0.108000
# (Epoch 9 / 20) train acc: 0.180000; val_acc: 0.093000
# (Epoch 10 / 20) train acc: 0.180000; val_acc: 0.082000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.082000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.082000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.084000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.180000; val_acc: 0.097000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.096000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.096000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.096000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.097000
# Final train accuracy after iteration 4: 0.12
# Train accuracy is less than 100%, trying again...
#
# Итерация: 5
# (Iteration 1 / 40) loss: 4.193364
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.092000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.124000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.121000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.105000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.092000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.093000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.095000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.083000
# Final train accuracy after iteration 5: 0.2
# Train accuracy is less than 100%, trying again...
#
# Итерация: 6
# (Iteration 1 / 40) loss: 5.055694
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.095000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.111000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.089000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.084000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.102000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.109000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.115000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.110000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.095000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.111000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.111000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.111000
# Final train accuracy after iteration 6: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 7
# (Iteration 1 / 40) loss: 6.980485
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.200000; val_acc: 0.140000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.100000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.129000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.111000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 6 / 20) train acc: 0.180000; val_acc: 0.111000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.122000
# (Epoch 8 / 20) train acc: 0.200000; val_acc: 0.115000
# (Epoch 9 / 20) train acc: 0.200000; val_acc: 0.114000
# (Epoch 10 / 20) train acc: 0.180000; val_acc: 0.117000
# (Epoch 11 / 20) train acc: 0.100000; val_acc: 0.114000
# (Epoch 12 / 20) train acc: 0.180000; val_acc: 0.127000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.105000
# Final train accuracy after iteration 7: 0.2
# Train accuracy is less than 100%, trying again...
#
# Итерация: 8
# (Iteration 1 / 40) loss: 6.105603
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.104000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.109000
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.109000
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.113000
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.124000
# (Epoch 7 / 20) train acc: 0.240000; val_acc: 0.103000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.092000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.096000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.106000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.106000
# Final train accuracy after iteration 8: 0.26
# Train accuracy is less than 100%, trying again...
#
# Итерация: 9
# (Iteration 1 / 40) loss: 6.097667
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.060000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.090000
# Final train accuracy after iteration 9: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 10
# (Iteration 1 / 40) loss: 4.970595
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.087000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.088000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.087000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.100000; val_acc: 0.098000
# (Epoch 9 / 20) train acc: 0.200000; val_acc: 0.114000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.112000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 12 / 20) train acc: 0.200000; val_acc: 0.108000
# (Epoch 13 / 20) train acc: 0.180000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.099000
# (Epoch 15 / 20) train acc: 0.200000; val_acc: 0.109000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 17 / 20) train acc: 0.240000; val_acc: 0.107000
# (Epoch 18 / 20) train acc: 0.180000; val_acc: 0.109000
# (Epoch 19 / 20) train acc: 0.200000; val_acc: 0.108000
# (Epoch 20 / 20) train acc: 0.200000; val_acc: 0.110000
# Final train accuracy after iteration 10: 0.12
# Train accuracy is less than 100%, trying again...
#
# Итерация: 11
# (Iteration 1 / 40) loss: 4.215419
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.107000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.096000
# (Epoch 4 / 20) train acc: 0.200000; val_acc: 0.113000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.127000
# (Epoch 6 / 20) train acc: 0.280000; val_acc: 0.117000
# (Epoch 7 / 20) train acc: 0.300000; val_acc: 0.150000
# (Epoch 8 / 20) train acc: 0.220000; val_acc: 0.099000
# (Epoch 9 / 20) train acc: 0.240000; val_acc: 0.120000
# (Epoch 10 / 20) train acc: 0.280000; val_acc: 0.119000
# (Epoch 11 / 20) train acc: 0.280000; val_acc: 0.137000
# (Epoch 12 / 20) train acc: 0.280000; val_acc: 0.146000
# (Epoch 13 / 20) train acc: 0.180000; val_acc: 0.112000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.128000
# (Epoch 15 / 20) train acc: 0.300000; val_acc: 0.119000
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 17 / 20) train acc: 0.220000; val_acc: 0.111000
# (Epoch 18 / 20) train acc: 0.400000; val_acc: 0.133000
# (Epoch 19 / 20) train acc: 0.120000; val_acc: 0.093000
# (Epoch 20 / 20) train acc: 0.260000; val_acc: 0.120000
# Final train accuracy after iteration 11: 0.3
# Train accuracy is less than 100%, trying again...
#
# Итерация: 12
# (Iteration 1 / 40) loss: 5.745329
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.090000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.101000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.116000
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.116000
# (Epoch 8 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.101000
# Final train accuracy after iteration 12: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 13
# (Iteration 1 / 40) loss: 7.154243
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.096000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.096000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.096000
# (Epoch 8 / 20) train acc: 0.080000; val_acc: 0.100000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.098000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 11 / 20) train acc: 0.180000; val_acc: 0.110000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 13 / 20) train acc: 0.180000; val_acc: 0.109000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.108000
# (Epoch 15 / 20) train acc: 0.180000; val_acc: 0.117000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.118000
# (Epoch 18 / 20) train acc: 0.180000; val_acc: 0.117000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.109000
# Final train accuracy after iteration 13: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 14
# (Iteration 1 / 40) loss: 4.518825
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.093000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.084000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.092000
# (Epoch 4 / 20) train acc: 0.260000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.117000
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.097000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 9 / 20) train acc: 0.220000; val_acc: 0.086000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 12 / 20) train acc: 0.200000; val_acc: 0.094000
# (Epoch 13 / 20) train acc: 0.200000; val_acc: 0.098000
# (Epoch 14 / 20) train acc: 0.200000; val_acc: 0.106000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.111000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.109000
# (Epoch 17 / 20) train acc: 0.200000; val_acc: 0.125000
# (Epoch 18 / 20) train acc: 0.200000; val_acc: 0.119000
# (Epoch 19 / 20) train acc: 0.280000; val_acc: 0.132000
# (Epoch 20 / 20) train acc: 0.220000; val_acc: 0.105000
# Final train accuracy after iteration 14: 0.28
# Train accuracy is less than 100%, trying again...
#
# Итерация: 15
# (Iteration 1 / 40) loss: 6.978093
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.084000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.090000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 19 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.093000
# Final train accuracy after iteration 15: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 16
# (Iteration 1 / 40) loss: 5.622321
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.090000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.097000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.098000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.098000
# Final train accuracy after iteration 16: 0.12
# Train accuracy is less than 100%, trying again...
#
# Итерация: 17
# (Iteration 1 / 40) loss: 3.738697
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.096000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.105000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.126000
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.127000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.108000
# (Epoch 9 / 20) train acc: 0.080000; val_acc: 0.102000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.136000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.108000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.107000
# (Epoch 13 / 20) train acc: 0.120000; val_acc: 0.108000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.114000
# (Epoch 15 / 20) train acc: 0.180000; val_acc: 0.124000
# (Epoch 16 / 20) train acc: 0.200000; val_acc: 0.125000
# (Epoch 17 / 20) train acc: 0.180000; val_acc: 0.113000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.108000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.106000
# Final train accuracy after iteration 17: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 18
# (Iteration 1 / 40) loss: 5.787297
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.106000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.131000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.119000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.132000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.131000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.121000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.118000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.119000
# (Epoch 11 / 20) train acc: 0.180000; val_acc: 0.107000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.098000
# (Epoch 15 / 20) train acc: 0.180000; val_acc: 0.101000
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.100000
# (Epoch 17 / 20) train acc: 0.180000; val_acc: 0.104000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 20 / 20) train acc: 0.180000; val_acc: 0.104000
# Final train accuracy after iteration 18: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 19
# (Iteration 1 / 40) loss: 5.341589
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.113000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 5 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 6 / 20) train acc: 0.220000; val_acc: 0.118000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.120000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.103000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.097000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.088000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.089000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 17 / 20) train acc: 0.180000; val_acc: 0.106000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.097000
# (Epoch 19 / 20) train acc: 0.140000; val_acc: 0.123000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.098000
# Final train accuracy after iteration 19: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 20
# (Iteration 1 / 40) loss: 3.667199
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.082000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.087000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.100000; val_acc: 0.088000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.101000
# (Epoch 10 / 20) train acc: 0.100000; val_acc: 0.089000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 12 / 20) train acc: 0.100000; val_acc: 0.089000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 18 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 19 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 20 / 20) train acc: 0.120000; val_acc: 0.104000
# Final train accuracy after iteration 20: 0.1
# Train accuracy is less than 100%, trying again...
#
# Итерация: 21
# (Iteration 1 / 40) loss: 4.946576
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.103000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.127000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.106000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.114000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.113000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.113000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.110000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.117000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.119000
# (Epoch 16 / 20) train acc: 0.200000; val_acc: 0.116000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.112000
# Final train accuracy after iteration 21: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 22
# (Iteration 1 / 40) loss: 3.562918
# (Epoch 0 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.120000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.132000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.083000
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.109000
# (Epoch 10 / 20) train acc: 0.080000; val_acc: 0.104000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.104000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.103000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.105000
# Final train accuracy after iteration 22: 0.18
# Train accuracy is less than 100%, trying again...
#
# Итерация: 23
# (Iteration 1 / 40) loss: 6.360246
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.084000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.118000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.077000
# (Epoch 5 / 20) train acc: 0.200000; val_acc: 0.109000
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.082000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.094000
# (Epoch 8 / 20) train acc: 0.100000; val_acc: 0.074000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 12 / 20) train acc: 0.180000; val_acc: 0.126000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.130000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.108000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.105000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.090000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.090000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.101000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.101000
# Final train accuracy after iteration 23: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 24
# (Iteration 1 / 40) loss: 3.455787
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.075000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.092000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.092000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.079000
# (Epoch 11 / 20) train acc: 0.180000; val_acc: 0.095000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.092000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.092000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.094000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.095000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.094000
# Final train accuracy after iteration 24: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 25
# (Iteration 1 / 40) loss: 3.149541
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.113000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.106000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 6 / 20) train acc: 0.200000; val_acc: 0.124000
# (Epoch 7 / 20) train acc: 0.220000; val_acc: 0.145000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 9 / 20) train acc: 0.200000; val_acc: 0.093000
# (Epoch 10 / 20) train acc: 0.100000; val_acc: 0.090000
# (Epoch 11 / 20) train acc: 0.200000; val_acc: 0.103000
# (Epoch 12 / 20) train acc: 0.200000; val_acc: 0.110000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.102000
# (Epoch 14 / 20) train acc: 0.100000; val_acc: 0.089000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 17 / 20) train acc: 0.120000; val_acc: 0.123000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.091000
# (Epoch 19 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.093000
# Final train accuracy after iteration 25: 0.22
# Train accuracy is less than 100%, trying again...
#
# Итерация: 26
# (Iteration 1 / 40) loss: 4.739103
# (Epoch 0 / 20) train acc: 0.040000; val_acc: 0.097000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.090000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.108000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.097000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.109000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.086000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.100000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 14 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 19 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.094000
# Final train accuracy after iteration 26: 0.12
# Train accuracy is less than 100%, trying again...
#
# Итерация: 27
# (Iteration 1 / 40) loss: 9.648306
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.090000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.140000; val_acc: 0.083000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.092000
# (Epoch 6 / 20) train acc: 0.100000; val_acc: 0.091000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.091000
# (Epoch 8 / 20) train acc: 0.120000; val_acc: 0.089000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.089000
# (Epoch 10 / 20) train acc: 0.120000; val_acc: 0.089000
# (Epoch 11 / 20) train acc: 0.120000; val_acc: 0.085000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.088000
# (Epoch 13 / 20) train acc: 0.100000; val_acc: 0.094000
# (Epoch 14 / 20) train acc: 0.100000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.100000; val_acc: 0.094000
# (Epoch 16 / 20) train acc: 0.100000; val_acc: 0.095000
# (Epoch 17 / 20) train acc: 0.100000; val_acc: 0.095000
# (Epoch 18 / 20) train acc: 0.100000; val_acc: 0.095000
# (Epoch 19 / 20) train acc: 0.100000; val_acc: 0.095000
# (Epoch 20 / 20) train acc: 0.100000; val_acc: 0.096000
# Final train accuracy after iteration 27: 0.16
# Train accuracy is less than 100%, trying again...
#
# Итерация: 28
# (Iteration 1 / 40) loss: 3.888840
# (Epoch 0 / 20) train acc: 0.200000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.091000
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.126000
# (Epoch 3 / 20) train acc: 0.080000; val_acc: 0.097000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.149000
# (Epoch 6 / 20) train acc: 0.160000; val_acc: 0.105000
# (Epoch 7 / 20) train acc: 0.140000; val_acc: 0.117000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 9 / 20) train acc: 0.240000; val_acc: 0.141000
# (Epoch 10 / 20) train acc: 0.180000; val_acc: 0.114000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 12 / 20) train acc: 0.120000; val_acc: 0.108000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.077000
# (Epoch 14 / 20) train acc: 0.180000; val_acc: 0.107000
# (Epoch 15 / 20) train acc: 0.220000; val_acc: 0.099000
# (Epoch 16 / 20) train acc: 0.200000; val_acc: 0.106000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 18 / 20) train acc: 0.240000; val_acc: 0.104000
# (Epoch 19 / 20) train acc: 0.260000; val_acc: 0.107000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.095000
# Final train accuracy after iteration 28: 0.18
# Train accuracy is less than 100%, trying again...
#
# Итерация: 29
# (Iteration 1 / 40) loss: 6.200622
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.086000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.093000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.060000; val_acc: 0.081000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 6 / 20) train acc: 0.240000; val_acc: 0.107000
# (Epoch 7 / 20) train acc: 0.180000; val_acc: 0.113000
# (Epoch 8 / 20) train acc: 0.180000; val_acc: 0.114000
# (Epoch 9 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 10 / 20) train acc: 0.140000; val_acc: 0.093000
# (Epoch 11 / 20) train acc: 0.180000; val_acc: 0.132000
# (Epoch 12 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 13 / 20) train acc: 0.160000; val_acc: 0.107000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.112000
# (Epoch 15 / 20) train acc: 0.140000; val_acc: 0.098000
# (Epoch 16 / 20) train acc: 0.140000; val_acc: 0.098000
# (Epoch 17 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 18 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 19 / 20) train acc: 0.140000; val_acc: 0.099000
# (Epoch 20 / 20) train acc: 0.140000; val_acc: 0.099000
# Final train accuracy after iteration 29: 0.18
# Train accuracy is less than 100%, trying again...
#
# Итерация: 30
# (Iteration 1 / 40) loss: 6.937555
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.088000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.110000
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.099000
# (Epoch 4 / 20) train acc: 0.120000; val_acc: 0.090000
# (Epoch 5 / 20) train acc: 0.120000; val_acc: 0.099000
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.092000
# (Epoch 7 / 20) train acc: 0.120000; val_acc: 0.099000
# (Epoch 8 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 9 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 10 / 20) train acc: 0.100000; val_acc: 0.090000
# (Epoch 11 / 20) train acc: 0.140000; val_acc: 0.089000
# (Epoch 12 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 13 / 20) train acc: 0.140000; val_acc: 0.096000
# (Epoch 14 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 15 / 20) train acc: 0.160000; val_acc: 0.098000
# (Epoch 16 / 20) train acc: 0.160000; val_acc: 0.098000
# (Epoch 17 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 18 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 19 / 20) train acc: 0.160000; val_acc: 0.099000
# (Epoch 20 / 20) train acc: 0.160000; val_acc: 0.099000
# Final train accuracy after iteration 30: 0.12
# Train accuracy is less than 100%, trying again...
#
# Итерация: 31
# (Iteration 1 / 40) loss: 4.471355
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.100000; val_acc: 0.098000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.091000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.083000
# (Epoch 5 / 20) train acc: 0.100000; val_acc: 0.093000
# (Epoch 6 / 20) train acc: 0.120000; val_acc: 0.118000
# (Epoch 7 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 8 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 9 / 20) train acc: 0.120000; val_acc: 0.086000
# (Epoch 10 / 20) train acc: 0.160000; val_acc: 0.098000
# (Epoch 11 / 20) train acc: 0.160000; val_acc: 0.093000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 28
#      20 model = FullyConnectedNet([100, 100], weight_scale=weight_scale, dtype=np.float64)
#      21 solver = Solver(model, small_data,
#      22                 print_every=400, num_epochs=20, batch_size=25,
#      23                 update_rule='sgd',
#    (...)
#      26                 },
#      27                 verbose=True)
# ---> 28 solver.train()
#      30 # Получение и вывод последней точности на обучающем наборе
#      31 train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\solver.py:288, in Solver.train(self)
#     284 if first_it or last_it or epoch_end:
#     285     train_acc = self.check_accuracy(
#     286         self.X_train, self.y_train, num_samples=self.num_train_samples
#     287     )
# --> 288     val_acc = self.check_accuracy(
#     289         self.X_val, self.y_val, num_samples=self.num_val_samples
#     290     )
#     291     self.train_acc_history.append(train_acc)
#     292     self.val_acc_history.append(val_acc)
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\solver.py:247, in Solver.check_accuracy(self, X, y, num_samples, batch_size)
#     245     start = i * batch_size
#     246     end = (i + 1) * batch_size
# --> 247     scores = self.model.loss(X[start:end])
#     248     y_pred.append(np.argmax(scores, axis=1))
#     249 y_pred = np.hstack(y_pred)
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\classifiers\fc_net.py:317, in FullyConnectedNet.loss(self, X, y)
#     314     caches[layer_index] = (fc_cache, bn_cache, relu_cache)
#     315 else:
#     316     # Прямой проход через комбинированный слой affine + ReLU
# --> 317     layer_output, cache = affine_relu_forward(layer_input, self.params[weight_key], self.params[bias_key])
#     318     caches[layer_index] = cache
#     320 # Если используется dropout
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\layer_utils.py:23, in affine_relu_forward(x, w, b)
#      11 """
#      12 Convenience layer that perorms an affine transform followed by a ReLU
#      13
#    (...)
#      20 - cache: Object to give to the backward pass
#      21 """
#      22 a, fc_cache = affine_forward(x, w, b)
# ---> 23 out, relu_cache = relu_forward(a)
#      24 cache = (fc_cache, relu_cache)
#      25 return out, cache
#
# File ~\PycharmProjects\neural-networks-course\Lab3\scripts\layers.py:93, in relu_forward(x)
#      87 out = None
#      88 ###########################################################################
#      89 # TODO: Implement the ReLU forward pass.                                  #
#      90 ###########################################################################
#      91 # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# ---> 93 out = np.where(x > 0, x, 0)
#      95 # *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
#      96 ###########################################################################
#      97 #                             END OF YOUR CODE                            #
#      98 ###########################################################################
#      99 cache = x
#
# KeyboardInterrupt:

# %% [markdown]
# Повторите эксперимент, описанный выше, для пятислойной сети.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by 
# tweaking just the learning rate and initialization scale.

# Предполагается, что данные CIFAR-10 уже загружены в переменную data
num_train = 50
small_data = {
    'X_train': data['X_train'][:num_train],
    'y_train': data['y_train'][:num_train],
    'X_val': data['X_val'],
    'y_val': data['y_val'],
}

weight_scale = 0.1   # Обновленный масштаб веса
learning_rate = 5e-4    # Обновленная скорость обучения

train_acc = 0
iteration = 0

while train_acc < 1.0:
    print(f"\nИтерация: {iteration + 1}")
    model = FullyConnectedNet([100, 100, 100, 100], weight_scale=weight_scale, dtype=np.float64)
    solver = Solver(model, small_data,
                    print_every=10, num_epochs=20, batch_size=25,
                    update_rule='sgd',
                    optim_config={
                      'learning_rate': learning_rate,
                    },
                    verbose=True)
    solver.train()

    # Получение и вывод последней точности на обучающем наборе
    train_acc = solver.check_accuracy(small_data['X_train'], small_data['y_train'], num_samples=None)
    print(f'Final train accuracy after iteration {iteration + 1}: {train_acc}')

    if train_acc < 1.0:
        print("Train accuracy is less than 100%, trying again...")
        iteration += 1
    else:
        print("Reached 100% train accuracy!")

    # Визуализация истории потерь после достижения 100% точности
    if train_acc == 1.0:
        plt.plot(solver.loss_history, 'o')
        plt.title('Training loss history')
        plt.xlabel('Iteration')
        plt.ylabel('Training loss')
        plt.show()
        break
# Out:
# Итерация: 1
# (Iteration 1 / 40) loss: 94.634878
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.107000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.104000
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.092000
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.113000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.106000
# (Iteration 11 / 40) loss: 13.016672
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.108000
# (Epoch 7 / 20) train acc: 0.540000; val_acc: 0.116000
# (Epoch 8 / 20) train acc: 0.600000; val_acc: 0.101000
# (Epoch 9 / 20) train acc: 0.720000; val_acc: 0.109000
# (Epoch 10 / 20) train acc: 0.760000; val_acc: 0.105000
# (Iteration 21 / 40) loss: 1.362863
# (Epoch 11 / 20) train acc: 0.880000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.880000; val_acc: 0.103000
# (Epoch 13 / 20) train acc: 0.760000; val_acc: 0.109000
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.116000
# (Epoch 15 / 20) train acc: 0.860000; val_acc: 0.115000
# (Iteration 31 / 40) loss: 0.362284
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.120000
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.130000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.124000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.123000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.121000
# Final train accuracy after iteration 1: 0.98
# Train accuracy is less than 100%, trying again...
#
# Итерация: 2
# (Iteration 1 / 40) loss: 172.676615
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.082000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.129000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.111000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.085000
# (Epoch 4 / 20) train acc: 0.100000; val_acc: 0.108000
# (Epoch 5 / 20) train acc: 0.220000; val_acc: 0.120000
# (Iteration 11 / 40) loss: 25.144072
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.104000
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.118000
# (Epoch 8 / 20) train acc: 0.260000; val_acc: 0.122000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.109000
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.131000
# (Iteration 21 / 40) loss: 6.097848
# (Epoch 11 / 20) train acc: 0.540000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.600000; val_acc: 0.123000
# (Epoch 13 / 20) train acc: 0.780000; val_acc: 0.115000
# (Epoch 14 / 20) train acc: 0.820000; val_acc: 0.121000
# (Epoch 15 / 20) train acc: 0.920000; val_acc: 0.127000
# (Iteration 31 / 40) loss: 0.987204
# (Epoch 16 / 20) train acc: 0.740000; val_acc: 0.124000
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.138000
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.133000
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.138000
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.134000
# Final train accuracy after iteration 2: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 3
# (Iteration 1 / 40) loss: 196.123861
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.097000
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.106000
# (Epoch 2 / 20) train acc: 0.180000; val_acc: 0.093000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.117000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.103000
# (Iteration 11 / 40) loss: 13.690507
# (Epoch 6 / 20) train acc: 0.460000; val_acc: 0.112000
# (Epoch 7 / 20) train acc: 0.540000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.460000; val_acc: 0.105000
# (Epoch 9 / 20) train acc: 0.560000; val_acc: 0.109000
# (Epoch 10 / 20) train acc: 0.460000; val_acc: 0.119000
# (Iteration 21 / 40) loss: 3.701775
# (Epoch 11 / 20) train acc: 0.400000; val_acc: 0.094000
# (Epoch 12 / 20) train acc: 0.400000; val_acc: 0.097000
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.109000
# (Epoch 14 / 20) train acc: 0.580000; val_acc: 0.094000
# (Epoch 15 / 20) train acc: 0.760000; val_acc: 0.086000
# (Iteration 31 / 40) loss: 0.483101
# (Epoch 16 / 20) train acc: 0.800000; val_acc: 0.095000
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.092000
# (Epoch 18 / 20) train acc: 0.700000; val_acc: 0.105000
# (Epoch 19 / 20) train acc: 0.640000; val_acc: 0.111000
# (Epoch 20 / 20) train acc: 0.840000; val_acc: 0.104000
# Final train accuracy after iteration 3: 0.46
# Train accuracy is less than 100%, trying again...
#
# Итерация: 4
# (Iteration 1 / 40) loss: 259.324227
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.108000
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.115000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.300000; val_acc: 0.110000
# (Epoch 5 / 20) train acc: 0.360000; val_acc: 0.118000
# (Iteration 11 / 40) loss: 15.733460
# (Epoch 6 / 20) train acc: 0.460000; val_acc: 0.119000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.106000
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.114000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.115000
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.109000
# (Iteration 21 / 40) loss: 1.666221
# (Epoch 11 / 20) train acc: 0.560000; val_acc: 0.115000
# (Epoch 12 / 20) train acc: 0.680000; val_acc: 0.136000
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.128000
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.124000
# (Epoch 15 / 20) train acc: 0.800000; val_acc: 0.120000
# (Iteration 31 / 40) loss: 0.731960
# (Epoch 16 / 20) train acc: 0.560000; val_acc: 0.121000
# (Epoch 17 / 20) train acc: 0.820000; val_acc: 0.133000
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.127000
# (Epoch 19 / 20) train acc: 0.900000; val_acc: 0.121000
# (Epoch 20 / 20) train acc: 0.940000; val_acc: 0.125000
# Final train accuracy after iteration 4: 0.68
# Train accuracy is less than 100%, trying again...
#
# Итерация: 5
# (Iteration 1 / 40) loss: 214.652094
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.080000
# (Epoch 1 / 20) train acc: 0.060000; val_acc: 0.106000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.116000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.119000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.101000
# (Epoch 5 / 20) train acc: 0.300000; val_acc: 0.129000
# (Iteration 11 / 40) loss: 6.893948
# (Epoch 6 / 20) train acc: 0.420000; val_acc: 0.121000
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.126000
# (Epoch 8 / 20) train acc: 0.520000; val_acc: 0.137000
# (Epoch 9 / 20) train acc: 0.560000; val_acc: 0.144000
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.137000
# (Iteration 21 / 40) loss: 1.389947
# (Epoch 11 / 20) train acc: 0.600000; val_acc: 0.133000
# (Epoch 12 / 20) train acc: 0.740000; val_acc: 0.139000
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.145000
# (Epoch 14 / 20) train acc: 0.780000; val_acc: 0.149000
# (Epoch 15 / 20) train acc: 0.860000; val_acc: 0.136000
# (Iteration 31 / 40) loss: 0.213970
# (Epoch 16 / 20) train acc: 0.920000; val_acc: 0.141000
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.140000
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.139000
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.136000
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.141000
# Final train accuracy after iteration 5: 0.78
# Train accuracy is less than 100%, trying again...
#
# Итерация: 6
# (Iteration 1 / 40) loss: 156.241749
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.100000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.125000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.116000
# (Epoch 5 / 20) train acc: 0.360000; val_acc: 0.116000
# (Iteration 11 / 40) loss: 5.685260
# (Epoch 6 / 20) train acc: 0.400000; val_acc: 0.124000
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.104000
# (Epoch 8 / 20) train acc: 0.220000; val_acc: 0.100000
# (Epoch 9 / 20) train acc: 0.380000; val_acc: 0.105000
# (Epoch 10 / 20) train acc: 0.600000; val_acc: 0.106000
# (Iteration 21 / 40) loss: 2.687793
# (Epoch 11 / 20) train acc: 0.660000; val_acc: 0.112000
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.105000
# (Epoch 13 / 20) train acc: 0.700000; val_acc: 0.109000
# (Epoch 14 / 20) train acc: 0.680000; val_acc: 0.107000
# (Epoch 15 / 20) train acc: 0.720000; val_acc: 0.111000
# (Iteration 31 / 40) loss: 0.520236
# (Epoch 16 / 20) train acc: 0.820000; val_acc: 0.111000
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.104000
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.108000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.102000
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.109000
# Final train accuracy after iteration 6: 0.18
# Train accuracy is less than 100%, trying again...
#
# Итерация: 7
# (Iteration 1 / 40) loss: 179.356354
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.180000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.113000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.134000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.103000
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.134000
# (Iteration 11 / 40) loss: 15.691004
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.132000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.144000
# (Epoch 8 / 20) train acc: 0.320000; val_acc: 0.143000
# (Epoch 9 / 20) train acc: 0.400000; val_acc: 0.134000
# (Epoch 10 / 20) train acc: 0.520000; val_acc: 0.140000
# (Iteration 21 / 40) loss: 1.964400
# (Epoch 11 / 20) train acc: 0.580000; val_acc: 0.141000
# (Epoch 12 / 20) train acc: 0.700000; val_acc: 0.123000
# (Epoch 13 / 20) train acc: 0.680000; val_acc: 0.131000
# (Epoch 14 / 20) train acc: 0.780000; val_acc: 0.144000
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.145000
# (Iteration 31 / 40) loss: 0.462660
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.131000
# (Epoch 17 / 20) train acc: 0.960000; val_acc: 0.132000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.141000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.143000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.140000
# Final train accuracy after iteration 7: 0.84
# Train accuracy is less than 100%, trying again...
#
# Итерация: 8
# (Iteration 1 / 40) loss: 246.277192
# (Epoch 0 / 20) train acc: 0.040000; val_acc: 0.089000
# (Epoch 1 / 20) train acc: 0.120000; val_acc: 0.109000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.132000
# (Epoch 3 / 20) train acc: 0.240000; val_acc: 0.105000
# (Epoch 4 / 20) train acc: 0.200000; val_acc: 0.098000
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.102000
# (Iteration 11 / 40) loss: 10.918249
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.114000
# (Epoch 7 / 20) train acc: 0.380000; val_acc: 0.115000
# (Epoch 8 / 20) train acc: 0.640000; val_acc: 0.121000
# (Epoch 9 / 20) train acc: 0.620000; val_acc: 0.113000
# (Epoch 10 / 20) train acc: 0.720000; val_acc: 0.126000
# (Iteration 21 / 40) loss: 3.253058
# (Epoch 11 / 20) train acc: 0.800000; val_acc: 0.117000
# (Epoch 12 / 20) train acc: 0.920000; val_acc: 0.122000
# (Epoch 13 / 20) train acc: 0.900000; val_acc: 0.129000
# (Epoch 14 / 20) train acc: 0.900000; val_acc: 0.128000
# (Epoch 15 / 20) train acc: 0.920000; val_acc: 0.129000
# (Iteration 31 / 40) loss: 1.038438
# (Epoch 16 / 20) train acc: 0.940000; val_acc: 0.123000
# (Epoch 17 / 20) train acc: 0.980000; val_acc: 0.130000
# (Epoch 18 / 20) train acc: 0.960000; val_acc: 0.119000
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.115000
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.119000
# Final train accuracy after iteration 8: 0.14
# Train accuracy is less than 100%, trying again...
#
# Итерация: 9
# (Iteration 1 / 40) loss: 292.051542
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.111000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.121000
# (Epoch 2 / 20) train acc: 0.040000; val_acc: 0.098000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.106000
# (Epoch 4 / 20) train acc: 0.240000; val_acc: 0.103000
# (Epoch 5 / 20) train acc: 0.320000; val_acc: 0.099000
# (Iteration 11 / 40) loss: 9.521889
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.109000
# (Epoch 7 / 20) train acc: 0.340000; val_acc: 0.113000
# (Epoch 8 / 20) train acc: 0.540000; val_acc: 0.114000
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.108000
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.112000
# (Iteration 21 / 40) loss: 2.090288
# (Epoch 11 / 20) train acc: 0.540000; val_acc: 0.111000
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.120000
# (Epoch 13 / 20) train acc: 0.580000; val_acc: 0.118000
# (Epoch 14 / 20) train acc: 0.720000; val_acc: 0.108000
# (Epoch 15 / 20) train acc: 0.840000; val_acc: 0.111000
# (Iteration 31 / 40) loss: 0.364978
# (Epoch 16 / 20) train acc: 0.900000; val_acc: 0.121000
# (Epoch 17 / 20) train acc: 0.900000; val_acc: 0.129000
# (Epoch 18 / 20) train acc: 0.980000; val_acc: 0.129000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.125000
# (Epoch 20 / 20) train acc: 0.980000; val_acc: 0.128000
# Final train accuracy after iteration 9: 0.9
# Train accuracy is less than 100%, trying again...
#
# Итерация: 10
# (Iteration 1 / 40) loss: 345.979620
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.085000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.140000; val_acc: 0.095000
# (Epoch 3 / 20) train acc: 0.180000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.160000; val_acc: 0.093000
# (Epoch 5 / 20) train acc: 0.140000; val_acc: 0.129000
# (Iteration 11 / 40) loss: 23.935281
# (Epoch 6 / 20) train acc: 0.140000; val_acc: 0.117000
# (Epoch 7 / 20) train acc: 0.260000; val_acc: 0.108000
# (Epoch 8 / 20) train acc: 0.360000; val_acc: 0.112000
# (Epoch 9 / 20) train acc: 0.360000; val_acc: 0.146000
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.139000
# (Iteration 21 / 40) loss: 2.478710
# (Epoch 11 / 20) train acc: 0.500000; val_acc: 0.132000
# (Epoch 12 / 20) train acc: 0.640000; val_acc: 0.117000
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.111000
# (Epoch 14 / 20) train acc: 0.580000; val_acc: 0.116000
# (Epoch 15 / 20) train acc: 0.700000; val_acc: 0.115000
# (Iteration 31 / 40) loss: 1.632601
# (Epoch 16 / 20) train acc: 0.680000; val_acc: 0.122000
# (Epoch 17 / 20) train acc: 0.700000; val_acc: 0.107000
# (Epoch 18 / 20) train acc: 0.840000; val_acc: 0.120000
# (Epoch 19 / 20) train acc: 0.880000; val_acc: 0.116000
# (Epoch 20 / 20) train acc: 0.860000; val_acc: 0.111000
# Final train accuracy after iteration 10: 0.36
# Train accuracy is less than 100%, trying again...
#
# Итерация: 11
# (Iteration 1 / 40) loss: 327.536001
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.084000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.160000; val_acc: 0.109000
# (Epoch 3 / 20) train acc: 0.160000; val_acc: 0.118000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.115000
# (Epoch 5 / 20) train acc: 0.180000; val_acc: 0.100000
# (Iteration 11 / 40) loss: 18.906592
# (Epoch 6 / 20) train acc: 0.240000; val_acc: 0.105000
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.095000
# (Epoch 8 / 20) train acc: 0.440000; val_acc: 0.110000
# (Epoch 9 / 20) train acc: 0.380000; val_acc: 0.131000
# (Epoch 10 / 20) train acc: 0.440000; val_acc: 0.118000
# (Iteration 21 / 40) loss: 3.907648
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.121000
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.120000
# (Epoch 13 / 20) train acc: 0.580000; val_acc: 0.129000
# (Epoch 14 / 20) train acc: 0.740000; val_acc: 0.119000
# (Epoch 15 / 20) train acc: 0.820000; val_acc: 0.119000
# (Iteration 31 / 40) loss: 0.494626
# (Epoch 16 / 20) train acc: 0.780000; val_acc: 0.111000
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.133000
# (Epoch 18 / 20) train acc: 0.920000; val_acc: 0.128000
# (Epoch 19 / 20) train acc: 0.900000; val_acc: 0.127000
# (Epoch 20 / 20) train acc: 0.840000; val_acc: 0.120000
# Final train accuracy after iteration 11: 0.88
# Train accuracy is less than 100%, trying again...
#
# Итерация: 12
# (Iteration 1 / 40) loss: 192.364467
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.086000
# (Epoch 1 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 2 / 20) train acc: 0.120000; val_acc: 0.112000
# (Epoch 3 / 20) train acc: 0.140000; val_acc: 0.101000
# (Epoch 4 / 20) train acc: 0.180000; val_acc: 0.109000
# (Epoch 5 / 20) train acc: 0.260000; val_acc: 0.104000
# (Iteration 11 / 40) loss: 13.348223
# (Epoch 6 / 20) train acc: 0.360000; val_acc: 0.122000
# (Epoch 7 / 20) train acc: 0.440000; val_acc: 0.132000
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.142000
# (Epoch 9 / 20) train acc: 0.520000; val_acc: 0.136000
# (Epoch 10 / 20) train acc: 0.620000; val_acc: 0.139000
# (Iteration 21 / 40) loss: 4.034142
# (Epoch 11 / 20) train acc: 0.480000; val_acc: 0.138000
# (Epoch 12 / 20) train acc: 0.600000; val_acc: 0.128000
# (Epoch 13 / 20) train acc: 0.800000; val_acc: 0.128000
# (Epoch 14 / 20) train acc: 0.840000; val_acc: 0.130000
# (Epoch 15 / 20) train acc: 0.900000; val_acc: 0.138000
# (Iteration 31 / 40) loss: 0.190582
# (Epoch 16 / 20) train acc: 0.880000; val_acc: 0.137000
# (Epoch 17 / 20) train acc: 0.840000; val_acc: 0.133000
# (Epoch 18 / 20) train acc: 0.860000; val_acc: 0.136000
# (Epoch 19 / 20) train acc: 0.940000; val_acc: 0.142000
# (Epoch 20 / 20) train acc: 0.920000; val_acc: 0.142000
# Final train accuracy after iteration 12: 0.48
# Train accuracy is less than 100%, trying again...
#
# Итерация: 13
# (Iteration 1 / 40) loss: 182.687707
# (Epoch 0 / 20) train acc: 0.060000; val_acc: 0.106000
# (Epoch 1 / 20) train acc: 0.140000; val_acc: 0.115000
# (Epoch 2 / 20) train acc: 0.260000; val_acc: 0.125000
# (Epoch 3 / 20) train acc: 0.260000; val_acc: 0.096000
# (Epoch 4 / 20) train acc: 0.280000; val_acc: 0.098000
# (Epoch 5 / 20) train acc: 0.380000; val_acc: 0.097000
# (Iteration 11 / 40) loss: 11.570023
# (Epoch 6 / 20) train acc: 0.380000; val_acc: 0.107000
# (Epoch 7 / 20) train acc: 0.400000; val_acc: 0.125000
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.116000
# (Epoch 9 / 20) train acc: 0.420000; val_acc: 0.123000
# (Epoch 10 / 20) train acc: 0.480000; val_acc: 0.123000
# (Iteration 21 / 40) loss: 1.949300
# (Epoch 11 / 20) train acc: 0.560000; val_acc: 0.127000
# (Epoch 12 / 20) train acc: 0.620000; val_acc: 0.121000
# (Epoch 13 / 20) train acc: 0.640000; val_acc: 0.130000
# (Epoch 14 / 20) train acc: 0.640000; val_acc: 0.115000
# (Epoch 15 / 20) train acc: 0.780000; val_acc: 0.118000
# (Iteration 31 / 40) loss: 0.615287
# (Epoch 16 / 20) train acc: 0.840000; val_acc: 0.115000
# (Epoch 17 / 20) train acc: 0.800000; val_acc: 0.113000
# (Epoch 18 / 20) train acc: 0.840000; val_acc: 0.116000
# (Epoch 19 / 20) train acc: 0.860000; val_acc: 0.117000
# (Epoch 20 / 20) train acc: 0.720000; val_acc: 0.124000
# Final train accuracy after iteration 13: 0.64
# Train accuracy is less than 100%, trying again...
#
# Итерация: 14
# (Iteration 1 / 40) loss: 105.928509
# (Epoch 0 / 20) train acc: 0.160000; val_acc: 0.110000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.094000
# (Epoch 2 / 20) train acc: 0.060000; val_acc: 0.098000
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.131000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.130000
# (Epoch 5 / 20) train acc: 0.240000; val_acc: 0.124000
# (Iteration 11 / 40) loss: 21.622552
# (Epoch 6 / 20) train acc: 0.300000; val_acc: 0.119000
# (Epoch 7 / 20) train acc: 0.460000; val_acc: 0.133000
# (Epoch 8 / 20) train acc: 0.480000; val_acc: 0.121000
# (Epoch 9 / 20) train acc: 0.500000; val_acc: 0.116000
# (Epoch 10 / 20) train acc: 0.640000; val_acc: 0.126000
# (Iteration 21 / 40) loss: 2.398854
# (Epoch 11 / 20) train acc: 0.520000; val_acc: 0.131000
# (Epoch 12 / 20) train acc: 0.760000; val_acc: 0.125000
# (Epoch 13 / 20) train acc: 0.900000; val_acc: 0.131000
# (Epoch 14 / 20) train acc: 0.940000; val_acc: 0.132000
# (Epoch 15 / 20) train acc: 0.960000; val_acc: 0.135000
# (Iteration 31 / 40) loss: 0.171794
# (Epoch 16 / 20) train acc: 0.940000; val_acc: 0.126000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.140000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.141000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.141000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.142000
# Final train accuracy after iteration 14: 1.0
# Reached 100% train accuracy!

# %% [markdown]
# На 12 итерации получилась точность 1.0

# %% [markdown]
# Ранее обновление весов проходило по правилу SGD. Теперь попробуйте реализовать стохастический градиентный спуск с импульсом (SGD+momentum). http://cs231n.github.io/neural-networks-3/#sgd Реализуйте sgd_momentum в scripts/optim.py  и запустите проверку.

# %%
from scripts.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-3, 'velocity': v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print('next_w error: ', rel_error(next_w, expected_next_w))
print('velocity error: ', rel_error(expected_velocity, config['velocity']))

# %% [markdown]
# Сравните результаты обучения шестислойной сети, обученной классическим градиентным спуском и адаптивным алгоритмом с импульсом. Какой алгоритм сходится быстрее.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
  print('running with ', update_rule)
  model = FullyConnectedNet([100, 100, 100, 100, 100], weight_scale=5e-2)

  solver = Solver(model, small_data,
                  num_epochs=5, batch_size=100,
                  update_rule=update_rule,
                  optim_config={
                    'learning_rate': 5e-3,
                  },
                  verbose=True)
  solvers[update_rule] = solver
  solver.train()
  print()

plt.subplot(3, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(3, 1, 2)
plt.title('Training accuracy')
plt.xlabel('Epoch')

plt.subplot(3, 1, 3)
plt.title('Validation accuracy')
plt.xlabel('Epoch')

for update_rule, solver in solvers.items():
  plt.subplot(3, 1, 1)
  plt.plot(solver.loss_history, 'o', label="loss_%s" % update_rule)
  
  plt.subplot(3, 1, 2)
  plt.plot(solver.train_acc_history, '-o', label="train_acc_%s" % update_rule)

  plt.subplot(3, 1, 3)
  plt.plot(solver.val_acc_history, '-o', label="val_acc_%s" % update_rule)
  
for i in [1, 2, 3]:
  plt.subplot(3, 1, i)
  plt.legend(loc='upper center', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# Реализуйте алгоритмы RMSProp [1] and Adam [2] с коррекцией смещения  - методы rmsprop и adam .
#
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from scripts.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))

# %%
# Test Adam implementation
from scripts.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, _ = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))

# %% [markdown]
# Обучите пару глубоких сетей с испольованием RMSProp и Adam алгоритмов обновления весов и сравните результаты обучения.

# %% [markdown]
# Получите лучшую полносвязную сеть для классификации вашего набора данных. На наборе CIFAR-10 необходимо получить accuracy не ниже 50 % на валидационном наборе.

# %%
best_model = None
################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Инициализационные параметры
weight_scale = 1e-3
learning_rate = 1e-3
update_rules = ['rmsprop', 'adam']
best_val_acc = 0.0  # Сохраняем наилучшую точность на валидационном наборе
best_model = None

for update_rule in update_rules:
    print("\nОбучение с использованием", update_rule.upper())

    model = FullyConnectedNet([500, 250, 250], weight_scale=weight_scale, dtype=np.float32, seed=42)

    solver = Solver(model, data,
                    print_every=500,
                    num_epochs=30,
                    batch_size=250,
                    update_rule=update_rule,
                    optim_config={
                        'learning_rate': learning_rate,
                    },
                    lr_decay=0.9)

    solver.train()

    print("Точность валидации:", solver.best_val_acc)

    # Проверка и сохранение лучшей модели
    if solver.best_val_acc > best_val_acc:
        best_val_acc = solver.best_val_acc
        best_model = model

print("\nЛучшая точность валидации:", best_val_acc)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# %% [markdown]
# Получите оценку accuracy для валидационной и тестовой выборок.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())

# %% [markdown]
# # Нормализация по мини-батчам
#
# Идея нормализации по мини-батчам предложена в работе [1]
#
# [1] Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift", ICML 2015.

# %% [markdown]
# Реализуйте прямой проход для слоя батч-нормализации - функция batchnorm_forward в scripts/layers.py . Проверьте свою реализацию, запустив следующий код:

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after batch normalization   

# Simulate the forward pass for a two-layer network
np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before batch normalization:')
print_mean_std(a,axis=0)

gamma = np.ones((D3,))
beta = np.zeros((D3,))
# Means should be close to zero and stds close to one
print('After batch normalization (gamma=1, beta=0)')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)

gamma = np.asarray([1.0, 2.0, 3.0])
beta = np.asarray([11.0, 12.0, 13.0])
# Now means should be close to beta and stds close to gamma
print('After batch normalization (gamma=', gamma, ', beta=', beta, ')')
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print_mean_std(a_norm,axis=0)

# %%
# Check the test-time forward pass by running the training-time
# forward pass many times to warm up the running averages, and then
# checking the means and variances of activations after a test-time
# forward pass.

np.random.seed(231)
N, D1, D2, D3 = 200, 50, 60, 3
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)

bn_param = {'mode': 'train'}
gamma = np.ones(D3)
beta = np.zeros(D3)

for t in range(50):
  X = np.random.randn(N, D1)
  a = np.maximum(0, X.dot(W1)).dot(W2)
  batchnorm_forward(a, gamma, beta, bn_param)

bn_param['mode'] = 'test'
X = np.random.randn(N, D1)
a = np.maximum(0, X.dot(W1)).dot(W2)
a_norm, _ = batchnorm_forward(a, gamma, beta, bn_param)

# Means should be close to zero and stds close to one, but will be
# noisier than training-time forward passes.
print('After batch normalization (test-time):')
print_mean_std(a_norm,axis=0)

# %% [markdown]
# Реализуйте обратный проход в функции batchnorm_backward.

# %%
# Gradient check batchnorm backward pass
np.random.seed(231)
N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}
fx = lambda x: batchnorm_forward(x, gamma, beta, bn_param)[0]
fg = lambda a: batchnorm_forward(x, a, beta, bn_param)[0]
fb = lambda b: batchnorm_forward(x, gamma, b, bn_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma.copy(), dout)
db_num = eval_numerical_gradient_array(fb, beta.copy(), dout)

_, cache = batchnorm_forward(x, gamma, beta, bn_param)
dx, dgamma, dbeta = batchnorm_backward(dout, cache)
#You should expect to see relative errors between 1e-13 and 1e-8
print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))

# %% [markdown]
# Измените реализацию класса FullyConnectedNet, добавив батч-нормализацию.
# Если флаг normalization == "batchnorm", то вам необходимо вставить слой батч-нормализации перед каждым слоем активации ReLU, кроме выхода сети.

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

# You should expect losses between 1e-4~1e-10 for W, 
# losses between 1e-08~1e-10 for b,
# and losses between 1e-08~1e-09 for beta and gammas.
for reg in [0, 3.14]:
  print('Running check with reg = ', reg)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            reg=reg, weight_scale=5e-2, dtype=np.float64,
                            normalization='batchnorm')

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  if reg == 0: print()

# %% [markdown]
# Обучите 6-ти слойную сеть на наборе из 1000 изображений с батч-нормализацией и без нее

# %%
np.random.seed(231)
# Try training a very deep net with batchnorm
hidden_dims = [100, 100, 100, 100, 100]

num_train = 1000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 2e-2
bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization='batchnorm')
model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)

print('Solver with batch norm:')
bn_solver = Solver(bn_model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True,print_every=20)
bn_solver.train()

print('\nSolver without batch norm:')
solver = Solver(model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()

# %% [markdown]
# Визуализируйте процесс обучения для двух сетей. Увеличилась ли скорость сходимости в случае с батч-нормализацией? Сделайте выводы.

# %% [markdown]
# ## Выводы
#
# Графики демонстрируют, что сеть, интегрированная с техникой пакетной нормализации, продемонстрировала лучшие результаты по сравнению с сетью без этой технологии. Конкретно, она показала более низкие уровни потерь при обучении, что указывает на более эффективное и стабильное уменьшение ошибок в процессе обучения. Точность обучения у этой сети увеличивается более резко и достигает высших значений быстрее, чем у стандартной сети. Это же преимущество наблюдается и в производительности на валидационной выборке: сеть с пакетной нормализацией выявляет себя более эффективной. Следовательно, включение пакетной нормализации в архитектуру нейронной сети способствует ускорению её обучения, достигая при этом лучших показателей точности и снижения ошибок как на этапе обучения, так и при валидации.

# %%
def plot_training_history(title, label, baseline, bn_solvers, plot_fn, bl_marker='.', bn_marker='.', labels=None):
    """utility function for plotting training history"""
    plt.title(title)
    plt.xlabel(label)
    bn_plots = [plot_fn(bn_solver) for bn_solver in bn_solvers]
    bl_plot = plot_fn(baseline)
    num_bn = len(bn_plots)
    for i in range(num_bn):
        label='with_norm'
        if labels is not None:
            label += str(labels[i])
        plt.plot(bn_plots[i], bn_marker, label=label)
    label='baseline'
    if labels is not None:
        label += str(labels[0])
    plt.plot(bl_plot, bl_marker, label=label)
    plt.legend(loc='lower center', ncol=num_bn+1) 

    
plt.subplot(3, 1, 1)
plot_training_history('Training loss','Iteration', solver, [bn_solver], \
                      lambda x: x.loss_history, bl_marker='o', bn_marker='o')
plt.subplot(3, 1, 2)
plot_training_history('Training accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.train_acc_history, bl_marker='-o', bn_marker='-o')
plt.subplot(3, 1, 3)
plot_training_history('Validation accuracy','Epoch', solver, [bn_solver], \
                      lambda x: x.val_acc_history, bl_marker='-o', bn_marker='-o')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# Обучите 6-тислойную сеть с батч-нормализацией и без нее, используя разные размеры батча. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента.

# %% [markdown]
# # Выводы
#
# Нейронные сети, включающие в себя механизм пакетной нормализации, демонстрируют превосходство в точности как на этапе обучения, так и при проверке по сравнению с сетями, где данный метод не применяется. При этом, с ростом объема данных в пакете, эффективность сетей, использующих пакетную нормализацию, увеличивается, подчеркивая высокую работоспособность этого подхода при обработке больших партий данных. В отличие от них, сеть без механизма пакетной нормализации показывает менее удовлетворительные результаты обучения, что выражается в более низкой и менее ровной траектории увеличения точности. В итоге, применение пакетной нормализации способствует более гладкому и последовательному улучшению показателей сети со временем.

# %%
def run_batchsize_experiments(normalization_mode):
    np.random.seed(231)
    # Try training a very deep net with batchnorm
    hidden_dims = [100, 100, 100, 100, 100]
    num_train = 1000
    small_data = {
      'X_train': data['X_train'][:num_train],
      'y_train': data['y_train'][:num_train],
      'X_val': data['X_val'],
      'y_val': data['y_val'],
    }
    n_epochs=10
    weight_scale = 2e-2
    batch_sizes = [5,10,50]
    lr = 10**(-3.5)
    solver_bsize = batch_sizes[0]

    print('No normalization: batch size = ',solver_bsize)
    model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=None)
    solver = Solver(model, small_data,
                    num_epochs=n_epochs, batch_size=solver_bsize,
                    update_rule='adam',
                    optim_config={
                      'learning_rate': lr,
                    },
                    verbose=False)
    solver.train()
    
    bn_solvers = []
    for i in range(len(batch_sizes)):
        b_size=batch_sizes[i]
        print('Normalization: batch size = ',b_size)
        bn_model = FullyConnectedNet(hidden_dims, weight_scale=weight_scale, normalization=normalization_mode)
        bn_solver = Solver(bn_model, small_data,
                        num_epochs=n_epochs, batch_size=b_size,
                        update_rule='adam',
                        optim_config={
                          'learning_rate': lr,
                        },
                        verbose=False)
        bn_solver.train()
        bn_solvers.append(bn_solver)
        
    return bn_solvers, solver, batch_sizes

batch_sizes = [5,10,50]
bn_solvers_bsize, solver_bsize, batch_sizes = run_batchsize_experiments('batchnorm')

# %%
plt.subplot(2, 1, 1)
plot_training_history('Training accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.train_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)
plt.subplot(2, 1, 2)
plot_training_history('Validation accuracy (Batch Normalization)','Epoch', solver_bsize, bn_solvers_bsize, \
                      lambda x: x.val_acc_history, bl_marker='-^', bn_marker='-o', labels=batch_sizes)

plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# # Dropout

# %% [markdown]
# Реализуйте прямой проход для dropout-слоя в scripts/layers.py
#
# http://cs231n.github.io/neural-networks-2/#reg

# %%
np.random.seed(231)
x = np.random.randn(500, 500) + 10

for p in [0.25, 0.4, 0.7]:
  out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
  out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean())
  print('Mean of train-time output: ', out.mean())
  print('Mean of test-time output: ', out_test.mean())
  print('Fraction of train-time output set to zero: ', (out == 0).mean())
  print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
  print()

# %% [markdown]
# Реализуйте обратный проход для dropout-слоя

# %%
np.random.seed(231)
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.2, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

# Error should be around e-10 or less
print('dx relative error: ', rel_error(dx, dx_num))

# %% [markdown]
# Добавьте в реализацию класса FullyConnectedNet поддержку dropout. Если параметр dropout != 1, то добавьте в модель dropout-слой после каждого слоя активации. Проверьте свою реализацию

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [1, 0.75, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)
  
  # Relative errors should be around e-6 or less; Note that it's fine
  # if for dropout=1 you have W2 error be on the order of e-5.
  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
  print()

# %% [markdown]
# Обучите две двухслойные сети с dropout-слоем (вероятность отсева 0,25) и без на наборе из 500 изображений. Визуализируйте графики обучения. Сделайте выводы по результатам эксперимента

# %% [markdown]
# # Выводы
#
# Из представленных графиков следует, что нейронная сеть, обученная без использования dropout, показывает лучшие результаты по сравнению с сетью, в которой применяется dropout с определенным коэффициентом. Сеть без механизма dropout отмечает устойчивый прирост точности на этапах обучения и валидации, достигая к концу процесса обучения заметно высших показателей эффективности. С другой стороны, сеть с включенным dropout показывает значительно меньший прирост точности как на обучающем, так и на валидационном наборах данных, что может свидетельствовать о ее недостаточной обученности.
#
# **UPD (изменение lr=1e-4)**
#
# Из измененных результатов видно, что увеличение learning_rate до 1e-4 привело к улучшению обучения обеих моделей. Нейронная сеть без применения dropout продемонстрировала более значимый прирост точности как на обучающем, так и на валидационном наборах данных по сравнению с сетью, в которой использовался dropout с коэффициентом 0.25. Это указывает на то, что при данной скорости обучения модель без dropout лучше справляется с обучением и демонстрирует более высокую устойчивость.

# %%
# Train two identical nets, one with dropout and one without
np.random.seed(231)
num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [1, 0.25]
for dropout in dropout_choices:
  model = FullyConnectedNet([500], dropout=dropout)
  print(dropout)

  solver = Solver(model, small_data,
                  num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 1e-4,
                  },
                  verbose=True, print_every=100)
  solver.train()
  solvers[dropout] = solver
  print()
# Out:
# 1
# (Iteration 1 / 125) loss: 20.836255
# (Epoch 0 / 25) train acc: 0.092000; val_acc: 0.108000
# (Epoch 1 / 25) train acc: 0.126000; val_acc: 0.135000
# (Epoch 2 / 25) train acc: 0.166000; val_acc: 0.137000
# (Epoch 3 / 25) train acc: 0.192000; val_acc: 0.175000
# (Epoch 4 / 25) train acc: 0.168000; val_acc: 0.159000
# (Epoch 5 / 25) train acc: 0.200000; val_acc: 0.183000
# (Epoch 6 / 25) train acc: 0.224000; val_acc: 0.174000
# (Epoch 7 / 25) train acc: 0.296000; val_acc: 0.191000
# (Epoch 8 / 25) train acc: 0.276000; val_acc: 0.182000
# (Epoch 9 / 25) train acc: 0.282000; val_acc: 0.197000
# (Epoch 10 / 25) train acc: 0.340000; val_acc: 0.198000
# (Epoch 11 / 25) train acc: 0.308000; val_acc: 0.174000
# (Epoch 12 / 25) train acc: 0.406000; val_acc: 0.198000
# (Epoch 13 / 25) train acc: 0.376000; val_acc: 0.196000
# (Epoch 14 / 25) train acc: 0.378000; val_acc: 0.189000
# (Epoch 15 / 25) train acc: 0.424000; val_acc: 0.209000
# (Epoch 16 / 25) train acc: 0.398000; val_acc: 0.210000
# (Epoch 17 / 25) train acc: 0.472000; val_acc: 0.225000
# (Epoch 18 / 25) train acc: 0.506000; val_acc: 0.223000
# (Epoch 19 / 25) train acc: 0.500000; val_acc: 0.226000
# (Epoch 20 / 25) train acc: 0.560000; val_acc: 0.225000
# (Iteration 101 / 125) loss: 1.280828
# (Epoch 21 / 25) train acc: 0.612000; val_acc: 0.230000
# (Epoch 22 / 25) train acc: 0.598000; val_acc: 0.240000
# (Epoch 23 / 25) train acc: 0.604000; val_acc: 0.240000
# (Epoch 24 / 25) train acc: 0.614000; val_acc: 0.225000
# (Epoch 25 / 25) train acc: 0.624000; val_acc: 0.228000
#
# 0.25
# (Iteration 1 / 125) loss: 32.496304
# (Epoch 0 / 25) train acc: 0.158000; val_acc: 0.105000
# (Epoch 1 / 25) train acc: 0.162000; val_acc: 0.156000
# (Epoch 2 / 25) train acc: 0.226000; val_acc: 0.190000
# (Epoch 3 / 25) train acc: 0.230000; val_acc: 0.169000
# (Epoch 4 / 25) train acc: 0.190000; val_acc: 0.177000
# (Epoch 5 / 25) train acc: 0.194000; val_acc: 0.167000
# (Epoch 6 / 25) train acc: 0.196000; val_acc: 0.143000
# (Epoch 7 / 25) train acc: 0.190000; val_acc: 0.126000
# (Epoch 8 / 25) train acc: 0.192000; val_acc: 0.146000
# (Epoch 9 / 25) train acc: 0.186000; val_acc: 0.152000
# (Epoch 10 / 25) train acc: 0.178000; val_acc: 0.145000
# (Epoch 11 / 25) train acc: 0.186000; val_acc: 0.151000
# (Epoch 12 / 25) train acc: 0.222000; val_acc: 0.172000
# (Epoch 13 / 25) train acc: 0.208000; val_acc: 0.159000
# (Epoch 14 / 25) train acc: 0.204000; val_acc: 0.128000
# (Epoch 15 / 25) train acc: 0.250000; val_acc: 0.164000
# (Epoch 16 / 25) train acc: 0.282000; val_acc: 0.180000
# (Epoch 17 / 25) train acc: 0.268000; val_acc: 0.163000
# (Epoch 18 / 25) train acc: 0.268000; val_acc: 0.160000
# (Epoch 19 / 25) train acc: 0.272000; val_acc: 0.164000
# (Epoch 20 / 25) train acc: 0.256000; val_acc: 0.176000
# (Iteration 101 / 125) loss: 2.232838
# (Epoch 21 / 25) train acc: 0.260000; val_acc: 0.158000
# (Epoch 22 / 25) train acc: 0.250000; val_acc: 0.136000
# (Epoch 23 / 25) train acc: 0.252000; val_acc: 0.143000
# (Epoch 24 / 25) train acc: 0.242000; val_acc: 0.149000
# (Epoch 25 / 25) train acc: 0.262000; val_acc: 0.155000

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
  solver = solvers[dropout]
  train_accs.append(solver.train_acc_history[-1])
  val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].train_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].val_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# # Сверточные нейронные сети (CNN)

# %% [markdown]
# Реализуйте прямой проход для сверточного слоя - функция conv_forward_naive в scripts/layers.py юПроверьте свою реализацию, запустив код ниже

# %%
x_shape = (2, 3, 4, 4)
w_shape = (3, 3, 4, 4)
x = np.linspace(-0.1, 0.5, num=np.prod(x_shape)).reshape(x_shape)
w = np.linspace(-0.2, 0.3, num=np.prod(w_shape)).reshape(w_shape)
b = np.linspace(-0.1, 0.2, num=3)

conv_param = {'stride': 2, 'pad': 1}
out, _ = conv_forward_naive(x, w, b, conv_param)
correct_out = np.array([[[[-0.08759809, -0.10987781],
                           [-0.18387192, -0.2109216 ]],
                          [[ 0.21027089,  0.21661097],
                           [ 0.22847626,  0.23004637]],
                          [[ 0.50813986,  0.54309974],
                           [ 0.64082444,  0.67101435]]],
                         [[[-0.98053589, -1.03143541],
                           [-1.19128892, -1.24695841]],
                          [[ 0.69108355,  0.66880383],
                           [ 0.59480972,  0.56776003]],
                          [[ 2.36270298,  2.36904306],
                           [ 2.38090835,  2.38247847]]]])

# Compare your output to ours; difference should be around e-8
print('Testing conv_forward_naive')
print('difference: ', rel_error(out, correct_out))

# %% [markdown]
# Реализуйте обратный проход - функция conv_backward_naive в scripts/layers.py

# %%
np.random.seed(231)
x = np.random.randn(4, 3, 5, 5)
w = np.random.randn(2, 3, 3, 3)
b = np.random.randn(2,)
dout = np.random.randn(4, 2, 5, 5)
conv_param = {'stride': 1, 'pad': 1}

dx_num = eval_numerical_gradient_array(lambda x: conv_forward_naive(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_forward_naive(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_forward_naive(x, w, b, conv_param)[0], b, dout)

out, cache = conv_forward_naive(x, w, b, conv_param)
dx, dw, db = conv_backward_naive(dout, cache)

# Your errors should be around e-8 or less.
print('Testing conv_backward_naive function')
print('dx error: ', rel_error(dx, dx_num))
print('dw error: ', rel_error(dw, dw_num))
print('db error: ', rel_error(db, db_num))

# %% [markdown]
# Реализуйте прямой проход для max-pooling слоя -функция  max_pool_forward_naive в scripts/layers.py

# %%
x_shape = (2, 3, 4, 4)
x = np.linspace(-0.3, 0.4, num=np.prod(x_shape)).reshape(x_shape)
pool_param = {'pool_width': 2, 'pool_height': 2, 'stride': 2}

out, _ = max_pool_forward_naive(x, pool_param)

correct_out = np.array([[[[-0.26315789, -0.24842105],
                          [-0.20421053, -0.18947368]],
                         [[-0.14526316, -0.13052632],
                          [-0.08631579, -0.07157895]],
                         [[-0.02736842, -0.01263158],
                          [ 0.03157895,  0.04631579]]],
                        [[[ 0.09052632,  0.10526316],
                          [ 0.14947368,  0.16421053]],
                         [[ 0.20842105,  0.22315789],
                          [ 0.26736842,  0.28210526]],
                         [[ 0.32631579,  0.34105263],
                          [ 0.38526316,  0.4       ]]]])

# Compare your output with ours. Difference should be on the order of e-8.
print('Testing max_pool_forward_naive function:')
print('difference: ', rel_error(out, correct_out))

# %% [markdown]
# Реализуйте обратный проход для max-pooling слоя в max_pool_backward_naive .

# %%
np.random.seed(231)
x = np.random.randn(3, 2, 8, 8)
dout = np.random.randn(3, 2, 4, 4)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

dx_num = eval_numerical_gradient_array(lambda x: max_pool_forward_naive(x, pool_param)[0], x, dout)

out, cache = max_pool_forward_naive(x, pool_param)
dx = max_pool_backward_naive(dout, cache)

# Your error should be on the order of e-12
print('Testing max_pool_backward_naive function:')
print('dx error: ', rel_error(dx, dx_num))

# %% [markdown]
# В скрипте scripts/fast_layers.py представлены быстрые реализации слоев свертки и пуллинга, написанных с использованием  Cython.
#
# Для компиляции выполните следующую команду в директории scripts
#
# ```bash
# python setup.py build_ext --inplace
# ```

# %% [markdown]
# Сравните ваши реализации слоев свертки и пуллинга с быстрыми реализациями.

# %%
# Rel errors should be around e-9 or less
from scripts.fast_layers import conv_forward_fast, conv_backward_fast
from time import time
np.random.seed(231)
x = np.random.randn(100, 3, 31, 31)
w = np.random.randn(25, 3, 3, 3)
b = np.random.randn(25,)
dout = np.random.randn(100, 25, 16, 16)
conv_param = {'stride': 2, 'pad': 1}

t0 = time()
out_naive, cache_naive = conv_forward_naive(x, w, b, conv_param)
t1 = time()
out_fast, cache_fast = conv_forward_fast(x, w, b, conv_param)
t2 = time()

print('Testing conv_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
print('Speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('Difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive, dw_naive, db_naive = conv_backward_naive(dout, cache_naive)
t1 = time()
dx_fast, dw_fast, db_fast = conv_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting conv_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('Fast: %fs' % (t2 - t1))
print('Speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('dx difference: ', rel_error(dx_naive, dx_fast))
print('dw difference: ', rel_error(dw_naive, dw_fast))
print('db difference: ', rel_error(db_naive, db_fast))

# %%
# Relative errors should be close to 0.0
from scripts.fast_layers import max_pool_forward_fast, max_pool_backward_fast
np.random.seed(231)
x = np.random.randn(100, 3, 32, 32)
dout = np.random.randn(100, 3, 16, 16)
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

t0 = time()
out_naive, cache_naive = max_pool_forward_naive(x, pool_param)
t1 = time()
out_fast, cache_fast = max_pool_forward_fast(x, pool_param)
t2 = time()

print('Testing pool_forward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('difference: ', rel_error(out_naive, out_fast))

t0 = time()
dx_naive = max_pool_backward_naive(dout, cache_naive)
t1 = time()
dx_fast = max_pool_backward_fast(dout, cache_fast)
t2 = time()

print('\nTesting pool_backward_fast:')
print('Naive: %fs' % (t1 - t0))
print('fast: %fs' % (t2 - t1))
print('speedup: %fx' % ((t1 - t0) / (t2 - t1)))
print('dx difference: ', rel_error(dx_naive, dx_fast))

# %% [markdown]
# В layer_utils.py вы можете найти  часто используемые комбинации слоев, используемых в сверточных сетях. Ознакомьтесь с ними и запустите код ниже для проверки их работы

# %%
from scripts.layer_utils import conv_relu_pool_forward, conv_relu_pool_backward
np.random.seed(231)
x = np.random.randn(2, 3, 16, 16)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}
pool_param = {'pool_height': 2, 'pool_width': 2, 'stride': 2}

out, cache = conv_relu_pool_forward(x, w, b, conv_param, pool_param)
dx, dw, db = conv_relu_pool_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_pool_forward(x, w, b, conv_param, pool_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu_pool')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))

# %%
from scripts.layer_utils import conv_relu_forward, conv_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 8, 8)
w = np.random.randn(3, 3, 3, 3)
b = np.random.randn(3,)
dout = np.random.randn(2, 3, 8, 8)
conv_param = {'stride': 1, 'pad': 1}

out, cache = conv_relu_forward(x, w, b, conv_param)
dx, dw, db = conv_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: conv_relu_forward(x, w, b, conv_param)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: conv_relu_forward(x, w, b, conv_param)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: conv_relu_forward(x, w, b, conv_param)[0], b, dout)

# Relative errors should be around e-8 or less
print('Testing conv_relu:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))

# %% [markdown]
# Напишите реализацию класса ThreeLayerConvNet в scripts/classifiers/cnn.py . Вы можете использовать готовые реализации слоев и их комбинаций.

# %% [markdown]
# Проверьте вашу реализацию. Ожидается, что значение функции потерь softmax будет порядка `log(C)` для `C` классов для случая без регуляризации. В случае регуляризации значение функции потерь должно немного возрасти.

# %%
model = ThreeLayerConvNet()

N = 50
X = np.random.randn(N, 3, 32, 32)
y = np.random.randint(10, size=N)

loss, grads = model.loss(X, y)
print('Initial loss (no regularization): ', loss)

model.reg = 0.5
loss, grads = model.loss(X, y)
print('Initial loss (with regularization): ', loss)

# %% [markdown]
# Проверьте реализацию обратного прохода

# %%
num_inputs = 2
input_dim = (3, 16, 16)
reg = 0.0
num_classes = 10
np.random.seed(231)
X = np.random.randn(num_inputs, *input_dim)
y = np.random.randint(num_classes, size=num_inputs)

model = ThreeLayerConvNet(num_filters=3, filter_size=3,
                          input_dim=input_dim, hidden_dim=7,
                          dtype=np.float64)
loss, grads = model.loss(X, y)
# Errors should be small, but correct implementations may have
# relative errors up to the order of e-2
for param_name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[param_name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[param_name])
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))

# %% [markdown]
# Попробуйте добиться эффекта переобучения. Обучите модель на небольшом наборе данных.Сравните значения accuracy на обучающих данных и на валидационных. Визуализируйте графики обучения

# %%
np.random.seed(231)

num_train = 100
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

model = ThreeLayerConvNet(weight_scale=1e-2)

solver = Solver(model, small_data,
                num_epochs=30, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=1)
solver.train()

# %%
# Print final training accuracy
print(
    "Small data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)

# %%
# Print final validation accuracy
print(
    "Small data validation accuracy:",
    solver.check_accuracy(small_data['X_val'], small_data['y_val'])
)

# %%
plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')
plt.xlabel('iteration')
plt.ylabel('loss')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o')
plt.plot(solver.val_acc_history, '-o')
plt.legend(['train', 'val'], loc='upper left')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %% [markdown]
# Обучите сеть на полном наборе данных. Выведите accuracy на обучающей и валидационной выборках

# %%
model = ThreeLayerConvNet(weight_scale=0.001, hidden_dim=500, reg=0.001)

solver = Solver(model, data,
                num_epochs=1, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=20)
solver.train()

# %%
# Print final training accuracy
print(
    "Full data training accuracy:",
    solver.check_accuracy(small_data['X_train'], small_data['y_train'])
)

# %%
# Print final validation accuracy
print(
    "Full data validation accuracy:",
    solver.check_accuracy(data['X_val'], data['y_val'])
)

# %% [markdown]
# Визуализируйте фильтры на первом слое обученной сети

# %%
from scripts.vis_utils import visualize_grid

grid = visualize_grid(model.params['W1'].transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(5, 5)
plt.show()
